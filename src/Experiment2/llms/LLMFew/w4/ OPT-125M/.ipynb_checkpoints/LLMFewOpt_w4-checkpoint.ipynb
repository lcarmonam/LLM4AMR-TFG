# %%
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

import sklearn
from sklearn import metrics

import random, os, json
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import sys
sys.path.append("../")
import utils

from joblib import Parallel, delayed
import multiprocessing

import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader, TensorDataset

from torch.optim import Adam
from torch.nn import BCELoss
import numpy as np
import argparse
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, confusion_matrix

#from LLMFew import LLMFew
from CasualCNN import CausalCNNEncoder
from Embed import PatchEmbedding
from sklearn.utils import resample
from LLMprepareopt import LLMprepare

device = torch.device('cuda:0')
# Out:
# 2025-04-21 17:18:28.166409: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-21 17:18:28.203121: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-21 17:18:29.118282: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# cuda:0

# %%
def calculate_metrics(y_true, y_pred_probs):
    y_pred = np.round(y_pred_probs).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    specificity = tn / (tn + fp)  
    roc_auc = roc_auc_score(y_true, y_pred_probs) 

    return accuracy, recall, specificity, roc_auc, tn, fp, fn, tp

# %% [markdown]
# ### HYPERPARAMETERS

# %% [markdown]
# - **seeds**: Seed values to ensure reproducibility.
# - **batch_size**: Number of samples per batch used during training.
# - **dropout**: Dropout rate applied to prevent overfitting.
# - **weight_decay**: Weight decay for the optimizer to apply additional L2 regularization.
# - **lr**: Learning rate assigned to the optimizer.
# - **patience**: Number of epochs with no improvement before early stopping is triggered.
# - **dimensions**: Number of features in each time step of the input data.
# - **length**: Number of time steps in the input sequence.
# - **num_class**: Number of output classes for the prediction task.
# - **patch_len**: Length of each patch created from the input sequence.
# - **stride**: Step size used when unfolding the sequence into patches.
# - **llm_type**: Type of large language model used as a backbone.

# %%
class Configs:
    def __init__(self):
        self.dimensions = 87
        self.length = 4
        self.num_class = 1  
        self.depth = 2
        self.channels = 128
        self.reduced_size = 64
        self.kernel_size = 3
        self.patch_len = 2
        self.stride = 1
        self.dropout = 0.1
        self.batch_size = 4
        self.epochs = 100
        self.lr = 0.0005
        self.llm_type = "facebook/opt-125m"  
        self.lora = 1
        
seeds = [9, 76, 227, 12, 18, 45]
batch_size = 4
n_epochs_max = 100
configs = Configs() 
monitor = "val_auc"  

hyperparameters = {
    "lr": configs.lr,
    "batch_size": batch_size,          
    "n_epochs_max": n_epochs_max,                
    "weight_decay": 5e-4, 
    "dropout": configs.dropout,
    "patience": 15,
}

# %% [markdown]
# ### FUNCTIONS OF THE MODEL

# %%
class LLMFew(nn.Module):
    def __init__(self, configs):
        super(LLMFew, self).__init__()
        self.configs = configs
        self.num_class = configs.num_class
        self.length = configs.length
        self.dimensions = configs.dimensions
        self.llm_type = configs.llm_type
        self.lora = configs.lora
        self.patch_len = configs.patch_len
        self.stride = configs.stride
        self.llm_model, self.d_model = LLMprepare(configs)
        self.patch_embedding = PatchEmbedding(
            self.d_model, self.patch_len, self.stride, configs.dropout) 
        self.patch_nums = int((self.length - self.patch_len) / self.stride + 2)
        self.padding_patch_layer = nn.ReplicationPad1d((0, self.stride if self.patch_len < self.length else 0))
        self.encoder = CausalCNNEncoder(in_channels=self.dimensions, channels=configs.channels, depth=configs.depth,
                                        reduced_size=configs.reduced_size, out_channels=self.d_model,
                                        kernel_size=configs.kernel_size)
        self.dropout = nn.Dropout(configs.dropout)
        self.relu = nn.LeakyReLU()
        self.act = F.relu
        self.ln_proj = nn.LayerNorm(self.d_model * self.patch_nums).to(torch.bfloat16)
        self.mapping = nn.Sequential(nn.Linear(self.d_model * self.patch_nums, self.num_class),
                                     nn.Dropout(configs.dropout))
        self.activation = nn.Sigmoid()

    def forward(self, x):
        # x: batch, dim(dimensions), seq(length)
        x = x.contiguous()
        B, L, M = x.shape
        x = x.permute(0, 2, 1)  # (B, M, L)
        input_x = self.padding_patch_layer(x)  
        input_x = input_x.unfold(dimension=-1, size=self.patch_len, step=self.stride)
        input_x = rearrange(input_x, 'b m n p-> (b n) m p')
        output_x = self.encoder(input_x)
        output_x = self.dropout(output_x)
        output_x = rearrange(output_x, '(b n) o-> b n o', b=B)
        output_x = output_x.to(torch.bfloat16)
        
        llm_out = self.llm_model(inputs_embeds=output_x.contiguous()).last_hidden_state
        outputs = self.relu(llm_out + output_x).reshape(B, -1)
        outputs = self.ln_proj(outputs)
        outputs = outputs.to(torch.float32)
        outputs = self.mapping(outputs)
        outputs = self.activation(outputs)
        
        return outputs

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0, verbose=False):
    """
    Early stops the training if validation ROC AUC does not improve after a given patience.

    Args:
        - patience: Number of epochs to wait for an improvement before stopping the training. 
        - delta: Minimum change in the monitored metric to qualify as an improvement.
        - verbose: If True, prints detailed messages each time the model improves and when early stopping is triggered.
    """
        self.patience = patience
        self.delta = delta
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.best_roc_auc = 0.0  

    def __call__(self, roc_auc, model):
        if self.best_score is None:
            self.best_score = roc_auc
            self.save_checkpoint(roc_auc, model)
        elif roc_auc < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = roc_auc
            self.save_checkpoint(roc_auc, model)
            self.counter = 0

    def save_checkpoint(self, roc_auc, model):
        """Saves the model when ROC AUC increases."""
        if self.verbose:
            print(f"ROC AUC increased ({self.best_roc_auc:.4f} --> {roc_auc:.4f}). Saving model ...")
        self.best_roc_auc = roc_auc
        torch.save(model.state_dict(), 'checkpoint.pt')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False 
    
def run_network(X_train, X_val, y_train, y_val, hyperparameters, seed, configs): 
    """
    Trains and evaluates the built model based on the provided data and hyperparameters.

    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.
        - configs: Configuration object with model settings.

    Returns:
        - model: The trained PyTorch model.
        - history: Training history object containing loss and metrics.
    """  
    device = torch.device('cuda:0')
    print(device)
    batch_size=hyperparameters['batch_size']

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device).unsqueeze(1)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device).unsqueeze(1)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    set_seed(seed)
    
    configs = Configs()
    model = LLMFew(configs).to(device)
    print(model)
    
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=hyperparameters['lr'], weight_decay=hyperparameters['weight_decay'])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

    train_loss_history = []
    val_loss_history = []
    val_auc_history = [] 
    early_stopping = EarlyStopping(patience=hyperparameters['patience'], delta=0.001, verbose=True)


    for epoch in range(hyperparameters['n_epochs_max']):
        model.train()
        train_loss = 0.0
        
        for batch_x, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_loss_history.append(train_loss)

        model.eval()
        val_loss = 0.0
        y_val_preds = []
        y_val_true = []
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()

                y_val_preds.extend(outputs.cpu().numpy().flatten())
                y_val_true.extend(batch_y.cpu().numpy().flatten())
        
        val_loss /= len(val_loader)
        val_loss_history.append(val_loss)

        y_val_preds = np.array(y_val_preds)
        y_val_true = np.array(y_val_true)
        accuracy, recall, specificity, roc_auc, tn, fp, fn, tp = calculate_metrics(y_val_true, y_val_preds)
        
        val_auc_history.append(roc_auc)
        scheduler.step(val_loss)
        
        print(f"Epoch {epoch + 1}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"Validation Metrics - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        early_stopping(roc_auc, model)
        if early_stopping.early_stop:
            print("Early stopping.")
            break
    
    model.load_state_dict(torch.load('checkpoint.pt'))

    history = {'loss': train_loss_history, 'val_loss': val_loss_history,
        'val_auc': val_auc_history}
    return model, history

# %%
def objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs):
    """
    Objective function for hyperparameter optimization using Optuna.
    Args:
        - trial (optuna.trial.Trial): Optuna trial object.
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
        - configs: Configuration object with model settings.        
   
    Returns:
        - metric_dev: Best validation AUC achieved during training.     
    """
    trial_seed = seed + trial.number  
    set_seed(trial_seed)

    hyperparameters_copy = hyperparameters.copy()

    hyperparameters_copy['lr'] = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    hyperparameters_copy['weight_decay'] = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    hyperparameters_copy['dropout'] = trial.suggest_float("dropout", 0.0, 0.3)
    hyperparameters_copy['patience'] = trial.suggest_int("patience", 3, 20)

    v_val_auc = [] 
    
    configs = Configs()
    
    model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters_copy,
            trial_seed, 
            configs
        )

    v_val_auc.append(max(history['val_auc']))
    metric_dev = np.mean(v_val_auc)

    return metric_dev

def optuna_study(hyperparameters, seed, X_train, y_train, X_val, y_val):
    """
    Runs an Optuna study to optimize hyperparameters for the model.
    
    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
    Returns:
        - best_hyperparameters: Dictionary containing the best hyperparameters found 
          after the optimization process.
    """  
    set_seed(seed)

    sampler = optuna.samplers.TPESampler(seed=seed)
    study = optuna.create_study(direction='maximize', sampler=sampler)

    study.optimize(
        lambda trial: objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs),
        n_trials=20,  
        n_jobs=1      
    )

    best_params = study.best_params
    best_metric = study.best_value
    
    best_hyperparameters = {
        'lr': best_params['lr'], 
        'weight_decay': best_params['weight_decay'], 
        'dropout': best_params['dropout'],  
        'patience': best_params['patience'],  
    }

    print(f"Best Hyperparameters: {best_params}")
    print(f"Best Validation Metric: {best_metric}")

    return best_hyperparameters

# %% [markdown]
# ### PREDICTIONS

# %%
import time
import os
import pickle
import torch
import numpy as np
import pandas as pd

run_model = True
results = []
if run_model:
    loss_train = []
    loss_dev = []
    v_models = []

    y_pred_by_split = {}
    bestHyperparameters_bySplit = {}
        
    for i in [1,2,3,4,5]:
        init = time.time()
        
        X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_test_tensor_standardScaler.npy")
        y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_train_tensor_standardScaler.npy")
        y_train = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_train_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    
        X_val = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_val_tensor_standardScaler.npy")
        y_val = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_val_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)


        X_train = np.where(X_train == 666, 0, X_train)
        X_val = np.where(X_val == 666, 0, X_val)
        X_test = np.where(X_test == 666, 0, X_test)

        X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device).unsqueeze(1)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        bestHyperparameters = optuna_study(
            hyperparameters,
            seeds[i-1],
            X_train, y_train,  
            X_val, y_val
        )

        bestHyperparameters_bySplit[str(i)] = bestHyperparameters
        
        split_directory = f'./Results_FewOpt/split_{i}'
        if not os.path.exists(split_directory):
            os.makedirs(split_directory)
        
        with open(os.path.join(split_directory, f"bestHyperparameters_split_{i}.pkl"), 'wb') as f:
            pickle.dump(bestHyperparameters, f)
        
        hyperparameters.update({
            'lr': bestHyperparameters['lr'], 
            'weight_decay': bestHyperparameters['weight_decay'],
            'dropout': bestHyperparameters['dropout'], 
            'patience': bestHyperparameters['patience']
        })        

        
        configs = Configs()
        criterion = nn.BCELoss()
        
        model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters,
            seeds[i-1], 
            configs
        )

        v_models.append(model)
        loss_train.append(history['loss'])
        loss_dev.append(history['val_loss'])

        y_pred = []
        y_true = []
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                test_loss += loss.item()
                
                y_pred.extend(outputs.cpu().numpy().flatten())
                y_true.extend(batch_y.cpu().numpy().flatten())
        
        test_loss /= len(test_loader)
        y_pred = np.array(y_pred)  
        y_true = np.array(y_true)
        
        accuracy, recall, specificity, roc_auc, tn, fp, fn, tp = calculate_metrics(y_true, y_pred)
    
        print(f" Test Loss: {test_loss:.4f}")
        print(f"Test Metrics for Split {i} - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        results.append([accuracy, recall, specificity, roc_auc, tn, fp, fn, tp])

        y_pred_by_split[str(i)] = y_pred
        print(f"for split {i}:")
        print(y_pred_by_split[str(i)])

        y_pred_path = os.path.join(split_directory, f"y_pred_split_{i}.pkl")
        with open(y_pred_path, 'wb') as f:
            pickle.dump(y_pred, f)
    
    directory = './Results_FewOpt'
    if not os.path.exists(directory):
        os.makedirs(directory)

    def save_to_pickle(data, filename):
        with open(filename, 'wb') as f:
            pickle.dump(data, f)

    save_to_pickle(y_pred_by_split, os.path.join(directory, "y_pred_by_split.pkl"))
    save_to_pickle(loss_train, os.path.join(directory, "loss_train.pkl"))
    save_to_pickle(loss_dev, os.path.join(directory, "loss_dev.pkl"))
    save_to_pickle(bestHyperparameters_bySplit, os.path.join(directory, "bestHyperparameters_bySplit.pkl"))
# Out:
# cuda:0
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): OPTModel(
#         (decoder): OPTDecoder(
#           (embed_tokens): Embedding(50272, 768, padding_idx=1)
#           (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (layers): ModuleList(
#             (0-11): 12 x OPTDecoderLayer(
#               (self_attn): OPTSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (activation_fn): ReLU()
#               (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6665, Validation Loss: 0.6049
# Validation Metrics - Accuracy: 0.6580, Recall: 0.6724, Specificity: 0.6519, ROC AUC: 0.7582
# Confusion Matrix - TN: 88, FP: 47, FN: 19, TP: 39
# ROC AUC increased (0.0000 --> 0.7582). Saving model ...
# Epoch 2, Training Loss: 0.5557, Validation Loss: 0.6601
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7414, Specificity: 0.6222, ROC AUC: 0.7526
# Confusion Matrix - TN: 84, FP: 51, FN: 15, TP: 43
# EarlyStopping counter: 1 out of 15
# Epoch 3, Training Loss: 0.5889, Validation Loss: 0.6178
# Validation Metrics - Accuracy: 0.6839, Recall: 0.6724, Specificity: 0.6889, ROC AUC: 0.7792
# Confusion Matrix - TN: 93, FP: 42, FN: 19, TP: 39
# ROC AUC increased (0.7582 --> 0.7792). Saving model ...
# Epoch 4, Training Loss: 0.4552, Validation Loss: 0.6810
# Validation Metrics - Accuracy: 0.6736, Recall: 0.6552, Specificity: 0.6815, ROC AUC: 0.7471
# Confusion Matrix - TN: 92, FP: 43, FN: 20, TP: 38
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.3809, Validation Loss: 1.0236
# Validation Metrics - Accuracy: 0.5648, Recall: 0.7414, Specificity: 0.4889, ROC AUC: 0.7184
# Confusion Matrix - TN: 66, FP: 69, FN: 15, TP: 43
# EarlyStopping counter: 2 out of 15
# Epoch 6, Training Loss: 0.2795, Validation Loss: 1.0848
# Validation Metrics - Accuracy: 0.5907, Recall: 0.7414, Specificity: 0.5259, ROC AUC: 0.7294
# Confusion Matrix - TN: 71, FP: 64, FN: 15, TP: 43
# EarlyStopping counter: 3 out of 15
# Epoch 7, Training Loss: 0.1643, Validation Loss: 1.2236
# Validation Metrics - Accuracy: 0.6736, Recall: 0.7414, Specificity: 0.6444, ROC AUC: 0.7212
# Confusion Matrix - TN: 87, FP: 48, FN: 15, TP: 43
# EarlyStopping counter: 4 out of 15
# Epoch 8, Training Loss: 0.1593, Validation Loss: 2.2188
# Validation Metrics - Accuracy: 0.5130, Recall: 0.8448, Specificity: 0.3704, ROC AUC: 0.7139
# Confusion Matrix - TN: 50, FP: 85, FN: 9, TP: 49
# EarlyStopping counter: 5 out of 15
# Epoch 9, Training Loss: 0.1235, Validation Loss: 1.3001
# Validation Metrics - Accuracy: 0.6736, Recall: 0.7241, Specificity: 0.6519, ROC AUC: 0.7289
# Confusion Matrix - TN: 88, FP: 47, FN: 16, TP: 42
# EarlyStopping counter: 6 out of 15
# Epoch 10, Training Loss: 0.0864, Validation Loss: 1.3670
# Validation Metrics - Accuracy: 0.6736, Recall: 0.7241, Specificity: 0.6519, ROC AUC: 0.7296
# Confusion Matrix - TN: 88, FP: 47, FN: 16, TP: 42
# EarlyStopping counter: 7 out of 15
# Epoch 11, Training Loss: 0.0715, Validation Loss: 1.6364
# Validation Metrics - Accuracy: 0.6425, Recall: 0.7414, Specificity: 0.6000, ROC AUC: 0.7262
# Confusion Matrix - TN: 81, FP: 54, FN: 15, TP: 43
# EarlyStopping counter: 8 out of 15
# Epoch 12, Training Loss: 0.0701, Validation Loss: 1.6671
# Validation Metrics - Accuracy: 0.6477, Recall: 0.7414, Specificity: 0.6074, ROC AUC: 0.7291
# Confusion Matrix - TN: 82, FP: 53, FN: 15, TP: 43
# EarlyStopping counter: 9 out of 15
# Epoch 13, Training Loss: 0.0603, Validation Loss: 1.7815
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7586, Specificity: 0.6148, ROC AUC: 0.7228
# Confusion Matrix - TN: 83, FP: 52, FN: 14, TP: 44
# EarlyStopping counter: 10 out of 15
# Epoch 14, Training Loss: 0.0700, Validation Loss: 1.8039
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7586, Specificity: 0.6148, ROC AUC: 0.7215
# Confusion Matrix - TN: 83, FP: 52, FN: 14, TP: 44
# EarlyStopping counter: 11 out of 15
# Epoch 15, Training Loss: 0.0832, Validation Loss: 1.7634
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7414, Specificity: 0.6222, ROC AUC: 0.7251
# Confusion Matrix - TN: 84, FP: 51, FN: 15, TP: 43
# EarlyStopping counter: 12 out of 15
# Epoch 16, Training Loss: 0.0747, Validation Loss: 1.8393
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7586, Specificity: 0.6148, ROC AUC: 0.7259
# Confusion Matrix - TN: 83, FP: 52, FN: 14, TP: 44
# EarlyStopping counter: 13 out of 15
# Epoch 17, Training Loss: 0.0663, Validation Loss: 1.8456
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7586, Specificity: 0.6148, ROC AUC: 0.7266
# Confusion Matrix - TN: 83, FP: 52, FN: 14, TP: 44
# EarlyStopping counter: 14 out of 15
# Epoch 18, Training Loss: 0.0937, Validation Loss: 1.8988
# Validation Metrics - Accuracy: 0.6528, Recall: 0.7586, Specificity: 0.6074, ROC AUC: 0.7229
# Confusion Matrix - TN: 82, FP: 53, FN: 14, TP: 44
# EarlyStopping counter: 15 out of 15
# Confusion Matrix - TN: 74, FP: 40, FN: 11, TP: 38
# ROC AUC increased (0.7676 --> 0.7830). Saving model ...
# Epoch 4, Training Loss: 0.4149, Validation Loss: 0.5816
# Validation Metrics - Accuracy: 0.7669, Recall: 0.5714, Specificity: 0.8509, ROC AUC: 0.7460
# Confusion Matrix - TN: 97, FP: 17, FN: 21, TP: 28
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.3470, Validation Loss: 0.8396
# Validation Metrics - Accuracy: 0.6380, Recall: 0.7755, Specificity: 0.5789, ROC AUC: 0.7621
# Confusion Matrix - TN: 66, FP: 48, FN: 11, TP: 38
# EarlyStopping counter: 2 out of 15
# Epoch 6, Training Loss: 0.3069, Validation Loss: 0.8566
# Validation Metrics - Accuracy: 0.7055, Recall: 0.5714, Specificity: 0.7632, ROC AUC: 0.7150
# Confusion Matrix - TN: 87, FP: 27, FN: 21, TP: 28
# EarlyStopping counter: 3 out of 15
# Epoch 7, Training Loss: 0.3148, Validation Loss: 1.3561
# Validation Metrics - Accuracy: 0.5828, Recall: 0.8367, Specificity: 0.4737, ROC AUC: 0.7424
# Confusion Matrix - TN: 54, FP: 60, FN: 8, TP: 41
# EarlyStopping counter: 4 out of 15
# Epoch 8, Training Loss: 0.2095, Validation Loss: 1.3196
# Validation Metrics - Accuracy: 0.6442, Recall: 0.7143, Specificity: 0.6140, ROC AUC: 0.7131
# Confusion Matrix - TN: 70, FP: 44, FN: 14, TP: 35
# EarlyStopping counter: 5 out of 15
# Epoch 9, Training Loss: 0.1795, Validation Loss: 1.2119
# Validation Metrics - Accuracy: 0.6748, Recall: 0.6122, Specificity: 0.7018, ROC AUC: 0.7250
# Confusion Matrix - TN: 80, FP: 34, FN: 19, TP: 30
# EarlyStopping counter: 6 out of 15
# Epoch 10, Training Loss: 0.1354, Validation Loss: 1.4986
# Validation Metrics - Accuracy: 0.6380, Recall: 0.6735, Specificity: 0.6228, ROC AUC: 0.7206
# Confusion Matrix - TN: 71, FP: 43, FN: 16, TP: 33
# EarlyStopping counter: 7 out of 15
# Epoch 11, Training Loss: 0.1372, Validation Loss: 1.5215
# Validation Metrics - Accuracy: 0.6564, Recall: 0.6531, Specificity: 0.6579, ROC AUC: 0.7021
# Confusion Matrix - TN: 75, FP: 39, FN: 17, TP: 32
# EarlyStopping counter: 8 out of 15
# Epoch 12, Training Loss: 0.1040, Validation Loss: 1.8261
# Validation Metrics - Accuracy: 0.6442, Recall: 0.6939, Specificity: 0.6228, ROC AUC: 0.7099
# Confusion Matrix - TN: 71, FP: 43, FN: 15, TP: 34
# EarlyStopping counter: 9 out of 15
# Epoch 13, Training Loss: 0.0768, Validation Loss: 1.9067
# Validation Metrics - Accuracy: 0.6442, Recall: 0.6939, Specificity: 0.6228, ROC AUC: 0.7150
# Confusion Matrix - TN: 71, FP: 43, FN: 15, TP: 34
# EarlyStopping counter: 10 out of 15
# Epoch 14, Training Loss: 0.0864, Validation Loss: 1.8950
#  0.4549485  0.3700223  0.30290076 0.98712116 0.9108781  0.7336456
#  0.95264417 0.32912084 0.38032368 0.50980055 0.53431326 0.685041
#  0.4642526  0.7327504  0.6497476  0.8326995  0.5497245  0.583619
#  0.9801981  0.7615938  0.470344   0.34062314 0.6657438  0.9593685
#  0.8461356  0.8656522  0.7555026  0.18172902 0.9519249  0.71421856
#  0.10211123 0.11858803]
# cuda:0
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): OPTModel(
#         (decoder): OPTDecoder(
#           (embed_tokens): Embedding(50272, 768, padding_idx=1)
#           (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (layers): ModuleList(
#             (0-11): 12 x OPTDecoderLayer(
#               (self_attn): OPTSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (activation_fn): ReLU()
#               (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7644, Validation Loss: 0.5729
# Validation Metrics - Accuracy: 0.7291, Recall: 0.3115, Specificity: 0.9085, ROC AUC: 0.6949
# Confusion Matrix - TN: 129, FP: 13, FN: 42, TP: 19
# ROC AUC increased (0.0000 --> 0.6949). Saving model ...
# Epoch 2, Training Loss: 0.5789, Validation Loss: 0.5695
# Validation Metrics - Accuracy: 0.7291, Recall: 0.4426, Specificity: 0.8521, ROC AUC: 0.7333
# Confusion Matrix - TN: 121, FP: 21, FN: 34, TP: 27
# ROC AUC increased (0.6949 --> 0.7333). Saving model ...
# Epoch 3, Training Loss: 0.4630, Validation Loss: 0.5015
# Validation Metrics - Accuracy: 0.7931, Recall: 0.5246, Specificity: 0.9085, ROC AUC: 0.7741
# Confusion Matrix - TN: 129, FP: 13, FN: 29, TP: 32
# ROC AUC increased (0.7333 --> 0.7741). Saving model ...
# Epoch 4, Training Loss: 0.4944, Validation Loss: 0.5950
# Validation Metrics - Accuracy: 0.7094, Recall: 0.6230, Specificity: 0.7465, ROC AUC: 0.7419
# Confusion Matrix - TN: 106, FP: 36, FN: 23, TP: 38
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.4486, Validation Loss: 0.6130
# Validation Metrics - Accuracy: 0.7340, Recall: 0.4590, Specificity: 0.8521, ROC AUC: 0.6963
# Confusion Matrix - TN: 121, FP: 21, FN: 33, TP: 28
# EarlyStopping counter: 2 out of 15
# Epoch 6, Training Loss: 0.3875, Validation Loss: 0.5775
# Validation Metrics - Accuracy: 0.7241, Recall: 0.6230, Specificity: 0.7676, ROC AUC: 0.7523
# Confusion Matrix - TN: 109, FP: 33, FN: 23, TP: 38
# EarlyStopping counter: 3 out of 15
# Epoch 7, Training Loss: 0.4053, Validation Loss: 0.6760
# Validation Metrics - Accuracy: 0.7488, Recall: 0.2951, Specificity: 0.9437, ROC AUC: 0.7453
# Confusion Matrix - TN: 134, FP: 8, FN: 43, TP: 18
# EarlyStopping counter: 4 out of 15
# Epoch 8, Training Loss: 0.3159, Validation Loss: 0.6575
# Validation Metrics - Accuracy: 0.6995, Recall: 0.6393, Specificity: 0.7254, ROC AUC: 0.7402
# Confusion Matrix - TN: 103, FP: 39, FN: 22, TP: 39
# EarlyStopping counter: 5 out of 15
# Epoch 9, Training Loss: 0.2482, Validation Loss: 0.8586
# Validation Metrics - Accuracy: 0.6847, Recall: 0.7541, Specificity: 0.6549, ROC AUC: 0.7363
# Confusion Matrix - TN: 93, FP: 49, FN: 15, TP: 46
# EarlyStopping counter: 6 out of 15
# Epoch 10, Training Loss: 0.2473, Validation Loss: 0.8852
# Validation Metrics - Accuracy: 0.6798, Recall: 0.7377, Specificity: 0.6549, ROC AUC: 0.7549
# Confusion Matrix - TN: 93, FP: 49, FN: 16, TP: 45
# EarlyStopping counter: 7 out of 15
# Epoch 11, Training Loss: 0.1575, Validation Loss: 0.8422
# Validation Metrics - Accuracy: 0.7291, Recall: 0.7377, Specificity: 0.7254, ROC AUC: 0.7647
# Confusion Matrix - TN: 103, FP: 39, FN: 16, TP: 45
# EarlyStopping counter: 8 out of 15
# Epoch 12, Training Loss: 0.1304, Validation Loss: 0.9733
# Validation Metrics - Accuracy: 0.6601, Recall: 0.7705, Specificity: 0.6127, ROC AUC: 0.7656
# Confusion Matrix - TN: 87, FP: 55, FN: 14, TP: 47
# EarlyStopping counter: 9 out of 15
# Epoch 13, Training Loss: 0.1298, Validation Loss: 0.8149
# Validation Metrics - Accuracy: 0.7685, Recall: 0.7213, Specificity: 0.7887, ROC AUC: 0.7641
# Confusion Matrix - TN: 112, FP: 30, FN: 17, TP: 44
# EarlyStopping counter: 10 out of 15
# Epoch 14, Training Loss: 0.1091, Validation Loss: 0.9322
# Validation Metrics - Accuracy: 0.7291, Recall: 0.7377, Specificity: 0.7254, ROC AUC: 0.7603
# Confusion Matrix - TN: 103, FP: 39, FN: 16, TP: 45
# EarlyStopping counter: 11 out of 15
# Epoch 15, Training Loss: 0.1044, Validation Loss: 0.9727
# Validation Metrics - Accuracy: 0.7143, Recall: 0.7541, Specificity: 0.6972, ROC AUC: 0.7611
# Confusion Matrix - TN: 99, FP: 43, FN: 15, TP: 46
# EarlyStopping counter: 12 out of 15
# Epoch 16, Training Loss: 0.1123, Validation Loss: 0.9825
# Validation Metrics - Accuracy: 0.7094, Recall: 0.7541, Specificity: 0.6901, ROC AUC: 0.7621
# Confusion Matrix - TN: 98, FP: 44, FN: 15, TP: 46
# EarlyStopping counter: 13 out of 15
# Epoch 17, Training Loss: 0.0979, Validation Loss: 0.9943
# Validation Metrics - Accuracy: 0.7192, Recall: 0.7541, Specificity: 0.7042, ROC AUC: 0.7646
# Confusion Matrix - TN: 100, FP: 42, FN: 15, TP: 46
# EarlyStopping counter: 14 out of 15
# Epoch 18, Training Loss: 0.0927, Validation Loss: 0.9743
# Validation Metrics - Accuracy: 0.7389, Recall: 0.7541, Specificity: 0.7324, ROC AUC: 0.7639
# Confusion Matrix - TN: 104, FP: 38, FN: 15, TP: 46
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 0.5342
# Test Metrics for Split 3 - Accuracy: 0.7919, Recall: 0.5385, Specificity: 0.9008, ROC AUC: 0.7723
# Confusion Matrix - TN: 218, FP: 24, FN: 48, TP: 56
#  0.08333952 0.99496436 0.24856077 0.9959086  0.99979705 0.48090407
#  0.85414416 0.9713208  0.9997056  0.7966726  0.0819089  0.13587913
#  0.10298495 0.10377713 0.0535845  0.03809077 0.4243662  0.8686127
#  0.141713   0.04723889 0.8827935  0.9969031  0.8559818  0.9679321
#  0.20775498 0.99975914 0.94976753 0.9995535  0.9978047  0.9622878
#  0.15839136 0.16678299 0.99732924 0.99924743 0.9714534  0.9998716
#  0.6653507  0.06673952 0.06781838 0.9842255  0.3875131  0.98894995
#  0.9989496  0.9997135  0.0579365  0.23922862 0.92018104 0.22734311
#  0.49315646 0.00373663 0.8458425  0.06015243 0.98727524 0.9867899
#  0.05258294]
# cuda:0
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): OPTModel(
#         (decoder): OPTDecoder(
#           (embed_tokens): Embedding(50272, 768, padding_idx=1)
#           (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (layers): ModuleList(
#             (0-11): 12 x OPTDecoderLayer(
#               (self_attn): OPTSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (activation_fn): ReLU()
#               (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6939, Validation Loss: 0.6310
# Validation Metrics - Accuracy: 0.6580, Recall: 0.9138, Specificity: 0.5481, ROC AUC: 0.8261
# Confusion Matrix - TN: 74, FP: 61, FN: 5, TP: 53
# ROC AUC increased (0.0000 --> 0.8261). Saving model ...
# Epoch 2, Training Loss: 0.5736, Validation Loss: 0.6995
# Validation Metrics - Accuracy: 0.6425, Recall: 0.8793, Specificity: 0.5407, ROC AUC: 0.8151
# Confusion Matrix - TN: 73, FP: 62, FN: 7, TP: 51
# EarlyStopping counter: 1 out of 15
# Epoch 3, Training Loss: 0.4814, Validation Loss: 0.5674
# Validation Metrics - Accuracy: 0.7409, Recall: 0.7414, Specificity: 0.7407, ROC AUC: 0.8082
# Confusion Matrix - TN: 100, FP: 35, FN: 15, TP: 43
# EarlyStopping counter: 2 out of 15
# Epoch 4, Training Loss: 0.4694, Validation Loss: 0.6837
# Validation Metrics - Accuracy: 0.6580, Recall: 0.8448, Specificity: 0.5778, ROC AUC: 0.8212
# Confusion Matrix - TN: 78, FP: 57, FN: 9, TP: 49
# EarlyStopping counter: 3 out of 15
# Epoch 5, Training Loss: 0.4055, Validation Loss: 1.4176
# Validation Metrics - Accuracy: 0.6425, Recall: 0.8276, Specificity: 0.5630, ROC AUC: 0.7534
# Confusion Matrix - TN: 76, FP: 59, FN: 10, TP: 48
# EarlyStopping counter: 4 out of 15
# Epoch 6, Training Loss: 0.3878, Validation Loss: 0.7297
# Validation Metrics - Accuracy: 0.7098, Recall: 0.7069, Specificity: 0.7111, ROC AUC: 0.8068
# Confusion Matrix - TN: 96, FP: 39, FN: 17, TP: 41
# EarlyStopping counter: 5 out of 15
# Epoch 7, Training Loss: 0.3324, Validation Loss: 0.6223
# Validation Metrics - Accuracy: 0.7254, Recall: 0.7241, Specificity: 0.7259, ROC AUC: 0.8130
# Confusion Matrix - TN: 98, FP: 37, FN: 16, TP: 42
# EarlyStopping counter: 6 out of 15
# Epoch 8, Training Loss: 0.2381, Validation Loss: 0.6881
# Validation Metrics - Accuracy: 0.7772, Recall: 0.7414, Specificity: 0.7926, ROC AUC: 0.8262
# Confusion Matrix - TN: 107, FP: 28, FN: 15, TP: 43
# EarlyStopping counter: 7 out of 15
# Epoch 9, Training Loss: 0.1797, Validation Loss: 0.7819
# Validation Metrics - Accuracy: 0.7513, Recall: 0.7414, Specificity: 0.7556, ROC AUC: 0.8220
# Confusion Matrix - TN: 102, FP: 33, FN: 15, TP: 43
# EarlyStopping counter: 8 out of 15
# Epoch 10, Training Loss: 0.1189, Validation Loss: 0.9220
# Validation Metrics - Accuracy: 0.7461, Recall: 0.7414, Specificity: 0.7481, ROC AUC: 0.8146
# Confusion Matrix - TN: 101, FP: 34, FN: 15, TP: 43
# EarlyStopping counter: 9 out of 15
# Epoch 11, Training Loss: 0.1218, Validation Loss: 1.0338
# Validation Metrics - Accuracy: 0.7409, Recall: 0.7931, Specificity: 0.7185, ROC AUC: 0.8088
# Confusion Matrix - TN: 97, FP: 38, FN: 12, TP: 46
# EarlyStopping counter: 10 out of 15
# Epoch 12, Training Loss: 0.0855, Validation Loss: 1.0338
# Validation Metrics - Accuracy: 0.7513, Recall: 0.7759, Specificity: 0.7407, ROC AUC: 0.8105
# Confusion Matrix - TN: 100, FP: 35, FN: 13, TP: 45
# EarlyStopping counter: 11 out of 15
# Epoch 13, Training Loss: 0.0682, Validation Loss: 1.0436
# Validation Metrics - Accuracy: 0.7617, Recall: 0.7586, Specificity: 0.7630, ROC AUC: 0.8107
# Confusion Matrix - TN: 103, FP: 32, FN: 14, TP: 44
# EarlyStopping counter: 12 out of 15
# Epoch 14, Training Loss: 0.0780, Validation Loss: 1.1243
# Validation Metrics - Accuracy: 0.7668, Recall: 0.7931, Specificity: 0.7556, ROC AUC: 0.8139
# Confusion Matrix - TN: 102, FP: 33, FN: 12, TP: 46
# EarlyStopping counter: 13 out of 15
# Epoch 15, Training Loss: 0.0866, Validation Loss: 1.2006
# Validation Metrics - Accuracy: 0.7668, Recall: 0.7931, Specificity: 0.7556, ROC AUC: 0.8123
# Confusion Matrix - TN: 102, FP: 33, FN: 12, TP: 46
# EarlyStopping counter: 14 out of 15
# Epoch 16, Training Loss: 0.0762, Validation Loss: 1.2055
# Validation Metrics - Accuracy: 0.7617, Recall: 0.7759, Specificity: 0.7556, ROC AUC: 0.8095
# Confusion Matrix - TN: 102, FP: 33, FN: 13, TP: 45
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 0.6859
# Test Metrics for Split 5 - Accuracy: 0.5984, Recall: 0.7636, Specificity: 0.5273, ROC AUC: 0.7042
# Confusion Matrix - TN: 135, FP: 121, FN: 26, TP: 84
# for split 5:
# [0.3868362  0.66405576 0.664196   0.46252036 0.5822819  0.451813
#  0.35408577 0.4113692  0.42392302 0.40083587 0.2953626  0.31313312
#  0.79211074 0.471002   0.50366706 0.48479414 0.44989958 0.38704517
#  0.6325855  0.6134108  0.7080993  0.23705247 0.5315273  0.50402045
#  0.9272447  0.40881565 0.4744441  0.6849882  0.48010457 0.5105841
#  0.38390997 0.40285385 0.47019595 0.86010283 0.50948787 0.45752898
#  0.5406823  0.57053024 0.7219247  0.577709   0.7051987  0.7544179
#  0.5311411  0.5125845  0.46286827 0.7376748  0.86306816 0.5490767
#  0.3709429  0.6343093  0.6143553  0.5494299  0.54473126 0.61733705
#  0.6542333  0.51288515 0.30287498 0.3542175  0.6509842  0.6169965
#  0.6857312  0.7914208  0.42610732 0.69171804 0.579612   0.79603547
#  0.5239443  0.45599678 0.6214614  0.6547783  0.72166324 0.8041965
#  0.77221227 0.54605144 0.56092876 0.6793051  0.45512563 0.5329298
#  0.35612974 0.35982686 0.51004946 0.73855275 0.33210114 0.38866472
#  0.50011295 0.73323977 0.53721887 0.7406544  0.4741088  0.68296254
#  0.5233784  0.5046926  0.47244608 0.40189847 0.92550623 0.5604572
#  0.5924974  0.5393396  0.54173017 0.5067654  0.34624907 0.46808603
#  0.42290473 0.44785446 0.65349597 0.7583118  0.5224339  0.5324062
#  0.59792596 0.5201653  0.61282057 0.48983967 0.40255868 0.51978785
#  0.74075407 0.59867376 0.4922995  0.77030504 0.63532233 0.53984725
#  0.7031385  0.5037525  0.78025013 0.6354103  0.67646754 0.3935831 ]

# %% [markdown]
# ### RESULTS (PERFORMANCE)

# %% [markdown]
# #### Step 1. Load model and best results

# %%
directory = './Results_FewOpt'

def load_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

y_pred_by_split = {}
y_pred_by_split['1'] = load_from_pickle(os.path.join('./Results_FewOpt/split_1', "y_pred_split_1.pkl"))
y_pred_by_split['2'] = load_from_pickle(os.path.join('./Results_FewOpt/split_2', "y_pred_split_2.pkl"))
y_pred_by_split['3'] = load_from_pickle(os.path.join('./Results_FewOpt/split_3', "y_pred_split_3.pkl"))
y_pred_by_split['4'] = load_from_pickle(os.path.join('./Results_FewOpt/split_4', "y_pred_split_4.pkl"))
y_pred_by_split['5'] = load_from_pickle(os.path.join('./Results_FewOpt/split_5', "y_pred_split_5.pkl"))

# %% [markdown]
# #### Step 2. Analysis of results

# %%
all_metrics = []

for i in [1,2,4]: 
    y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    y_test_single = y_test.flatten()  
    y_test_pred = y_pred_by_split[str(i)].flatten()  
    
    df_metrics = utils.get_metrics_(y_test_single, (y_test_pred))
    print(df_metrics)
    utils.plot_metrics(df_metrics)
    utils.plot_roc_curve(y_test_single, y_test_pred)

    all_metrics.append(df_metrics)
print(all_metrics)
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  186  77  41  72   0.68617     0.637168     0.707224  0.722804  0.549618
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  174  96  35  81  0.660622     0.698276     0.644444  0.728895  0.552901
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  183  78  39  73  0.686327     0.651786     0.701149  0.716236  0.555133
# [    TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  186  77  41  72   0.68617     0.637168     0.707224  0.722804  0.549618,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  174  96  35  81  0.660622     0.698276     0.644444  0.728895  0.552901,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  183  78  39  73  0.686327     0.651786     0.701149  0.716236  0.555133]

# %%
metrics_FewOpt = pd.concat(all_metrics)
metrics_FewOpt.to_csv('./Results_FewOpt/metrics_FewOpt.csv', index=False)

metrics_FewOpt.head()
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  186  77  41  72  0.686170     0.637168     0.707224  0.722804  0.549618
# 0  174  96  35  81  0.660622     0.698276     0.644444  0.728895  0.552901
# 0  183  78  39  73  0.686327     0.651786     0.701149  0.716236  0.555133

# %%
metrics_mean = metrics_FewOpt.mean()
metrics_std = metrics_FewOpt.std()

summary_df = pd.DataFrame({
    "Metric": metrics_mean.index,
    "Mean": metrics_mean.values,
    "Standard Deviation": metrics_std.values
})

summary_df.to_csv('./Results_FewOpt/metrics_summary_FewOpt.csv', index=False)

print("\nMean and Standard Deviation of the Splits:")
print(summary_df)
# Out:
# Mean and Standard Deviation of the Splits:
#         Metric        Mean  Standard Deviation
# 0           TN  181.000000            6.244998
# 1           FP   83.666667           10.692677
# 2           FN   38.333333            3.055050
# 3           TP   75.333333            4.932883
# 4     Accuracy    0.677706            0.014796
# 5  Sensitivity    0.662410            0.031909
# 6  Specificity    0.684273            0.034626
# 7      ROC AUC    0.722645            0.006331
# 8     F1 Score    0.552551            0.002774

# %%
metrics_FewOpt = pd.read_csv('./Results_FewOpt/metrics_FewOpt.csv')
stats_Opt = metrics_FewOpt.agg(["mean", "std"]) 
formatted_metrics = stats_Opt.apply(lambda x: f"{x['mean']*100:.2f} ± {x['std']*100:.2f}", axis=0)
formatted_metrics_df = pd.DataFrame(formatted_metrics, columns=["Metrics (Mean ± Std)"])
formatted_metrics_df.to_csv('./Results_FewOpt/metrics_FewOpt_formatted.csv', index=True)
print(formatted_metrics_df)
# Out:
#             Metrics (Mean ± Std)
# TN             18100.00 ± 624.50
# FP             8366.67 ± 1069.27
# FN              3833.33 ± 305.51
# TP              7533.33 ± 493.29
# Accuracy            67.77 ± 1.48
# Sensitivity         66.24 ± 3.19
# Specificity         68.43 ± 3.46
# ROC AUC             72.26 ± 0.63
# F1 Score            55.26 ± 0.28

# %% [markdown]
# ### SHAP

# %%
import shap

model_path = "/home/lcarmona/Modelos_finales/final_models/SHAP_bueno/LLM-Few4/checkpoint.pt"
if os.path.exists(model_path):
    configs = Configs()
    model = LLMFew(configs).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    print("Model loaded")
else:
    raise FileNotFoundError(f"Model not found in {model_path}")

feature_names = [
    'AMG', 'ATF', 'ATI', 'ATP', 'CAR', 'CF1', 'CF2', 'CF3', 'CF4', 'Falta', 
    'GCC', 'GLI', 'LIN', 'LIP', 'MAC', 'MON', 'NTI', 
    'OTR', 'OXA', 'PAP', 'PEN', 'POL', 'QUI', 
    'SUL', 'TTC', 'hoursVM', 'acinet.$_{pc}$', 'enterobac.$_{pc}$', 'enteroc.$_{pc}$',
    'pseud.$_{pc}$', 'staph.$_{pc}$', 'others.$_{pc}$', 'hoursICU', '# pat_atb', '# pat_MR', 
    'CAR.$_{n}$', 'PAP.$_{n}$', 'Falta.$_{n}$', 'QUI.$_{n}$', 
    'ATF.$_{n}$', 'OXA.$_{n}$', 'PEN.$_{n}$', 'CF3.$_{n}$', 
    'GLI.$_{n}$', 'CF4.$_{n}$', 'SUL.$_{n}$', 'NTI.$_{n}$', 
    'LIN.$_{n}$', 'AMG.$_{n}$', 'MAC.$_{n}$', 'CF1.$_{n}$', 'GCC.$_{n}$', 
    'POL.$_{n}$', 'ATI.$_{n}$', 'MON.$_{n}$', 'LIP.$_{n}$', 'TTC.$_{n}$', 
    'OTR.$_{n}$', 'CF2.$_{n}$', 'ATP.$_{n}$', '# pat_ttl', 'posture.$_{change}$', 
    'insulin', 'nutr_art', 'sedation', 'relax', 'hep_fail', 'renal_fail', 
    'coag_fail', 'hemo_fail', 'resp_fail', 'multi_fail', 'n_transf', 
    'vasoactive.$_{drug}$', 'dosis_nems', 'hoursTracheo', 'hoursUlcer', 
    'hoursHemo', 'C01 PIVC 1', 'C01 PIVC 2', 'C02 CVC - YD', 'C02 CVC - SD', 
    'C02 CVC - SI', 'C02 CVC - FD', 'C02 CVC - YI', 'C02 CVC - FI', '# catheters'
]

all_shap_values = []
all_inputs = []

class WrappedModel(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        return self.model(x)

wrapped_model = WrappedModel(model)

for i in [1, 2, 3, 4, 5]:
    print(f"Processing split {i}...")
    X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_test_tensor_standardScaler.npy")
    X_test_tensor = torch.tensor(np.where(X_test == 666, 0, X_test), dtype=torch.float32).to(device)

    background = X_test_tensor[np.random.choice(X_test_tensor.shape[0], 100, replace=False)]

    explainer = shap.GradientExplainer(wrapped_model, background)
    shap_values = explainer.shap_values(X_test_tensor)

    all_shap_values.append(shap_values)
    all_inputs.append(X_test_tensor.cpu().numpy())

all_shap_concat = np.concatenate(all_shap_values, axis=0)
all_inputs_concat = np.concatenate(all_inputs, axis=0)

if all_shap_concat.ndim == 3:
    shap_values_avg = all_shap_concat.mean(axis=1)
    X_test_avg = all_inputs_concat.mean(axis=1)
else:
    shap_values_avg = all_shap_concat
    X_test_avg = all_inputs_concat

plt.figure(figsize=(12, 8))
shap.summary_plot(
    shap_values_avg,
    X_test_avg,
    feature_names=feature_names,
    max_display=30,
    show=False
)

plt.xticks(rotation=45, fontsize=18) 
plt.yticks(fontsize=19)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=20)
cbar.set_ylabel("Feature value", fontsize=20)

plt.tight_layout()
plt.savefig("shap_summary_llmfewopt4.png", dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Model loaded
# Processing split1...
# Processing split2...
# Processing split3...
# Processing split4...
# Processing split5...

# %%
plt.figure(figsize=(12, 8))
shap_values_exp = shap.Explanation(
    values=shap_values_avg,
    data=X_test_avg,
    feature_names=feature_names
)

shap.plots.heatmap(shap_values_exp, show=False)

plt.xticks(fontsize=21, rotation=45)
plt.yticks(fontsize=21)
plt.xlabel("Instances", fontsize=20)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=19)
cbar.set_ylabel("SHAP value (impact on model output)", fontsize=17)

plt.savefig("shap_heatmap_llmfewopt4.png", dpi=300, bbox_inches='tight')
plt.close()

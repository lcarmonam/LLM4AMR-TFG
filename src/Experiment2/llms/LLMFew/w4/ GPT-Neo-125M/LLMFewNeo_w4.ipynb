# %%
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

import sklearn
from sklearn import metrics

import random, os, json
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import sys
sys.path.append("../")
import utils

from joblib import Parallel, delayed
import multiprocessing

import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader, TensorDataset

from torch.optim import Adam
from torch.nn import BCELoss
import numpy as np
import argparse
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, confusion_matrix

from CasualCNN import CausalCNNEncoder
from Embed import PatchEmbedding
from sklearn.utils import resample
from LLMpreparegptneo import LLMprepare

device = torch.device('cuda:0')
# Out:
# 2025-04-30 11:14:35.072045: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-30 11:14:35.121633: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-30 11:14:36.508802: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def calculate_metrics(y_true, y_pred_probs):
    y_pred = np.round(y_pred_probs).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    specificity = tn / (tn + fp)  
    roc_auc = roc_auc_score(y_true, y_pred_probs) 

    return accuracy, recall, specificity, roc_auc, tn, fp, fn, tp

# %% [markdown]
# ### HYPERPARAMETERS

# %% [markdown]
# - **seeds**: Seed values to ensure reproducibility.
# - **batch_size**: Number of samples per batch used during training.
# - **dropout**: Dropout rate applied to prevent overfitting.
# - **weight_decay**: Weight decay for the optimizer to apply additional L2 regularization.
# - **lr**: Learning rate assigned to the optimizer.
# - **patience**: Number of epochs with no improvement before early stopping is triggered.
# - **dimensions**: Number of features in each time step of the input data.
# - **length**: Number of time steps in the input sequence.
# - **num_class**: Number of output classes for the prediction task.
# - **patch_len**: Length of each patch created from the input sequence.
# - **stride**: Step size used when unfolding the sequence into patches.
# - **llm_type**: Type of large language model used as a backbone.

# %%
class Configs:
    def __init__(self):
        self.dimensions = 87
        self.length = 4
        self.num_class = 1  
        self.depth = 2
        self.channels = 128
        self.reduced_size = 64
        self.kernel_size = 3
        self.patch_len = 2
        self.stride = 1
        self.dropout = 0.1
        self.batch_size = 4
        self.epochs = 100
        self.lr = 0.0005
        self.llm_type = "gpt-neo-125M"  
        self.lora = 1
        
seeds = [9, 76, 227, 12, 18, 45]
batch_size = 4
n_epochs_max = 100
configs = Configs() 
monitor = "val_auc"  

hyperparameters = {
    "lr": configs.lr,
    "batch_size": batch_size,          
    "n_epochs_max": n_epochs_max,                
    "weight_decay": 5e-4, 
    "dropout": configs.dropout,
    "patience": 15,
}

# %% [markdown]
# ### FUNCTIONS OF THE MODEL

# %%
class LLMFew(nn.Module):
    def __init__(self, configs):
        super(LLMFew, self).__init__()
        self.configs = configs
        self.num_class = configs.num_class
        self.length = configs.length
        self.dimensions = configs.dimensions
        self.llm_type = configs.llm_type
        self.lora = configs.lora
        self.patch_len = configs.patch_len
        self.stride = configs.stride
        self.llm_model, self.d_model = LLMprepare(configs)
        self.patch_embedding = PatchEmbedding(
            self.d_model, self.patch_len, self.stride, configs.dropout)  
        self.patch_nums = int((self.length - self.patch_len) / self.stride + 2)
        self.padding_patch_layer = nn.ReplicationPad1d((0, self.stride if self.patch_len < self.length else 0))
        self.encoder = CausalCNNEncoder(in_channels=self.dimensions, channels=configs.channels, depth=configs.depth,
                                        reduced_size=configs.reduced_size, out_channels=self.d_model,
                                        kernel_size=configs.kernel_size)
        self.dropout = nn.Dropout(configs.dropout)
        self.relu = nn.LeakyReLU()
        self.act = F.relu
        self.ln_proj = nn.LayerNorm(self.d_model * self.patch_nums).to(torch.bfloat16)
        self.mapping = nn.Sequential(nn.Linear(self.d_model * self.patch_nums, self.num_class),
                                     nn.Dropout(configs.dropout))
        self.activation = nn.Sigmoid()

    def forward(self, x):
        # x: batch, dim(dimensions), seq(length)
        x = x.contiguous()
        B, L, M = x.shape
        x = x.permute(0, 2, 1)  # (B, M, L)
        input_x = self.padding_patch_layer(x) 
        input_x = input_x.unfold(dimension=-1, size=self.patch_len, step=self.stride)
        input_x = rearrange(input_x, 'b m n p-> (b n) m p')
        output_x = self.encoder(input_x)
        output_x = self.dropout(output_x)
        output_x = rearrange(output_x, '(b n) o-> b n o', b=B)
        output_x = output_x.to(torch.bfloat16)
        
        llm_out = self.llm_model(inputs_embeds=output_x.contiguous()).last_hidden_state
        outputs = self.relu(llm_out + output_x).reshape(B, -1)
        outputs = self.ln_proj(outputs)
        outputs = outputs.to(torch.float32)
        outputs = self.mapping(outputs)
        outputs = self.activation(outputs)
        
        return outputs

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.001, verbose=False):
        """
        Early stops the training if validation ROC AUC does not improve after a given patience.
    
        Args:
            - patience: Number of epochs to wait for an improvement before stopping the training. 
            - delta: Minimum change in the monitored metric to qualify as an improvement.
            - verbose: If True, prints detailed messages each time the model improves and when early stopping is triggered.
        """
        self.patience = patience
        self.delta = delta
        self.verbose = verbose
        self.counter = 0
        self.best_roc_auc = None  
        self.early_stop = False

    def __call__(self, roc_auc, model):
        if self.best_roc_auc is None or roc_auc > self.best_roc_auc + self.delta:
            self.save_checkpoint(roc_auc, model)
            self.best_roc_auc = roc_auc
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True

    def save_checkpoint(self, roc_auc, model):
        if self.verbose:
            print(f"ROC AUC improved ({self.best_roc_auc if self.best_roc_auc is not None else 0:.4f} --> {roc_auc:.4f}). Saving model ...")
        torch.save(model.state_dict(), 'checkpointNeo.pt')
# Out:
#   Cell In[5], line 10
#     """
#     ^
# IndentationError: expected an indented block

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False 
    
def run_network(X_train, X_val, y_train, y_val, hyperparameters, seed, configs): 
    """
    Trains and evaluates the built model based on the provided data and hyperparameters.

    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.
        - configs: Configuration object with model settings.

    Returns:
        - model: The trained PyTorch model.
        - history: Training history object containing loss and metrics.
    """    
    device = torch.device('cuda:0')
    batch_size=hyperparameters['batch_size']
    

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device).unsqueeze(1)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device).unsqueeze(1)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    set_seed(seed)
    
    configs = Configs()
    model = LLMFew(configs).to(device)
    print(model)
    
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=hyperparameters['lr'], weight_decay=hyperparameters['weight_decay'])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

    train_loss_history = []
    val_loss_history = []
    val_auc_history = [] 
    early_stopping = EarlyStopping(patience=hyperparameters['patience'], delta=0.001, verbose=True)


    for epoch in range(hyperparameters['n_epochs_max']):
        model.train()
        train_loss = 0.0
        
        for batch_x, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_loss_history.append(train_loss)

        model.eval()
        val_loss = 0.0
        y_val_preds = []
        y_val_true = []
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()

                y_val_preds.extend(outputs.cpu().numpy().flatten())
                y_val_true.extend(batch_y.cpu().numpy().flatten())
        
        val_loss /= len(val_loader)
        val_loss_history.append(val_loss)

        y_val_preds = np.array(y_val_preds)
        y_val_true = np.array(y_val_true)
        accuracy, recall, specificity, roc_auc, tn, fp, fn, tp = calculate_metrics(y_val_true, y_val_preds)

        val_auc_history.append(roc_auc)
        scheduler.step(val_loss)
        
        print(f"Epoch {epoch + 1}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"Validation Metrics - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        early_stopping(roc_auc, model)
        if early_stopping.early_stop:
            print("Early stopping triggered.")
            break  
    
    print(f"The best model had a ROC AUC of: {early_stopping.best_roc_auc:.4f}")
    print("Loading the best model before test...")
    model.load_state_dict(torch.load('checkpointNeo.pt')) 

    history = {'loss': train_loss_history, 'val_loss': val_loss_history,
        'val_auc': val_auc_history}
    return model, history

# %%
def objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs):
    """
    Objective function for hyperparameter optimization using Optuna.
    Args:
        - trial (optuna.trial.Trial): Optuna trial object.
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
        - configs: Configuration object with model settings.        
   
    Returns:
        - metric_dev: Best validation AUC achieved during training.     
    """
    trial_seed = seed + trial.number  
    set_seed(trial_seed)

    hyperparameters_copy = hyperparameters.copy()

    hyperparameters_copy['lr'] = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    hyperparameters_copy['weight_decay'] = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    hyperparameters_copy['dropout'] = trial.suggest_float("dropout", 0.0, 0.3)
    hyperparameters_copy['patience'] = trial.suggest_int("patience", 3, 20)

    v_val_auc = [] 
    
    configs = Configs()
    
    model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters_copy,
            trial_seed, 
            configs
        )

    v_val_auc.append(max(history['val_auc']))
    metric_dev = np.mean(v_val_auc)

    return metric_dev

def optuna_study(hyperparameters, seed, X_train, y_train, X_val, y_val):
    """
    Runs an Optuna study to optimize hyperparameters for the model.
    
    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
    Returns:
        - best_hyperparameters: Dictionary containing the best hyperparameters found 
          after the optimization process.
    """  
    set_seed(seed)

    sampler = optuna.samplers.TPESampler(seed=seed)
    study = optuna.create_study(direction='maximize', sampler=sampler)

    study.optimize(
        lambda trial: objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs),
        n_trials=20,  
        n_jobs=1      
    )

    best_params = study.best_params
    best_metric = study.best_value
    
    best_hyperparameters = {
        'lr': best_params['lr'], 
        'weight_decay': best_params['weight_decay'], 
        'dropout': best_params['dropout'],  
        'patience': best_params['patience'],  
    }

    print(f"Best Hyperparameters: {best_params}")
    print(f"Best Validation Metric: {best_metric}")

    return best_hyperparameters

# %% [markdown]
# ### PREDICTIONS

# %%
import time
import os
import pickle
import torch
import numpy as np
import pandas as pd

run_model = True
results = []
if run_model:
    loss_train = []
    loss_dev = []
    v_models = []

    y_pred_by_split = {}
    bestHyperparameters_bySplit = {}

        
    for i in [1,2,3,4,5]:
        init = time.time()

        X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_test_tensor_standardScaler.npy")
        y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_train_tensor_standardScaler.npy")
        y_train = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_train_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    
        X_val = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_val_tensor_standardScaler.npy")
        y_val = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_val_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
   
        X_train = np.where(X_train == 666, 0, X_train)
        X_val = np.where(X_val == 666, 0, X_val)
        X_test = np.where(X_test == 666, 0, X_test)
    

        X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device).unsqueeze(1)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        bestHyperparameters = optuna_study(
            hyperparameters,
            seeds[i-1],
            X_train, y_train,  
            X_val, y_val
        )

        bestHyperparameters_bySplit[str(i)] = bestHyperparameters
        
        split_directory = f'./Results_FewNeo/split_{i}'
        if not os.path.exists(split_directory):
            os.makedirs(split_directory)
        
        with open(os.path.join(split_directory, f"bestHyperparameters_split_{i}.pkl"), 'wb') as f:
            pickle.dump(bestHyperparameters, f)

        hyperparameters.update({
            'lr': bestHyperparameters['lr'], 
            'weight_decay': bestHyperparameters['weight_decay'],
            'dropout': bestHyperparameters['dropout'], 
            'patience': bestHyperparameters['patience']
        })        
        
        configs = Configs()
        criterion = nn.BCELoss()
        
        model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters,
            seeds[i-1], 
            configs
        )

        v_models.append(model)
        loss_train.append(history['loss'])
        loss_dev.append(history['val_loss'])

        y_pred = []
        y_true = []
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                test_loss += loss.item()
                
                y_pred.extend(outputs.cpu().numpy().flatten())
                y_true.extend(batch_y.cpu().numpy().flatten())
        
        test_loss /= len(test_loader)
        y_pred = np.array(y_pred)  
        y_true = np.array(y_true)
        
        accuracy, recall, specificity, roc_auc, tn, fp, fn, tp = calculate_metrics(y_true, y_pred)
    
        print(f" Test Loss: {test_loss:.4f}")
        print(f"Test Metrics for Split {i} - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        results.append([accuracy, recall, specificity, roc_auc, tn, fp, fn, tp])

        y_pred_by_split[str(i)] = y_pred
        print(f"for split {i}:")
        print(y_pred_by_split[str(i)])

        y_pred_path = os.path.join(split_directory, f"y_pred_split_{i}.pkl")
        with open(y_pred_path, 'wb') as f:
            pickle.dump(y_pred, f)
        

    directory = './Results_FewNeo'
    if not os.path.exists(directory):
        os.makedirs(directory)

    def save_to_pickle(data, filename):
        with open(filename, 'wb') as f:
            pickle.dump(data, f)

    save_to_pickle(y_pred_by_split, os.path.join(directory, "y_pred_by_split.pkl"))
    save_to_pickle(loss_train, os.path.join(directory, "loss_train.pkl"))
    save_to_pickle(loss_dev, os.path.join(directory, "loss_dev.pkl"))
    save_to_pickle(bestHyperparameters_bySplit, os.path.join(directory, "bestHyperparameters_bySplit.pkl"))
# Out:
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPTNeoModel(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(2048, 768)
#         (drop): Dropout(p=0.0, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPTNeoBlock(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPTNeoAttention(
#               (attention): GPTNeoSelfAttention(
#                 (attn_dropout): Dropout(p=0.0, inplace=False)
#                 (resid_dropout): Dropout(p=0.0, inplace=False)
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPTNeoMLP(
#               (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#               (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6881, Validation Loss: 0.6201
# Validation Metrics - Accuracy: 0.6788, Recall: 0.5172, Specificity: 0.7481, ROC AUC: 0.7019
# Confusion Matrix - TN: 101, FP: 34, FN: 28, TP: 30
# ROC AUC improved (0.0000 --> 0.7019). Saving model ...
# Epoch 2, Training Loss: 0.6125, Validation Loss: 0.6385
# Validation Metrics - Accuracy: 0.6425, Recall: 0.6552, Specificity: 0.6370, ROC AUC: 0.6863
# Confusion Matrix - TN: 86, FP: 49, FN: 20, TP: 38
# EarlyStopping counter: 1 out of 15
# Epoch 3, Training Loss: 0.4929, Validation Loss: 0.5874
# Validation Metrics - Accuracy: 0.6995, Recall: 0.5172, Specificity: 0.7778, ROC AUC: 0.7215
# Confusion Matrix - TN: 105, FP: 30, FN: 28, TP: 30
# ROC AUC improved (0.7019 --> 0.7215). Saving model ...
# Epoch 4, Training Loss: 0.4329, Validation Loss: 0.8561
# Validation Metrics - Accuracy: 0.5699, Recall: 0.6379, Specificity: 0.5407, ROC AUC: 0.6564
# Confusion Matrix - TN: 73, FP: 62, FN: 21, TP: 37
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.4002, Validation Loss: 0.8045
# Validation Metrics - Accuracy: 0.6062, Recall: 0.6552, Specificity: 0.5852, ROC AUC: 0.6889
# Confusion Matrix - TN: 79, FP: 56, FN: 20, TP: 38
# EarlyStopping counter: 2 out of 15
# Epoch 6, Training Loss: 0.3167, Validation Loss: 0.7396
# Validation Metrics - Accuracy: 0.6425, Recall: 0.6034, Specificity: 0.6593, ROC AUC: 0.6922
# Confusion Matrix - TN: 89, FP: 46, FN: 23, TP: 35
# EarlyStopping counter: 3 out of 15
# Epoch 7, Training Loss: 0.3315, Validation Loss: 0.8452
# Validation Metrics - Accuracy: 0.6321, Recall: 0.6724, Specificity: 0.6148, ROC AUC: 0.6990
# Confusion Matrix - TN: 83, FP: 52, FN: 19, TP: 39
# EarlyStopping counter: 4 out of 15
# Epoch 8, Training Loss: 0.2235, Validation Loss: 1.1303
# Validation Metrics - Accuracy: 0.5803, Recall: 0.7241, Specificity: 0.5185, ROC AUC: 0.7096
# Confusion Matrix - TN: 70, FP: 65, FN: 16, TP: 42
# EarlyStopping counter: 5 out of 15
# Epoch 9, Training Loss: 0.1346, Validation Loss: 1.1732
# Validation Metrics - Accuracy: 0.5959, Recall: 0.6897, Specificity: 0.5556, ROC AUC: 0.7185
# Confusion Matrix - TN: 75, FP: 60, FN: 18, TP: 40
# EarlyStopping counter: 6 out of 15
# Epoch 10, Training Loss: 0.1131, Validation Loss: 1.3986
# Validation Metrics - Accuracy: 0.5855, Recall: 0.6897, Specificity: 0.5407, ROC AUC: 0.7152
# Confusion Matrix - TN: 73, FP: 62, FN: 18, TP: 40
# EarlyStopping counter: 7 out of 15
# Epoch 11, Training Loss: 0.1152, Validation Loss: 1.3260
# Validation Metrics - Accuracy: 0.6062, Recall: 0.7069, Specificity: 0.5630, ROC AUC: 0.7221
# Confusion Matrix - TN: 76, FP: 59, FN: 17, TP: 41
# EarlyStopping counter: 8 out of 15
# Epoch 12, Training Loss: 0.0957, Validation Loss: 1.5161
# Validation Metrics - Accuracy: 0.5907, Recall: 0.7069, Specificity: 0.5407, ROC AUC: 0.7116
# Confusion Matrix - TN: 73, FP: 62, FN: 17, TP: 41
# EarlyStopping counter: 9 out of 15
# Epoch 13, Training Loss: 0.0951, Validation Loss: 1.6765
# Validation Metrics - Accuracy: 0.5907, Recall: 0.7241, Specificity: 0.5333, ROC AUC: 0.7103
# Confusion Matrix - TN: 72, FP: 63, FN: 16, TP: 42
# EarlyStopping counter: 10 out of 15
# Epoch 14, Training Loss: 0.0791, Validation Loss: 1.8000
# Validation Metrics - Accuracy: 0.5855, Recall: 0.7069, Specificity: 0.5333, ROC AUC: 0.7097
# Confusion Matrix - TN: 72, FP: 63, FN: 17, TP: 41
# EarlyStopping counter: 11 out of 15
# Epoch 15, Training Loss: 0.0833, Validation Loss: 1.9213
# Validation Metrics - Accuracy: 0.5855, Recall: 0.7241, Specificity: 0.5259, ROC AUC: 0.7103
# Confusion Matrix - TN: 71, FP: 64, FN: 16, TP: 42
# EarlyStopping counter: 12 out of 15
# Epoch 16, Training Loss: 0.0789, Validation Loss: 1.8174
# Validation Metrics - Accuracy: 0.5907, Recall: 0.7241, Specificity: 0.5333, ROC AUC: 0.7189
# Confusion Matrix - TN: 72, FP: 63, FN: 16, TP: 42
# EarlyStopping counter: 13 out of 15
# Epoch 17, Training Loss: 0.0803, Validation Loss: 1.8397
# Validation Metrics - Accuracy: 0.5959, Recall: 0.7414, Specificity: 0.5333, ROC AUC: 0.7179
# Confusion Matrix - TN: 72, FP: 63, FN: 15, TP: 43
# EarlyStopping counter: 14 out of 15
# Epoch 18, Training Loss: 0.0741, Validation Loss: 1.7946
# Validation Metrics - Accuracy: 0.6114, Recall: 0.7241, Specificity: 0.5630, ROC AUC: 0.7186
# Confusion Matrix - TN: 76, FP: 59, FN: 16, TP: 42
# EarlyStopping counter: 15 out of 15
# Early stopping triggered.
# The best model had a ROC AUC of: 0.7215
# Loading the best model before test...
#  Test Loss: 0.6009
# Test Metrics for Split 1 - Accuracy: 0.7367, Recall: 0.4513, Specificity: 0.8593, ROC AUC: 0.6935
#  0.1580509  0.08704554 0.1235103  0.08016176 0.31104374 0.4799771
#  0.42281008 0.8126947  0.47059363 0.35518497 0.10435256 0.25343847
#  0.2759047  0.28456026 0.22398067 0.6183124  0.10547455 0.10760973
#  0.1687758  0.00947904 0.2281362  0.36119002 0.81437445 0.31582746
#  0.83296895 0.08887384 0.2616369  0.10642437 0.697848   0.3210928
#  0.07086165 0.5536416  0.27565634 0.21326092 0.06903425 0.20803791
#  0.5432388  0.11244067 0.0975769  0.04618612 0.7329163  0.9235119
#  0.45668215 0.81436026 0.37667757 0.74039114 0.03259357 0.2651744
#  0.57432586 0.6981892  0.3332623  0.30275455 0.18942656 0.4003235
#  0.56855667 0.5968661  0.16694087 0.8386624  0.47940528 0.09831389
#  0.94673103 0.07198501 0.80075574 0.13212484 0.7283859  0.46542346
#  0.6857689  0.21462975 0.2140439  0.30220464 0.790489   0.2715115
#  0.21637139 0.36685562 0.20817412 0.2106595  0.1027315  0.27027303
#  0.7437117  0.10640967 0.28173712 0.25114194 0.83833015 0.88957125
#  0.6447977  0.5493304  0.45070297 0.6463516  0.18079495 0.81916445
#  0.10546983 0.24305382 0.91150534 0.21445395 0.3468055  0.5010933
#  0.08679747 0.06723703 0.9843332  0.9566637  0.46281302 0.49869835
#  0.36636257 0.3882305  0.46514204 0.14454688 0.63331884 0.5846551
#  0.15921478 0.29664522 0.1565773  0.23343757 0.7810034  0.28766772
#  0.09975528 0.24081872 0.7361605  0.40258133 0.17234011 0.12493998
#  0.06962928 0.11871994 0.9662995  0.13386331 0.34124747 0.5277301
#  0.37345    0.06881494 0.57592034 0.7255496  0.65173036 0.96315235
#  0.69988304 0.34607664 0.3878336  0.4533503 ]
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPTNeoModel(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(2048, 768)
#         (drop): Dropout(p=0.0, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPTNeoBlock(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPTNeoAttention(
#               (attention): GPTNeoSelfAttention(
#                 (attn_dropout): Dropout(p=0.0, inplace=False)
#                 (resid_dropout): Dropout(p=0.0, inplace=False)
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPTNeoMLP(
#               (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#               (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6709, Validation Loss: 0.9226
# Validation Metrics - Accuracy: 0.4233, Recall: 1.0000, Specificity: 0.1754, ROC AUC: 0.7320
# Confusion Matrix - TN: 20, FP: 94, FN: 0, TP: 49
# ROC AUC improved (0.0000 --> 0.7320). Saving model ...
# Epoch 2, Training Loss: 0.6031, Validation Loss: 0.5425
# Validation Metrics - Accuracy: 0.7117, Recall: 0.5306, Specificity: 0.7895, ROC AUC: 0.7481
# Confusion Matrix - TN: 90, FP: 24, FN: 23, TP: 26
# ROC AUC improved (0.7320 --> 0.7481). Saving model ...
# Epoch 3, Training Loss: 0.5297, Validation Loss: 0.8397
# Validation Metrics - Accuracy: 0.5031, Recall: 0.8980, Specificity: 0.3333, ROC AUC: 0.7592
# Confusion Matrix - TN: 38, FP: 76, FN: 5, TP: 44
# ROC AUC improved (0.7481 --> 0.7592). Saving model ...
# Epoch 4, Training Loss: 0.4621, Validation Loss: 0.7212
# Validation Metrics - Accuracy: 0.6503, Recall: 0.7347, Specificity: 0.6140, ROC AUC: 0.7553
# Confusion Matrix - TN: 70, FP: 44, FN: 13, TP: 36
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.4196, Validation Loss: 0.8776
# Validation Metrics - Accuracy: 0.5951, Recall: 0.8367, Specificity: 0.4912, ROC AUC: 0.7648
# Confusion Matrix - TN: 56, FP: 58, FN: 8, TP: 41
# ROC AUC improved (0.7592 --> 0.7648). Saving model ...
# Epoch 6, Training Loss: 0.4046, Validation Loss: 0.7467
# Validation Metrics - Accuracy: 0.7485, Recall: 0.6735, Specificity: 0.7807, ROC AUC: 0.7705
# Confusion Matrix - TN: 89, FP: 25, FN: 16, TP: 33
# ROC AUC improved (0.7648 --> 0.7705). Saving model ...
# Epoch 7, Training Loss: 0.2907, Validation Loss: 1.0541
# Validation Metrics - Accuracy: 0.6380, Recall: 0.7755, Specificity: 0.5789, ROC AUC: 0.7537
# Confusion Matrix - TN: 66, FP: 48, FN: 11, TP: 38
# EarlyStopping counter: 1 out of 15
# Epoch 8, Training Loss: 0.2123, Validation Loss: 1.1852
# Validation Metrics - Accuracy: 0.6503, Recall: 0.7755, Specificity: 0.5965, ROC AUC: 0.7447
# Confusion Matrix - TN: 68, FP: 46, FN: 11, TP: 38
# EarlyStopping counter: 2 out of 15
# Epoch 9, Training Loss: 0.1889, Validation Loss: 1.0785
# Validation Metrics - Accuracy: 0.6442, Recall: 0.6939, Specificity: 0.6228, ROC AUC: 0.7338
# Confusion Matrix - TN: 71, FP: 43, FN: 15, TP: 34
# EarlyStopping counter: 3 out of 15
# Epoch 10, Training Loss: 0.1873, Validation Loss: 1.2105
# Validation Metrics - Accuracy: 0.6626, Recall: 0.6531, Specificity: 0.6667, ROC AUC: 0.7213
# Confusion Matrix - TN: 76, FP: 38, FN: 17, TP: 32
# EarlyStopping counter: 4 out of 15
# Epoch 11, Training Loss: 0.1427, Validation Loss: 1.2869
# Validation Metrics - Accuracy: 0.6503, Recall: 0.7347, Specificity: 0.6140, ROC AUC: 0.7379
# Confusion Matrix - TN: 70, FP: 44, FN: 13, TP: 36
# EarlyStopping counter: 5 out of 15
# Epoch 12, Training Loss: 0.0971, Validation Loss: 1.5216
# Validation Metrics - Accuracy: 0.6135, Recall: 0.7755, Specificity: 0.5439, ROC AUC: 0.7343
# Confusion Matrix - TN: 62, FP: 52, FN: 11, TP: 38
# EarlyStopping counter: 6 out of 15
# Epoch 13, Training Loss: 0.1142, Validation Loss: 1.5332
# Validation Metrics - Accuracy: 0.6380, Recall: 0.7347, Specificity: 0.5965, ROC AUC: 0.7377
# Confusion Matrix - TN: 68, FP: 46, FN: 13, TP: 36
# EarlyStopping counter: 7 out of 15
# Epoch 14, Training Loss: 0.1017, Validation Loss: 1.5207
# Validation Metrics - Accuracy: 0.6626, Recall: 0.7347, Specificity: 0.6316, ROC AUC: 0.7445
# Confusion Matrix - TN: 72, FP: 42, FN: 13, TP: 36
# EarlyStopping counter: 8 out of 15
# Epoch 15, Training Loss: 0.0974, Validation Loss: 1.5504
# Validation Metrics - Accuracy: 0.6687, Recall: 0.7143, Specificity: 0.6491, ROC AUC: 0.7417
# Confusion Matrix - TN: 74, FP: 40, FN: 14, TP: 35
# EarlyStopping counter: 9 out of 15
# Epoch 16, Training Loss: 0.0689, Validation Loss: 1.5824
# Validation Metrics - Accuracy: 0.6748, Recall: 0.7347, Specificity: 0.6491, ROC AUC: 0.7424
# Confusion Matrix - TN: 74, FP: 40, FN: 13, TP: 36
# EarlyStopping counter: 10 out of 15
# Epoch 17, Training Loss: 0.0850, Validation Loss: 1.6456
# Validation Metrics - Accuracy: 0.6748, Recall: 0.7347, Specificity: 0.6491, ROC AUC: 0.7422
# Confusion Matrix - TN: 74, FP: 40, FN: 13, TP: 36
# EarlyStopping counter: 11 out of 15
# Epoch 18, Training Loss: 0.0674, Validation Loss: 1.6735
# Validation Metrics - Accuracy: 0.6810, Recall: 0.7347, Specificity: 0.6579, ROC AUC: 0.7417
# Confusion Matrix - TN: 75, FP: 39, FN: 13, TP: 36
# EarlyStopping counter: 12 out of 15
# Epoch 19, Training Loss: 0.0874, Validation Loss: 1.7059
# Validation Metrics - Accuracy: 0.6810, Recall: 0.7347, Specificity: 0.6579, ROC AUC: 0.7410
# Confusion Matrix - TN: 75, FP: 39, FN: 13, TP: 36
# EarlyStopping counter: 13 out of 15
# Epoch 20, Training Loss: 0.0680, Validation Loss: 1.7336
# Validation Metrics - Accuracy: 0.6748, Recall: 0.7347, Specificity: 0.6491, ROC AUC: 0.7397
# Confusion Matrix - TN: 74, FP: 40, FN: 13, TP: 36
# EarlyStopping counter: 14 out of 15
# Epoch 21, Training Loss: 0.0829, Validation Loss: 1.7461
# Validation Metrics - Accuracy: 0.6626, Recall: 0.7143, Specificity: 0.6404, ROC AUC: 0.7397
# Confusion Matrix - TN: 73, FP: 41, FN: 14, TP: 35
# EarlyStopping counter: 15 out of 15
# Early stopping triggered.
# The best model had a ROC AUC of: 0.7705
# Loading the best model before test...
#  Test Loss: 0.7175
# Test Metrics for Split 2 - Accuracy: 0.7124, Recall: 0.6293, Specificity: 0.7481, ROC AUC: 0.7315
# Confusion Matrix - TN: 202, FP: 68, FN: 43, TP: 73
# for split 2:
# [0.13890637 0.5778484  0.49898148 0.18065134 0.15492643 0.19711821
#  0.16157182 0.05971384 0.13144505 0.3071838  0.05330859 0.28782168
#  0.19554013 0.02576416 0.524995   0.09849709 0.22186455 0.19841725
#  0.15859039 0.91624874 0.6572328  0.15547173 0.98432124 0.02215236
#  0.09868266 0.9410203  0.18032266 0.3406351  0.9873125  0.09011355
#  0.08218013 0.08803796 0.08865135 0.24969056 0.01392744 0.02395945
#  0.02540232 0.0507816  0.05701403 0.06305439 0.7206214  0.3690259
#  0.16171429 0.10249696 0.07951231 0.9858067  0.11433718 0.40845084
#  0.09715735 0.425032   0.16218856 0.776949   0.10496351 0.9297652
#  0.57803226 0.01999093 0.9930107  0.9962291  0.86925644 0.31595516
#  0.15016519 0.03752726 0.7197683  0.01693395 0.0110911  0.36513624
#  0.02592467 0.01341166 0.01189691 0.294127   0.0658024  0.01241587
#  0.06871974 0.25082642 0.13937081 0.4284934  0.09967352 0.3064921
#  0.93258864 0.43343413 0.30603316 0.95031303 0.23114064 0.14424206
#  0.57360375 0.9941605  0.95633954 0.974843   0.30389857 0.60153425
#  0.25248674 0.0201267  0.11515141 0.5240872  0.20309094 0.00905142
#  0.46460322 0.17973973 0.1624617  0.6012252  0.8876102  0.28674483
#  0.5263913  0.09990904 0.03535746 0.09832747 0.11720757 0.20917876
#  0.20033    0.22552405 0.18335357 0.97644585 0.8198064  0.86251456
#  0.36331543 0.12309536 0.13722874 0.8313616  0.29848436 0.9316087
#  0.1881322  0.23285104 0.256726   0.40103975 0.26401103 0.55598545
#  0.9806656  0.4176394  0.93631476 0.07080171 0.56347716 0.8809423
#  0.81038827 0.39079577 0.67648387 0.11225194 0.89431465 0.6310112
#  0.04117312 0.08407545]
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPTNeoModel(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(2048, 768)
#         (drop): Dropout(p=0.0, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPTNeoBlock(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPTNeoAttention(
#               (attention): GPTNeoSelfAttention(
#                 (attn_dropout): Dropout(p=0.0, inplace=False)
#                 (resid_dropout): Dropout(p=0.0, inplace=False)
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPTNeoMLP(
#               (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#               (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7312, Validation Loss: 0.7071
# Validation Metrics - Accuracy: 0.5911, Recall: 0.7213, Specificity: 0.5352, ROC AUC: 0.6572
# Confusion Matrix - TN: 76, FP: 66, FN: 17, TP: 44
# ROC AUC improved (0.0000 --> 0.6572). Saving model ...
# Epoch 2, Training Loss: 0.6413, Validation Loss: 0.5924
# Validation Metrics - Accuracy: 0.6404, Recall: 0.4918, Specificity: 0.7042, ROC AUC: 0.6802
# Confusion Matrix - TN: 100, FP: 42, FN: 31, TP: 30
# ROC AUC improved (0.6572 --> 0.6802). Saving model ...
# Epoch 3, Training Loss: 0.5896, Validation Loss: 0.5320
# Validation Metrics - Accuracy: 0.7291, Recall: 0.2787, Specificity: 0.9225, ROC AUC: 0.7331
# Confusion Matrix - TN: 131, FP: 11, FN: 44, TP: 17
# ROC AUC improved (0.6802 --> 0.7331). Saving model ...
# Epoch 4, Training Loss: 0.5678, Validation Loss: 0.7612
# Validation Metrics - Accuracy: 0.5764, Recall: 0.8525, Specificity: 0.4577, ROC AUC: 0.7663
# Confusion Matrix - TN: 65, FP: 77, FN: 9, TP: 52
# ROC AUC improved (0.7331 --> 0.7663). Saving model ...
# Epoch 5, Training Loss: 0.4803, Validation Loss: 0.5566
# Validation Metrics - Accuracy: 0.7291, Recall: 0.5574, Specificity: 0.8028, ROC AUC: 0.7609
# Confusion Matrix - TN: 114, FP: 28, FN: 27, TP: 34
# EarlyStopping counter: 1 out of 15
# Epoch 6, Training Loss: 0.4570, Validation Loss: 0.5855
# Validation Metrics - Accuracy: 0.7094, Recall: 0.5738, Specificity: 0.7676, ROC AUC: 0.7021
# Confusion Matrix - TN: 109, FP: 33, FN: 26, TP: 35
# EarlyStopping counter: 2 out of 15
# Epoch 7, Training Loss: 0.4142, Validation Loss: 0.6072
# Validation Metrics - Accuracy: 0.6897, Recall: 0.5902, Specificity: 0.7324, ROC AUC: 0.7370
# Confusion Matrix - TN: 104, FP: 38, FN: 25, TP: 36
# EarlyStopping counter: 3 out of 15
# Epoch 8, Training Loss: 0.3703, Validation Loss: 0.7703
# Validation Metrics - Accuracy: 0.6453, Recall: 0.7541, Specificity: 0.5986, ROC AUC: 0.7397
# Confusion Matrix - TN: 85, FP: 57, FN: 15, TP: 46
# EarlyStopping counter: 4 out of 15
# Epoch 9, Training Loss: 0.2970, Validation Loss: 0.5986
# Validation Metrics - Accuracy: 0.7488, Recall: 0.5410, Specificity: 0.8380, ROC AUC: 0.7572
# Confusion Matrix - TN: 119, FP: 23, FN: 28, TP: 33
# EarlyStopping counter: 5 out of 15
# Epoch 10, Training Loss: 0.2829, Validation Loss: 0.6593
# Validation Metrics - Accuracy: 0.7192, Recall: 0.6066, Specificity: 0.7676, ROC AUC: 0.7443
# Confusion Matrix - TN: 109, FP: 33, FN: 24, TP: 37
# EarlyStopping counter: 6 out of 15
# Epoch 11, Training Loss: 0.2346, Validation Loss: 1.0779
# Validation Metrics - Accuracy: 0.6158, Recall: 0.7705, Specificity: 0.5493, ROC AUC: 0.7249
# Confusion Matrix - TN: 78, FP: 64, FN: 14, TP: 47
# EarlyStopping counter: 7 out of 15
# Epoch 12, Training Loss: 0.1858, Validation Loss: 0.9597
# Validation Metrics - Accuracy: 0.6700, Recall: 0.6393, Specificity: 0.6831, ROC AUC: 0.7107
# Confusion Matrix - TN: 97, FP: 45, FN: 22, TP: 39
# EarlyStopping counter: 8 out of 15
# Epoch 13, Training Loss: 0.1568, Validation Loss: 1.0663
# Validation Metrics - Accuracy: 0.6502, Recall: 0.6885, Specificity: 0.6338, ROC AUC: 0.7117
# Confusion Matrix - TN: 90, FP: 52, FN: 19, TP: 42
# EarlyStopping counter: 9 out of 15
# Epoch 14, Training Loss: 0.1464, Validation Loss: 1.2149
# Validation Metrics - Accuracy: 0.6552, Recall: 0.7213, Specificity: 0.6268, ROC AUC: 0.7189
# Confusion Matrix - TN: 89, FP: 53, FN: 17, TP: 44
# EarlyStopping counter: 10 out of 15
# Epoch 15, Training Loss: 0.1361, Validation Loss: 1.1024
# Validation Metrics - Accuracy: 0.6995, Recall: 0.7049, Specificity: 0.6972, ROC AUC: 0.7355
# Confusion Matrix - TN: 99, FP: 43, FN: 18, TP: 43
# EarlyStopping counter: 11 out of 15
# Epoch 16, Training Loss: 0.1182, Validation Loss: 1.0783
# Validation Metrics - Accuracy: 0.6847, Recall: 0.6557, Specificity: 0.6972, ROC AUC: 0.7370
# Confusion Matrix - TN: 99, FP: 43, FN: 21, TP: 40
# EarlyStopping counter: 12 out of 15
# Epoch 17, Training Loss: 0.0962, Validation Loss: 1.1660
# Validation Metrics - Accuracy: 0.6897, Recall: 0.6721, Specificity: 0.6972, ROC AUC: 0.7312
# Confusion Matrix - TN: 99, FP: 43, FN: 20, TP: 41
# EarlyStopping counter: 13 out of 15
# Epoch 18, Training Loss: 0.1079, Validation Loss: 1.2930
#  0.18858542 0.9913555  0.9606193  0.9774006  0.98369724 0.96040547
#  0.13773212 0.08812331 0.7431084  0.9940474  0.924336   0.9973283
#  0.6853891  0.07770353 0.03689483 0.5231478  0.5917507  0.6071888
#  0.8974908  0.99417984 0.19012325 0.2437724  0.918964   0.82188815
#  0.65961885 0.03960733 0.77044696 0.14521354 0.90879333 0.9164943
#  0.08790591]
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPTNeoModel(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(2048, 768)
#         (drop): Dropout(p=0.0, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPTNeoBlock(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPTNeoAttention(
#               (attention): GPTNeoSelfAttention(
#                 (attn_dropout): Dropout(p=0.0, inplace=False)
#                 (resid_dropout): Dropout(p=0.0, inplace=False)
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=False)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPTNeoMLP(
#               (c_fc): Linear(in_features=768, out_features=3072, bias=True)
#               (c_proj): Linear(in_features=3072, out_features=768, bias=True)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6857, Validation Loss: 0.5292
# Validation Metrics - Accuracy: 0.7668, Recall: 0.4138, Specificity: 0.9185, ROC AUC: 0.7963
# Confusion Matrix - TN: 124, FP: 11, FN: 34, TP: 24
# ROC AUC improved (0.0000 --> 0.7963). Saving model ...
# Epoch 2, Training Loss: 0.5706, Validation Loss: 0.5003
# Validation Metrics - Accuracy: 0.7720, Recall: 0.7414, Specificity: 0.7852, ROC AUC: 0.8309
# Confusion Matrix - TN: 106, FP: 29, FN: 15, TP: 43
# ROC AUC improved (0.7963 --> 0.8309). Saving model ...
# Epoch 3, Training Loss: 0.5559, Validation Loss: 0.4608
# Validation Metrics - Accuracy: 0.7824, Recall: 0.5862, Specificity: 0.8667, ROC AUC: 0.8381
# Confusion Matrix - TN: 117, FP: 18, FN: 24, TP: 34
# ROC AUC improved (0.8309 --> 0.8381). Saving model ...
# Epoch 4, Training Loss: 0.4541, Validation Loss: 0.7678
# Validation Metrics - Accuracy: 0.6114, Recall: 0.8966, Specificity: 0.4889, ROC AUC: 0.8148
# Confusion Matrix - TN: 66, FP: 69, FN: 6, TP: 52
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.4351, Validation Loss: 0.5769
# Validation Metrics - Accuracy: 0.7772, Recall: 0.7759, Specificity: 0.7778, ROC AUC: 0.8261
# Confusion Matrix - TN: 105, FP: 30, FN: 13, TP: 45
# EarlyStopping counter: 2 out of 15
# Epoch 6, Training Loss: 0.3956, Validation Loss: 0.6121
# Validation Metrics - Accuracy: 0.7254, Recall: 0.8448, Specificity: 0.6741, ROC AUC: 0.8275
# Confusion Matrix - TN: 91, FP: 44, FN: 9, TP: 49
# EarlyStopping counter: 3 out of 15
# Epoch 7, Training Loss: 0.3677, Validation Loss: 0.6959
# Validation Metrics - Accuracy: 0.6839, Recall: 0.8276, Specificity: 0.6222, ROC AUC: 0.8069
# Confusion Matrix - TN: 84, FP: 51, FN: 10, TP: 48
# EarlyStopping counter: 4 out of 15
# Epoch 8, Training Loss: 0.2891, Validation Loss: 1.0722
# Validation Metrics - Accuracy: 0.5907, Recall: 0.8276, Specificity: 0.4889, ROC AUC: 0.7937
# Confusion Matrix - TN: 66, FP: 69, FN: 10, TP: 48
# EarlyStopping counter: 5 out of 15
# Epoch 9, Training Loss: 0.2671, Validation Loss: 0.8145
# Validation Metrics - Accuracy: 0.6891, Recall: 0.7759, Specificity: 0.6519, ROC AUC: 0.7990
# Confusion Matrix - TN: 88, FP: 47, FN: 13, TP: 45
# EarlyStopping counter: 6 out of 15
# Epoch 10, Training Loss: 0.2168, Validation Loss: 0.7321
# Validation Metrics - Accuracy: 0.7150, Recall: 0.7069, Specificity: 0.7185, ROC AUC: 0.7805
# Confusion Matrix - TN: 97, FP: 38, FN: 17, TP: 41
# EarlyStopping counter: 7 out of 15
# Epoch 11, Training Loss: 0.1748, Validation Loss: 0.9803
# Validation Metrics - Accuracy: 0.6580, Recall: 0.7931, Specificity: 0.6000, ROC AUC: 0.7861
# Confusion Matrix - TN: 81, FP: 54, FN: 12, TP: 46
# EarlyStopping counter: 8 out of 15
# Epoch 12, Training Loss: 0.1347, Validation Loss: 0.8397
# Validation Metrics - Accuracy: 0.7098, Recall: 0.6724, Specificity: 0.7259, ROC AUC: 0.7702
# Confusion Matrix - TN: 98, FP: 37, FN: 19, TP: 39
# EarlyStopping counter: 9 out of 15
# Epoch 13, Training Loss: 0.1173, Validation Loss: 0.9483
# Validation Metrics - Accuracy: 0.6891, Recall: 0.6897, Specificity: 0.6889, ROC AUC: 0.7665
# Confusion Matrix - TN: 93, FP: 42, FN: 18, TP: 40
# EarlyStopping counter: 10 out of 15
# Epoch 14, Training Loss: 0.0910, Validation Loss: 0.9176
# Validation Metrics - Accuracy: 0.7150, Recall: 0.6207, Specificity: 0.7556, ROC AUC: 0.7664
# Confusion Matrix - TN: 102, FP: 33, FN: 22, TP: 36
# EarlyStopping counter: 11 out of 15
# Epoch 15, Training Loss: 0.1157, Validation Loss: 1.0094
# Validation Metrics - Accuracy: 0.7047, Recall: 0.6379, Specificity: 0.7333, ROC AUC: 0.7614
# Confusion Matrix - TN: 99, FP: 36, FN: 21, TP: 37
# EarlyStopping counter: 12 out of 15
# Epoch 16, Training Loss: 0.0886, Validation Loss: 1.0384
# Validation Metrics - Accuracy: 0.7150, Recall: 0.6724, Specificity: 0.7333, ROC AUC: 0.7673
# Confusion Matrix - TN: 99, FP: 36, FN: 19, TP: 39
# EarlyStopping counter: 13 out of 15
# Epoch 17, Training Loss: 0.0834, Validation Loss: 1.1065
# Validation Metrics - Accuracy: 0.7202, Recall: 0.6897, Specificity: 0.7333, ROC AUC: 0.7692
# Confusion Matrix - TN: 99, FP: 36, FN: 18, TP: 40
# EarlyStopping counter: 14 out of 15
# Epoch 18, Training Loss: 0.0659, Validation Loss: 1.1943
# Validation Metrics - Accuracy: 0.7047, Recall: 0.7069, Specificity: 0.7037, ROC AUC: 0.7715
# Confusion Matrix - TN: 95, FP: 40, FN: 17, TP: 41
# EarlyStopping counter: 15 out of 15
# Early stopping triggered.
# The best model had a ROC AUC of: 0.8381
# Loading the best model before test...
#  Test Loss: 0.5700
# Test Metrics for Split 5 - Accuracy: 0.7322, Recall: 0.5091, Specificity: 0.8281, ROC AUC: 0.7309
# Confusion Matrix - TN: 212, FP: 44, FN: 54, TP: 56
#  0.34525278 0.8073415  0.36253753 0.13386443 0.6171604  0.61346954
#  0.30835468 0.12215386 0.15463082 0.12272329 0.13110243 0.6398492
#  0.23830841 0.08297809 0.18237579 0.9074476  0.4718941  0.08896276
#  0.95851886 0.09133047 0.1765278  0.63350654 0.31115258 0.29101476
#  0.15749277 0.14646676 0.17759852 0.7014773  0.25498024 0.36479473
#  0.43418613 0.59408617 0.70682496 0.5498257  0.5607983  0.92722344
#  0.32568142 0.78300786 0.20978883 0.83401203 0.82099116 0.61373925
#  0.11578058 0.88531804 0.13333489 0.2154994  0.16916063 0.7486405
#  0.59470415 0.45036057 0.17887913 0.22328237 0.27827978 0.6916057
#  0.34706113 0.7707946  0.07447925 0.73769695 0.3078657  0.93427795
#  0.15508278 0.5528672  0.3017556  0.44536337 0.8319672  0.7027726
#  0.28304616 0.15312548 0.17597519 0.35764444 0.13197719 0.6394548
#  0.11017826 0.16311212 0.60370725 0.5594005  0.16175982 0.6351532
#  0.1727834  0.23484093 0.6949144  0.4340689  0.15843283 0.26557073
#  0.4589839  0.18647721 0.17827052 0.17045827 0.8109139  0.5829074
#  0.23126289 0.36195496 0.13187101 0.18934286 0.1208673  0.3710252
#  0.1793351  0.22315098 0.40589455 0.88472813 0.56763196 0.14560728
#  0.16242492 0.25372103 0.19289838 0.3481451  0.13120621 0.3121946
#  0.9090415  0.36754057 0.2076035  0.35703072 0.1327472  0.1515116
#  0.3877395  0.5017333  0.8878989  0.53500706 0.09635203 0.03962899]

# %% [markdown]
# ### RESULTS (PERFORMANCE)

# %% [markdown]
# #### Step 1. Load model and best results

# %%
directory = './Results_FewNeo'

def load_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

y_pred_by_split = {}
y_pred_by_split['1'] = load_from_pickle(os.path.join('./Results_FewNeo/split_1', "y_pred_split_1.pkl"))
y_pred_by_split['2'] = load_from_pickle(os.path.join('./Results_FewNeo/split_2', "y_pred_split_2.pkl"))
y_pred_by_split['3'] = load_from_pickle(os.path.join('./Results_FewNeo/split_3', "y_pred_split_3.pkl"))
y_pred_by_split['4'] = load_from_pickle(os.path.join('./Results_FewNeo/split_4', "y_pred_split_4.pkl"))
y_pred_by_split['5'] = load_from_pickle(os.path.join('./Results_FewNeo/split_5', "y_pred_split_5.pkl"))

# %% [markdown]
# #### Step 2. Analysis of results

# %%
all_metrics = []

for i in [2,4,5]: 
    y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    y_test_single = y_test.flatten()  
    y_test_pred = y_pred_by_split[str(i)].flatten()  
    
    df_metrics = utils.get_metrics_(y_test_single, (y_test_pred))
    print(df_metrics)
    utils.plot_metrics(df_metrics)
    utils.plot_roc_curve(y_test_single, y_test_pred)

    all_metrics.append(df_metrics)
print(all_metrics)
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  202  68  43  73  0.712435      0.62931     0.748148  0.731481  0.568093
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  185  76  44  68  0.678284     0.607143     0.708812  0.731117   0.53125
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  212  44  54  56   0.73224     0.509091     0.828125  0.730895  0.533333
# [    TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  202  68  43  73  0.712435      0.62931     0.748148  0.731481  0.568093,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  185  76  44  68  0.678284     0.607143     0.708812  0.731117   0.53125,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  212  44  54  56   0.73224     0.509091     0.828125  0.730895  0.533333]

# %%
metrics_FewNeo = pd.concat(all_metrics)
metrics_FewNeo.to_csv('./Results_FewNeo/metrics_FewNeo.csv', index=False)

metrics_FewNeo.head()
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  202  68  43  73  0.712435     0.629310     0.748148  0.731481  0.568093
# 0  185  76  44  68  0.678284     0.607143     0.708812  0.731117  0.531250
# 0  212  44  54  56  0.732240     0.509091     0.828125  0.730895  0.533333

# %%
metrics_mean = metrics_FewNeo.mean()
metrics_std = metrics_FewNeo.std()

summary_df = pd.DataFrame({
    "Metric": metrics_mean.index,
    "Mean": metrics_mean.values,
    "Standard Deviation": metrics_std.values
})

summary_df.to_csv('./Results_FewNeo/metrics_summary_FewNeo.csv', index=False)

print("\nMean and Standard Deviation of the Splits:")
print(summary_df)
# Out:
# Mean and Standard Deviation of the Splits:
#         Metric        Mean  Standard Deviation
# 0           TN  199.666667           13.650397
# 1           FP   62.666667           16.653328
# 2           FN   47.000000            6.082763
# 3           TP   65.666667            8.736895
# 4     Accuracy    0.707653            0.027294
# 5  Sensitivity    0.581848            0.063977
# 6  Specificity    0.761695            0.060799
# 7      ROC AUC    0.731164            0.000296
# 8     F1 Score    0.544226            0.020696

# %%
metrics_FewNeo = pd.read_csv('./Results_FewNeo/metrics_FewNeo.csv')

stats_Neo = metrics_FewNeo.agg(["mean", "std"]) 
formatted_metrics = stats_Neo.apply(lambda x: f"{x['mean']*100:.2f} ± {x['std']*100:.2f}", axis=0)
formatted_metrics_df = pd.DataFrame(formatted_metrics, columns=["Metrics (Mean ± Std)"])
formatted_metrics_df.to_csv('./Results_FewNeo/metrics_FewNeo_formatted.csv', index=True)
print(formatted_metrics_df)
# Out:
#             Metrics (Mean ± Std)
# TN            19966.67 ± 1365.04
# FP             6266.67 ± 1665.33
# FN              4700.00 ± 608.28
# TP              6566.67 ± 873.69
# Accuracy            70.77 ± 2.73
# Sensitivity         58.18 ± 6.40
# Specificity         76.17 ± 6.08
# ROC AUC             73.12 ± 0.03
# F1 Score            54.42 ± 2.07

# %% [markdown]
# ### SHAP

# %%
import shap

model_path = "/home/lcarmona/Modelos_finales/final_models/SHAP_bueno/LLM-Few4/checkpointNeo.pt"
if os.path.exists(model_path):
    configs = Configs()
    model = LLMFew(configs).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    print("Model loaded")
else:
    raise FileNotFoundError(f"Model not found in {model_path}")

feature_names = [
    'AMG', 'ATF', 'ATI', 'ATP', 'CAR', 'CF1', 'CF2', 'CF3', 'CF4', 'Falta', 
    'GCC', 'GLI', 'LIN', 'LIP', 'MAC', 'MON', 'NTI', 
    'OTR', 'OXA', 'PAP', 'PEN', 'POL', 'QUI', 
    'SUL', 'TTC', 'hoursVM', 'acinet.$_{pc}$', 'enterobac.$_{pc}$', 'enteroc.$_{pc}$',
    'pseud.$_{pc}$', 'staph.$_{pc}$', 'others.$_{pc}$', 'hoursICU', '# pat_atb', '# pat_MR', 
    'CAR.$_{n}$', 'PAP.$_{n}$', 'Falta.$_{n}$', 'QUI.$_{n}$', 
    'ATF.$_{n}$', 'OXA.$_{n}$', 'PEN.$_{n}$', 'CF3.$_{n}$', 
    'GLI.$_{n}$', 'CF4.$_{n}$', 'SUL.$_{n}$', 'NTI.$_{n}$', 
    'LIN.$_{n}$', 'AMG.$_{n}$', 'MAC.$_{n}$', 'CF1.$_{n}$', 'GCC.$_{n}$', 
    'POL.$_{n}$', 'ATI.$_{n}$', 'MON.$_{n}$', 'LIP.$_{n}$', 'TTC.$_{n}$', 
    'OTR.$_{n}$', 'CF2.$_{n}$', 'ATP.$_{n}$', '# pat_ttl', 'posture.$_{change}$', 
    'insulin', 'nutr_art', 'sedation', 'relax', 'hep_fail', 'renal_fail', 
    'coag_fail', 'hemo_fail', 'resp_fail', 'multi_fail', 'n_transf', 
    'vasoactive.$_{drug}$', 'dosis_nems', 'hoursTracheo', 'hoursUlcer', 
    'hoursHemo', 'C01 PIVC 1', 'C01 PIVC 2', 'C02 CVC - YD', 'C02 CVC - SD', 
    'C02 CVC - SI', 'C02 CVC - FD', 'C02 CVC - YI', 'C02 CVC - FI', '# catheters'
]

all_shap_values = []
all_inputs = []

class WrappedModel(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        return self.model(x)

wrapped_model = WrappedModel(model)

for i in [1, 2, 3, 4, 5]:
    print(f"Processing split {i}...")
    X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_test_tensor_standardScaler.npy")
    X_test_tensor = torch.tensor(np.where(X_test == 666, 0, X_test), dtype=torch.float32).to(device)

    background = X_test_tensor[np.random.choice(X_test_tensor.shape[0], 100, replace=False)]

    explainer = shap.GradientExplainer(wrapped_model, background)
    shap_values = explainer.shap_values(X_test_tensor)

    all_shap_values.append(shap_values)
    all_inputs.append(X_test_tensor.cpu().numpy())

all_shap_concat = np.concatenate(all_shap_values, axis=0)
all_inputs_concat = np.concatenate(all_inputs, axis=0)

if all_shap_concat.ndim == 3:
    shap_values_avg = all_shap_concat.mean(axis=1)
    X_test_avg = all_inputs_concat.mean(axis=1)
else:
    shap_values_avg = all_shap_concat
    X_test_avg = all_inputs_concat

plt.figure(figsize=(12, 8))
shap.summary_plot(
    shap_values_avg,
    X_test_avg,
    feature_names=feature_names,
    max_display=30,
    show=False
)

plt.xticks(rotation=45, fontsize=18) 
plt.yticks(fontsize=19)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=20)
cbar.set_ylabel("Feature value", fontsize=20)

plt.tight_layout()
plt.savefig("shap_summary_llmfewNeo.png", dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Model loaded
# Processing split 1...
# Processing split 2...
# Processing split 3...
# Processing split 4...
# Processing split 5...

# %%
plt.figure(figsize=(12, 8))
shap_values_exp = shap.Explanation(
    values=shap_values_avg,
    data=X_test_avg,
    feature_names=feature_names
)

shap.plots.heatmap(shap_values_exp, show=False)

plt.xticks(fontsize=21, rotation=45)
plt.yticks(fontsize=21)
plt.xlabel("Instances", fontsize=20)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=19)
cbar.set_ylabel("SHAP value (impact on model output)", fontsize=17)

plt.savefig("shap_heatmap_lllmfewNeo.png", dpi=300, bbox_inches='tight')
plt.close()

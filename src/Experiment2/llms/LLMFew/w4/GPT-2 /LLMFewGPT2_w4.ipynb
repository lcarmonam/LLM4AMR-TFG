# %%
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

import sklearn
from sklearn import metrics

import random, os, json
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import sys
sys.path.append("../")
import utils

from joblib import Parallel, delayed
import multiprocessing

import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader, TensorDataset

from torch.optim import Adam
from torch.nn import BCELoss
import numpy as np
import argparse
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, confusion_matrix

from CasualCNN import CausalCNNEncoder
from Embed import PatchEmbedding
from sklearn.utils import resample
from LLMprepare import LLMprepare

device = torch.device('cuda:0')
# Out:
# 2025-04-21 17:20:17.396726: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-21 17:20:17.445271: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-21 17:20:18.299676: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def calculate_metrics(y_true, y_pred_probs):
    y_pred = np.round(y_pred_probs).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    accuracy = accuracy_score(y_true, y_pred)
    sensitivity = recall_score(y_true, y_pred) 
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0 
    roc_auc = roc_auc_score(y_true, y_pred_probs)
    f1 = f1_score(y_true, y_pred)  

    return accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp

# %% [markdown]
# ### HYPERPARAMETERS

# %% [markdown]
# - **seeds**: Seed values to ensure reproducibility.
# - **batch_size**: Number of samples per batch used during training.
# - **dropout**: Dropout rate applied to prevent overfitting.
# - **weight_decay**: Weight decay for the optimizer to apply additional L2 regularization.
# - **lr**: Learning rate assigned to the optimizer.
# - **patience**: Number of epochs with no improvement before early stopping is triggered.
# - **dimensions**: Number of features in each time step of the input data.
# - **length**: Number of time steps in the input sequence.
# - **num_class**: Number of output classes for the prediction task.
# - **patch_len**: Length of each patch created from the input sequence.
# - **stride**: Step size used when unfolding the sequence into patches.
# - **llm_type**: Type of large language model used as a backbone.

# %%
class Configs:
    def __init__(self):
        self.dimensions = 87
        self.length = 4
        self.num_class = 1  
        self.depth = 2
        self.channels = 128
        self.reduced_size = 64
        self.kernel_size = 3
        self.patch_len = 2
        self.stride = 1
        self.dropout = 0.1
        self.batch_size = 4
        self.epochs = 100
        self.lr = 0.0005
        self.llm_type = "gpt2"
        self.lora = 1
        
seeds = [9, 76, 227, 12, 18, 45]
batch_size = 4
n_epochs_max = 100
configs = Configs() 
monitor = "val_auc"

hyperparameters = {
    "lr": configs.lr,
    "batch_size": batch_size,          
    "n_epochs_max": n_epochs_max,                
    "weight_decay": 5e-4, 
    "dropout": configs.dropout,
    "patience": 15,
}

# %% [markdown]
# ### FUNCTIONS OF THE MODEL

# %%
class LLMFew(nn.Module):
    def __init__(self, configs):
        super(LLMFew, self).__init__()
        self.configs = configs
        self.num_class = configs.num_class
        self.length = configs.length
        self.dimensions = configs.dimensions
        self.llm_type = configs.llm_type
        self.lora = configs.lora
        self.patch_len = configs.patch_len
        self.stride = configs.stride
        self.llm_model, self.d_model = LLMprepare(configs)
        self.patch_embedding = PatchEmbedding(
            self.d_model, self.patch_len, self.stride, configs.dropout) 
        self.patch_nums = int((self.length - self.patch_len) / self.stride + 2)
        self.padding_patch_layer = nn.ReplicationPad1d((0, self.stride if self.patch_len < self.length else 0))
        self.encoder = CausalCNNEncoder(in_channels=self.dimensions, channels=configs.channels, depth=configs.depth,
                                        reduced_size=configs.reduced_size, out_channels=self.d_model,
                                        kernel_size=configs.kernel_size)
        self.dropout = nn.Dropout(configs.dropout)
        self.relu = nn.LeakyReLU()
        self.act = F.relu
        self.ln_proj = nn.LayerNorm(self.d_model * self.patch_nums).to(torch.bfloat16)
        self.mapping = nn.Sequential(nn.Linear(self.d_model * self.patch_nums, self.num_class),
                                     nn.Dropout(configs.dropout))
        self.activation = nn.Sigmoid()

    def forward(self, x):
        # x: batch, dim(dimensions), seq(length)
        x = x.contiguous()
        B, L, M = x.shape
        x = x.permute(0, 2, 1)  # (B, M, L)
        input_x = self.padding_patch_layer(x)  
        input_x = input_x.unfold(dimension=-1, size=self.patch_len, step=self.stride)
        input_x = rearrange(input_x, 'b m n p-> (b n) m p')
        output_x = self.encoder(input_x)
        output_x = self.dropout(output_x)
        output_x = rearrange(output_x, '(b n) o-> b n o', b=B)
        output_x = output_x.to(torch.bfloat16)
        
        llm_out = self.llm_model(inputs_embeds=output_x.contiguous()).last_hidden_state
        outputs = self.relu(llm_out + output_x).reshape(B, -1)
        outputs = self.ln_proj(outputs)
        outputs = outputs.to(torch.float32)
        outputs = self.mapping(outputs)
        outputs = self.activation(outputs)
        
        return outputs

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.001, verbose=False):
    """
    Early stops the training if validation ROC AUC does not improve after a given patience.

    Args:
        - patience: Number of epochs to wait for an improvement before stopping the training. 
        - delta: Minimum change in the monitored metric to qualify as an improvement.
        - verbose: If True, prints detailed messages each time the model improves and when early stopping is triggered.
    """
        self.patience = patience
        self.delta = delta
        self.verbose = verbose
        self.counter = 0
        self.best_roc_auc = None  
        self.early_stop = False

    def __call__(self, roc_auc, model):
        if self.best_roc_auc is None or roc_auc > self.best_roc_auc + self.delta:
            self.save_checkpoint(roc_auc, model)
            self.best_roc_auc = roc_auc
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True

    def save_checkpoint(self, roc_auc, model):
        if self.verbose:
            print(f"ROC AUC improved ({self.best_roc_auc if self.best_roc_auc is not None else 0:.4f} --> {roc_auc:.4f}). Saving model ...")
        torch.save(model.state_dict(), 'checkpointGPT2.pt')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False 
    
def run_network(X_train, X_val, y_train, y_val, hyperparameters, seed, configs): 
    """
    Trains and evaluates the built model based on the provided data and hyperparameters.

    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.
        - configs: Configuration object with model settings.

    Returns:
        - model: The trained PyTorch model.
        - history: Training history object containing loss and metrics.
    """ 
    device = torch.device('cuda:0')
    batch_size=hyperparameters['batch_size']
    
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device).unsqueeze(1)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device).unsqueeze(1)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    set_seed(seed)
    
    configs = Configs()
    model = LLMFew(configs).to(device)
    print(model)
    
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=hyperparameters['lr'], weight_decay=hyperparameters['weight_decay'])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

    train_loss_history = []
    val_loss_history = []
    val_auc_history = [] 
    early_stopping = EarlyStopping(patience=hyperparameters['patience'], delta=0.001, verbose=True)


    for epoch in range(hyperparameters['n_epochs_max']):
        model.train()
        train_loss = 0.0
        
        for batch_x, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_loss_history.append(train_loss)

        model.eval()
        val_loss = 0.0
        y_val_preds = []
        y_val_true = []
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()

                y_val_preds.extend(outputs.cpu().numpy().flatten())
                y_val_true.extend(batch_y.cpu().numpy().flatten())
        
        val_loss /= len(val_loader)
        val_loss_history.append(val_loss)

        y_val_preds = np.array(y_val_preds)
        y_val_true = np.array(y_val_true)
        accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp = calculate_metrics(y_val_true, y_val_preds)
        
        val_auc_history.append(roc_auc)
        scheduler.step(val_loss)
        
        print(f"Epoch {epoch + 1}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"Validation Metrics - Accuracy: {accuracy:.4f}, f1: {f1:.4f}, sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f} ")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        early_stopping(roc_auc, model)
        if early_stopping.early_stop:
            print("Early stopping.")
            break
    
    model.load_state_dict(torch.load('checkpointGPT2.pt'))

    history = {'loss': train_loss_history, 'val_loss': val_loss_history,
        'val_auc': val_auc_history}
    return model, history

# %%
def objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs):
    """
    Objective function for hyperparameter optimization using Optuna.
    Args:
        - trial (optuna.trial.Trial): Optuna trial object.
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
        - configs: Configuration object with model settings.        
   
    Returns:
        - metric_dev: Best validation AUC achieved during training.     
    """
    trial_seed = seed + trial.number  
    set_seed(trial_seed)

    hyperparameters_copy = hyperparameters.copy()

    hyperparameters_copy['lr'] = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    hyperparameters_copy['weight_decay'] = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    hyperparameters_copy['dropout'] = trial.suggest_float("dropout", 0.0, 0.3)
    hyperparameters_copy['patience'] = trial.suggest_int("patience", 3, 20)

    v_val_auc = [] 
    
    configs = Configs()
    
    model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters_copy,
            trial_seed, 
            configs
        )

    v_val_auc.append(max(history['val_auc']))
    metric_dev = np.mean(v_val_auc)

    return metric_dev

def optuna_study(hyperparameters, seed, X_train, y_train, X_val, y_val):
    """
    Runs an Optuna study to optimize hyperparameters for the model.
    
    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
    Returns:
        - best_hyperparameters: Dictionary containing the best hyperparameters found 
          after the optimization process.
    """
    
    set_seed(seed)

    sampler = optuna.samplers.TPESampler(seed=seed)
    study = optuna.create_study(direction='maximize', sampler=sampler)

    study.optimize(
        lambda trial: objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs),
        n_trials=20,  
        n_jobs=1      
    )

    best_params = study.best_params
    best_metric = study.best_value
    
    best_hyperparameters = {
        'lr': best_params['lr'], 
        'weight_decay': best_params['weight_decay'], 
        'dropout': best_params['dropout'],  
        'patience': best_params['patience'],  
    }

    print(f"Best Hyperparameters: {best_params}")
    print(f"Best Validation Metric: {best_metric}")

    return best_hyperparameters

# %% [markdown]
# ### PREDICTIONS

# %%
import time
import os
import pickle
import torch
import numpy as np
import pandas as pd


run_model = True
results = []
if run_model:
    loss_train = []
    loss_dev = []
    v_models = []

    y_pred_by_split = {}
    bestHyperparameters_bySplit = {}
        
    for i in [1,2,3,4,5]:
        init = time.time()
        
        X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_test_tensor_standardScaler.npy")
        y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_train_tensor_standardScaler.npy")
        y_train = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_train_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    
        X_val = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_val_tensor_standardScaler.npy")
        y_val = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_val_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.where(X_train == 666, 0, X_train)
        X_val = np.where(X_val == 666, 0, X_val)
        X_test = np.where(X_test == 666, 0, X_test)
    

        X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device).unsqueeze(1)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        bestHyperparameters = optuna_study(
            hyperparameters,
            seeds[i-1],
            X_train, y_train,  
            X_val, y_val
        )

        bestHyperparameters_bySplit[str(i)] = bestHyperparameters
        
        split_directory = f'./Results_FewPGT2/split_{i}'
        if not os.path.exists(split_directory):
            os.makedirs(split_directory)

        with open(os.path.join(split_directory, f"bestHyperparameters_split_{i}.pkl"), 'wb') as f:
            pickle.dump(bestHyperparameters, f)

        hyperparameters.update({
            'lr': bestHyperparameters['lr'], 
            'weight_decay': bestHyperparameters['weight_decay'],
            'dropout': bestHyperparameters['dropout'], 
            'patience': bestHyperparameters['patience']
        })        

        
        configs = Configs()
        criterion = nn.BCELoss()
        
        model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters,
            seeds[i-1], 
            configs
        )

        v_models.append(model)
        loss_train.append(history['loss'])
        loss_dev.append(history['val_loss'])

        y_pred = []
        y_true = []
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                test_loss += loss.item()
                
                y_pred.extend(outputs.cpu().numpy().flatten())
                y_true.extend(batch_y.cpu().numpy().flatten())
        
        test_loss /= len(test_loader)
        y_pred = np.array(y_pred)  
        y_true = np.array(y_true)
        
        accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp = calculate_metrics(y_true, y_pred)
    
        print(f" Test Loss: {test_loss:.4f}")
        print(f"Test Metrics for Split {i} -Accuracy: {accuracy:.4f}, f1: {f1:.4f}, sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        results.append([accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp])

        y_pred_by_split[str(i)] = y_pred
        print(f"for split {i}:")
        print(y_pred_by_split[str(i)])

        y_pred_path = os.path.join(split_directory, f"y_pred_split_{i}.pkl")
        with open(y_pred_path, 'wb') as f:
            pickle.dump(y_pred, f)   
    
    directory = './Results_FewPGT2'
    if not os.path.exists(directory):
        os.makedirs(directory)

    def save_to_pickle(data, filename):
        with open(filename, 'wb') as f:
            pickle.dump(data, f)

    save_to_pickle(y_pred_by_split, os.path.join(directory, "y_pred_by_split.pkl"))
    save_to_pickle(loss_train, os.path.join(directory, "loss_train.pkl"))
    save_to_pickle(loss_dev, os.path.join(directory, "loss_dev.pkl"))
    save_to_pickle(bestHyperparameters_bySplit, os.path.join(directory, "bestHyperparameters_bySplit.pkl"))
# Out:
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6743, Validation Loss: 0.7693
# Validation Metrics - Accuracy: 0.5959, f1: 0.5714, sensitivity: 0.8966, Specificity: 0.4667, ROC AUC: 0.7670
# Confusion Matrix - TN: 63, FP: 72, FN: 6, TP: 52
# ROC AUC improved (0.0000 --> 0.7670). Saving model ...
# Epoch 2, Training Loss: 0.5276, Validation Loss: 0.5029
# Validation Metrics - Accuracy: 0.7720, f1: 0.5849, sensitivity: 0.5345, Specificity: 0.8741, ROC AUC: 0.7792
# Confusion Matrix - TN: 118, FP: 17, FN: 27, TP: 31
# ROC AUC improved (0.7670 --> 0.7792). Saving model ...
# Epoch 3, Training Loss: 0.4295, Validation Loss: 0.7485
# Validation Metrics - Accuracy: 0.6995, f1: 0.6081, sensitivity: 0.7759, Specificity: 0.6667, ROC AUC: 0.7695
# Confusion Matrix - TN: 90, FP: 45, FN: 13, TP: 45
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.3264, Validation Loss: 0.9241
# Validation Metrics - Accuracy: 0.6218, f1: 0.5466, sensitivity: 0.7586, Specificity: 0.5630, ROC AUC: 0.7450
# Confusion Matrix - TN: 76, FP: 59, FN: 14, TP: 44
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.2673, Validation Loss: 0.8703
# Validation Metrics - Accuracy: 0.6580, f1: 0.5769, sensitivity: 0.7759, Specificity: 0.6074, ROC AUC: 0.7805
# Confusion Matrix - TN: 82, FP: 53, FN: 13, TP: 45
# ROC AUC improved (0.7792 --> 0.7805). Saving model ...
# Epoch 6, Training Loss: 0.1521, Validation Loss: 0.9446
# Validation Metrics - Accuracy: 0.7461, f1: 0.6080, sensitivity: 0.6552, Specificity: 0.7852, ROC AUC: 0.7701
# Confusion Matrix - TN: 106, FP: 29, FN: 20, TP: 38
# EarlyStopping counter: 1 out of 15
# Epoch 7, Training Loss: 0.1115, Validation Loss: 1.1637
# Validation Metrics - Accuracy: 0.7047, f1: 0.5957, sensitivity: 0.7241, Specificity: 0.6963, ROC AUC: 0.7723
# Confusion Matrix - TN: 94, FP: 41, FN: 16, TP: 42
# EarlyStopping counter: 2 out of 15
# Epoch 8, Training Loss: 0.0823, Validation Loss: 1.2345
# Validation Metrics - Accuracy: 0.6891, f1: 0.5833, sensitivity: 0.7241, Specificity: 0.6741, ROC AUC: 0.7695
# Confusion Matrix - TN: 91, FP: 44, FN: 16, TP: 42
# EarlyStopping counter: 3 out of 15
# Epoch 9, Training Loss: 0.0694, Validation Loss: 1.2864
# Validation Metrics - Accuracy: 0.6943, f1: 0.5816, sensitivity: 0.7069, Specificity: 0.6889, ROC AUC: 0.7701
# Confusion Matrix - TN: 93, FP: 42, FN: 17, TP: 41
# EarlyStopping counter: 4 out of 15
# Epoch 10, Training Loss: 0.0947, Validation Loss: 1.3820
# Validation Metrics - Accuracy: 0.6736, f1: 0.5714, sensitivity: 0.7241, Specificity: 0.6519, ROC AUC: 0.7696
# Confusion Matrix - TN: 88, FP: 47, FN: 16, TP: 42
# EarlyStopping counter: 5 out of 15
# Epoch 11, Training Loss: 0.0559, Validation Loss: 1.3686
# Validation Metrics - Accuracy: 0.6839, f1: 0.5734, sensitivity: 0.7069, Specificity: 0.6741, ROC AUC: 0.7699
# Confusion Matrix - TN: 91, FP: 44, FN: 17, TP: 41
# EarlyStopping counter: 6 out of 15
# Epoch 12, Training Loss: 0.0796, Validation Loss: 1.3783
# Validation Metrics - Accuracy: 0.6891, f1: 0.5775, sensitivity: 0.7069, Specificity: 0.6815, ROC AUC: 0.7696
# Confusion Matrix - TN: 92, FP: 43, FN: 17, TP: 41
# EarlyStopping counter: 7 out of 15
# Epoch 13, Training Loss: 0.0712, Validation Loss: 1.4100
# Validation Metrics - Accuracy: 0.6788, f1: 0.5694, sensitivity: 0.7069, Specificity: 0.6667, ROC AUC: 0.7692
# Confusion Matrix - TN: 90, FP: 45, FN: 17, TP: 41
# EarlyStopping counter: 8 out of 15
# Epoch 14, Training Loss: 0.0678, Validation Loss: 1.4358
# Validation Metrics - Accuracy: 0.6891, f1: 0.5775, sensitivity: 0.7069, Specificity: 0.6815, ROC AUC: 0.7686
# Confusion Matrix - TN: 92, FP: 43, FN: 17, TP: 41
# EarlyStopping counter: 9 out of 15
# Epoch 15, Training Loss: 0.0792, Validation Loss: 1.4522
# Validation Metrics - Accuracy: 0.6891, f1: 0.5775, sensitivity: 0.7069, Specificity: 0.6815, ROC AUC: 0.7675
# Confusion Matrix - TN: 92, FP: 43, FN: 17, TP: 41
# EarlyStopping counter: 10 out of 15
# Epoch 16, Training Loss: 0.0544, Validation Loss: 1.4639
# Validation Metrics - Accuracy: 0.6839, f1: 0.5734, sensitivity: 0.7069, Specificity: 0.6741, ROC AUC: 0.7683
# Confusion Matrix - TN: 91, FP: 44, FN: 17, TP: 41
# EarlyStopping counter: 11 out of 15
# Epoch 17, Training Loss: 0.0802, Validation Loss: 1.4693
# Validation Metrics - Accuracy: 0.6891, f1: 0.5775, sensitivity: 0.7069, Specificity: 0.6815, ROC AUC: 0.7683
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6854, Validation Loss: 0.5464
# Validation Metrics - Accuracy: 0.7423, f1: 0.5116, sensitivity: 0.4490, Specificity: 0.8684, ROC AUC: 0.7508
# Confusion Matrix - TN: 99, FP: 15, FN: 27, TP: 22
# ROC AUC improved (0.0000 --> 0.7508). Saving model ...
# Epoch 2, Training Loss: 0.5846, Validation Loss: 0.5329
# Validation Metrics - Accuracy: 0.7423, f1: 0.5882, sensitivity: 0.6122, Specificity: 0.7982, ROC AUC: 0.7900
# Confusion Matrix - TN: 91, FP: 23, FN: 19, TP: 30
# ROC AUC improved (0.7508 --> 0.7900). Saving model ...
# Epoch 3, Training Loss: 0.5247, Validation Loss: 0.7098
# Validation Metrics - Accuracy: 0.6442, f1: 0.5972, sensitivity: 0.8776, Specificity: 0.5439, ROC AUC: 0.7898
# Confusion Matrix - TN: 62, FP: 52, FN: 6, TP: 43
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.4423, Validation Loss: 0.8626
# Validation Metrics - Accuracy: 0.6074, f1: 0.5294, sensitivity: 0.7347, Specificity: 0.5526, ROC AUC: 0.7580
# Confusion Matrix - TN: 63, FP: 51, FN: 13, TP: 36
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.4136, Validation Loss: 0.7549
# Validation Metrics - Accuracy: 0.6626, f1: 0.5926, sensitivity: 0.8163, Specificity: 0.5965, ROC AUC: 0.7402
# Confusion Matrix - TN: 68, FP: 46, FN: 9, TP: 40
# EarlyStopping counter: 3 out of 15
# Epoch 6, Training Loss: 0.2982, Validation Loss: 0.8905
# Validation Metrics - Accuracy: 0.6258, f1: 0.5271, sensitivity: 0.6939, Specificity: 0.5965, ROC AUC: 0.7465
# Confusion Matrix - TN: 68, FP: 46, FN: 15, TP: 34
# EarlyStopping counter: 4 out of 15
# Epoch 7, Training Loss: 0.2201, Validation Loss: 0.8169
# Validation Metrics - Accuracy: 0.6748, f1: 0.5620, sensitivity: 0.6939, Specificity: 0.6667, ROC AUC: 0.7338
# Confusion Matrix - TN: 76, FP: 38, FN: 15, TP: 34
# EarlyStopping counter: 5 out of 15
# Epoch 8, Training Loss: 0.1560, Validation Loss: 0.9372
# Validation Metrics - Accuracy: 0.6810, f1: 0.5593, sensitivity: 0.6735, Specificity: 0.6842, ROC AUC: 0.7413
# Confusion Matrix - TN: 78, FP: 36, FN: 16, TP: 33
# EarlyStopping counter: 6 out of 15
# Epoch 9, Training Loss: 0.1024, Validation Loss: 1.0286
# Validation Metrics - Accuracy: 0.6810, f1: 0.5593, sensitivity: 0.6735, Specificity: 0.6842, ROC AUC: 0.7478
# Confusion Matrix - TN: 78, FP: 36, FN: 16, TP: 33
# EarlyStopping counter: 7 out of 15
#  0.3741345  0.87182695 0.75043833 0.15881315 0.6407087  0.75225127
#  0.69801027 0.35640198 0.666733   0.54196376 0.8224681  0.1763763
#  0.19582096 0.95460904 0.33549708 0.5756328  0.8940383  0.05725901
#  0.5270186  0.3665034  0.8958406  0.93298656 0.1867738  0.27321604
#  0.21907862 0.20264283 0.26854774 0.30855367 0.48575804 0.49977216
#  0.35452732 0.5032967  0.38700017 0.7063185  0.15657534 0.4230239
#  0.72816193 0.74412113 0.67284185 0.27464855 0.6138182  0.36868984
#  0.08993038 0.70129216 0.07836126 0.6681735  0.15435399 0.16434976
#  0.28399113 0.33066627 0.39121795 0.91040945 0.75995564 0.15106028
#  0.41175476 0.8952206  0.7192994  0.8768935  0.30010316 0.6554792
#  0.2867523  0.25943407 0.3559524  0.21686776 0.28457406 0.07080068
#  0.44841233 0.20598651 0.20509796 0.790536   0.8670854  0.2724321
#  0.26464927 0.08185315 0.1939258  0.5490523  0.6391831  0.542907
#  0.6949171  0.13803492 0.3880565  0.9852969  0.5049046  0.4527978
#  0.70423657 0.21261115 0.29581222 0.4779511  0.7744149  0.832206
#  0.32780996 0.81879324 0.41791546 0.8593172  0.33331418 0.47613016
#  0.9661686  0.55155057 0.3524503  0.37047005 0.64061093 0.90528715
#  0.7596935  0.94083554 0.36226583 0.33559015 0.75444543 0.34939837
#  0.34479973 0.12672237]
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6990, Validation Loss: 0.5499
# Validation Metrics - Accuracy: 0.7734, f1: 0.4103, sensitivity: 0.2623, Specificity: 0.9930, ROC AUC: 0.7065
# Confusion Matrix - TN: 141, FP: 1, FN: 45, TP: 16
# ROC AUC improved (0.0000 --> 0.7065). Saving model ...
# Epoch 2, Training Loss: 0.5996, Validation Loss: 0.6253
# Validation Metrics - Accuracy: 0.6847, f1: 0.5733, sensitivity: 0.7049, Specificity: 0.6761, ROC AUC: 0.7671
# Confusion Matrix - TN: 96, FP: 46, FN: 18, TP: 43
# ROC AUC improved (0.7065 --> 0.7671). Saving model ...
# Epoch 3, Training Loss: 0.5514, Validation Loss: 0.6451
# Validation Metrics - Accuracy: 0.6650, f1: 0.5072, sensitivity: 0.5738, Specificity: 0.7042, ROC AUC: 0.6679
# Confusion Matrix - TN: 100, FP: 42, FN: 26, TP: 35
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.4740, Validation Loss: 0.7682
# Validation Metrics - Accuracy: 0.6108, f1: 0.5153, sensitivity: 0.6885, Specificity: 0.5775, ROC AUC: 0.7207
# Confusion Matrix - TN: 82, FP: 60, FN: 19, TP: 42
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.3525, Validation Loss: 0.7235
# Validation Metrics - Accuracy: 0.6601, f1: 0.4964, sensitivity: 0.5574, Specificity: 0.7042, ROC AUC: 0.6855
# Confusion Matrix - TN: 100, FP: 42, FN: 27, TP: 34
# EarlyStopping counter: 3 out of 15
# Epoch 6, Training Loss: 0.2423, Validation Loss: 0.7960
# Validation Metrics - Accuracy: 0.6749, f1: 0.5147, sensitivity: 0.5738, Specificity: 0.7183, ROC AUC: 0.6996
# Confusion Matrix - TN: 102, FP: 40, FN: 26, TP: 35
# EarlyStopping counter: 4 out of 15
# Epoch 7, Training Loss: 0.1570, Validation Loss: 0.8808
# Validation Metrics - Accuracy: 0.6798, f1: 0.5517, sensitivity: 0.6557, Specificity: 0.6901, ROC AUC: 0.7165
# Confusion Matrix - TN: 98, FP: 44, FN: 21, TP: 40
# EarlyStopping counter: 5 out of 15
# Epoch 8, Training Loss: 0.1150, Validation Loss: 1.0479
# Validation Metrics - Accuracy: 0.6502, f1: 0.5298, sensitivity: 0.6557, Specificity: 0.6479, ROC AUC: 0.6989
# Confusion Matrix - TN: 92, FP: 50, FN: 21, TP: 40
# EarlyStopping counter: 6 out of 15
# Epoch 9, Training Loss: 0.1116, Validation Loss: 1.2071
# Validation Metrics - Accuracy: 0.6453, f1: 0.5325, sensitivity: 0.6721, Specificity: 0.6338, ROC AUC: 0.6956
# Confusion Matrix - TN: 90, FP: 52, FN: 20, TP: 41
# EarlyStopping counter: 7 out of 15
# Epoch 10, Training Loss: 0.0925, Validation Loss: 1.2040
# Validation Metrics - Accuracy: 0.6749, f1: 0.5479, sensitivity: 0.6557, Specificity: 0.6831, ROC AUC: 0.6994
# Confusion Matrix - TN: 97, FP: 45, FN: 21, TP: 40
# EarlyStopping counter: 8 out of 15
# Epoch 11, Training Loss: 0.0798, Validation Loss: 1.2636
# Validation Metrics - Accuracy: 0.6749, f1: 0.5479, sensitivity: 0.6557, Specificity: 0.6831, ROC AUC: 0.6989
# Confusion Matrix - TN: 97, FP: 45, FN: 21, TP: 40
# EarlyStopping counter: 9 out of 15
# Epoch 12, Training Loss: 0.0759, Validation Loss: 1.3491
# Validation Metrics - Accuracy: 0.6700, f1: 0.5563, sensitivity: 0.6885, Specificity: 0.6620, ROC AUC: 0.7003
# Confusion Matrix - TN: 94, FP: 48, FN: 19, TP: 42
# EarlyStopping counter: 10 out of 15
# Epoch 13, Training Loss: 0.0851, Validation Loss: 1.3691
# Validation Metrics - Accuracy: 0.6650, f1: 0.5405, sensitivity: 0.6557, Specificity: 0.6690, ROC AUC: 0.7040
# Confusion Matrix - TN: 95, FP: 47, FN: 21, TP: 40
# EarlyStopping counter: 11 out of 15
# Epoch 14, Training Loss: 0.0628, Validation Loss: 1.3876
# Validation Metrics - Accuracy: 0.6700, f1: 0.5442, sensitivity: 0.6557, Specificity: 0.6761, ROC AUC: 0.7038
# Confusion Matrix - TN: 96, FP: 46, FN: 21, TP: 40
# EarlyStopping counter: 12 out of 15
out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6772, Validation Loss: 0.8444
# Validation Metrics - Accuracy: 0.5862, f1: 0.5532, sensitivity: 0.8525, Specificity: 0.4718, ROC AUC: 0.7222
# Confusion Matrix - TN: 67, FP: 75, FN: 9, TP: 52
# ROC AUC improved (0.0000 --> 0.7222). Saving model ...
# Epoch 2, Training Loss: 0.5948, Validation Loss: 0.6615
# Validation Metrics - Accuracy: 0.6946, f1: 0.5571, sensitivity: 0.6393, Specificity: 0.7183, ROC AUC: 0.7387
# Confusion Matrix - TN: 102, FP: 40, FN: 22, TP: 39
# ROC AUC improved (0.7222 --> 0.7387). Saving model ...
# Epoch 3, Training Loss: 0.4752, Validation Loss: 0.6048
# Validation Metrics - Accuracy: 0.7143, f1: 0.5397, sensitivity: 0.5574, Specificity: 0.7817, ROC AUC: 0.7492
# Confusion Matrix - TN: 111, FP: 31, FN: 27, TP: 34
# ROC AUC improved (0.7387 --> 0.7492). Saving model ...
# Epoch 4, Training Loss: 0.3960, Validation Loss: 0.5846
# Validation Metrics - Accuracy: 0.7537, f1: 0.5690, sensitivity: 0.5410, Specificity: 0.8451, ROC AUC: 0.7636
# Confusion Matrix - TN: 120, FP: 22, FN: 28, TP: 33
# ROC AUC improved (0.7492 --> 0.7636). Saving model ...
# Epoch 5, Training Loss: 0.3257, Validation Loss: 0.8202
# Validation Metrics - Accuracy: 0.7044, f1: 0.5946, sensitivity: 0.7213, Specificity: 0.6972, ROC AUC: 0.7302
# Confusion Matrix - TN: 99, FP: 43, FN: 17, TP: 44
# EarlyStopping counter: 1 out of 15
# Epoch 6, Training Loss: 0.2667, Validation Loss: 0.8819
# Validation Metrics - Accuracy: 0.6207, f1: 0.5333, sensitivity: 0.7213, Specificity: 0.5775, ROC AUC: 0.7072
# Confusion Matrix - TN: 82, FP: 60, FN: 17, TP: 44
# EarlyStopping counter: 2 out of 15
# Epoch 7, Training Loss: 0.2072, Validation Loss: 0.9122
# Validation Metrics - Accuracy: 0.7044, f1: 0.5522, sensitivity: 0.6066, Specificity: 0.7465, ROC AUC: 0.7325
# Confusion Matrix - TN: 106, FP: 36, FN: 24, TP: 37
# EarlyStopping counter: 3 out of 15
# Epoch 8, Training Loss: 0.1485, Validation Loss: 1.0499
# Validation Metrics - Accuracy: 0.6798, f1: 0.5185, sensitivity: 0.5738, Specificity: 0.7254, ROC AUC: 0.6985
# Confusion Matrix - TN: 103, FP: 39, FN: 26, TP: 35
# EarlyStopping counter: 4 out of 15
# Epoch 9, Training Loss: 0.1261, Validation Loss: 1.0032
# Validation Metrics - Accuracy: 0.6897, f1: 0.5116, sensitivity: 0.5410, Specificity: 0.7535, ROC AUC: 0.7250
# Confusion Matrix - TN: 107, FP: 35, FN: 28, TP: 33
# EarlyStopping counter: 5 out of 15
# Epoch 10, Training Loss: 0.0859, Validation Loss: 1.1415
# Validation Metrics - Accuracy: 0.6749, f1: 0.5217, sensitivity: 0.5902, Specificity: 0.7113, ROC AUC: 0.7353
# Confusion Matrix - TN: 101, FP: 41, FN: 25, TP: 36
# EarlyStopping counter: 6 out of 15
# Epoch 11, Training Loss: 0.0814, Validation Loss: 1.1846
# Validation Metrics - Accuracy: 0.6897, f1: 0.5532, sensitivity: 0.6393, Specificity: 0.7113, ROC AUC: 0.7371
# Confusion Matrix - TN: 101, FP: 41, FN: 22, TP: 39
# EarlyStopping counter: 7 out of 15
# Epoch 12, Training Loss: 0.0790, Validation Loss: 1.2578
# Validation Metrics - Accuracy: 0.6847, f1: 0.5616, sensitivity: 0.6721, Specificity: 0.6901, ROC AUC: 0.7387
# Confusion Matrix - TN: 98, FP: 44, FN: 20, TP: 41
# EarlyStopping counter: 8 out of 15
# Epoch 13, Training Loss: 0.0600, Validation Loss: 1.2504
# Validation Metrics - Accuracy: 0.7044, f1: 0.5775, sensitivity: 0.6721, Specificity: 0.7183, ROC AUC: 0.7385
# Confusion Matrix - TN: 102, FP: 40, FN: 20, TP: 41
# EarlyStopping counter: 9 out of 15
# Epoch 14, Training Loss: 0.0781, Validation Loss: 1.2613
# Validation Metrics - Accuracy: 0.6995, f1: 0.5674, sensitivity: 0.6557, Specificity: 0.7183, ROC AUC: 0.7396
# Confusion Matrix - TN: 102, FP: 40, FN: 21, TP: 40
# EarlyStopping counter: 10 out of 15
# Epoch 15, Training Loss: 0.0716, Validation Loss: 1.2777
# Validation Metrics - Accuracy: 0.7044, f1: 0.5652, sensitivity: 0.6393, Specificity: 0.7324, ROC AUC: 0.7399
# Confusion Matrix - TN: 104, FP: 38, FN: 22, TP: 39
# EarlyStopping counter: 11 out of 15
# Epoch 16, Training Loss: 0.0729, Validation Loss: 1.3072
# Validation Metrics - Accuracy: 0.7143, f1: 0.5857, sensitivity: 0.6721, Specificity: 0.7324, ROC AUC: 0.7401
# Confusion Matrix - TN: 104, FP: 38, FN: 20, TP: 41
# EarlyStopping counter: 12 out of 15
# Epoch 17, Training Loss: 0.0754, Validation Loss: 1.3183
# Validation Metrics - Accuracy: 0.7143, f1: 0.5857, sensitivity: 0.6721, Specificity: 0.7324, ROC AUC: 0.7400
# Confusion Matrix - TN: 104, FP: 38, FN: 20, TP: 41
# EarlyStopping counter: 13 out of 15
# Epoch 18, Training Loss: 0.0636, Validation Loss: 1.3327
# Validation Metrics - Accuracy: 0.7094, f1: 0.5816, sensitivity: 0.6721, Specificity: 0.7254, ROC AUC: 0.7410
# Confusion Matrix - TN: 103, FP: 39, FN: 20, TP: 41
# EarlyStopping counter: 14 out of 15
# Epoch 19, Training Loss: 0.0672, Validation Loss: 1.3502
# Validation Metrics - Accuracy: 0.7044, f1: 0.5775, sensitivity: 0.6721, Specificity: 0.7183, ROC AUC: 0.7413
# Confusion Matrix - TN: 102, FP: 40, FN: 20, TP: 41
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 0.6357
# ...
#  0.06828897 0.02720353 0.08047457 0.15656513 0.06153364 0.18786968
#  0.01547403 0.06579528 0.06013431 0.01479078 0.68631953 0.02612877
#  0.04630492 0.39599487 0.08721022 0.99469006 0.06971977 0.291974
#  0.04251187 0.21281794 0.385918   0.49167985 0.08333869 0.04611648
#  0.04962346 0.03030656 0.9108434  0.09287685 0.98129934 0.15261921
#  0.0842808  0.13153738 0.03748943 0.16130757 0.0888021  0.95459527
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((3072,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=3072, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6716, Validation Loss: 0.9650
# Validation Metrics - Accuracy: 0.3886, f1: 0.4914, sensitivity: 0.9828, Specificity: 0.1333, ROC AUC: 0.7765
# Confusion Matrix - TN: 18, FP: 117, FN: 1, TP: 57
# ROC AUC improved (0.0000 --> 0.7765). Saving model ...
# Epoch 2, Training Loss: 0.5561, Validation Loss: 0.6147
# Validation Metrics - Accuracy: 0.7254, f1: 0.6345, sensitivity: 0.7931, Specificity: 0.6963, ROC AUC: 0.8220
# Confusion Matrix - TN: 94, FP: 41, FN: 12, TP: 46
# ROC AUC improved (0.7765 --> 0.8220). Saving model ...
# Epoch 3, Training Loss: 0.4803, Validation Loss: 0.6487
# Validation Metrics - Accuracy: 0.7254, f1: 0.6345, sensitivity: 0.7931, Specificity: 0.6963, ROC AUC: 0.7962
# Confusion Matrix - TN: 94, FP: 41, FN: 12, TP: 46
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.4144, Validation Loss: 0.7552
# Validation Metrics - Accuracy: 0.6580, f1: 0.5976, sensitivity: 0.8448, Specificity: 0.5778, ROC AUC: 0.8006
# Confusion Matrix - TN: 78, FP: 57, FN: 9, TP: 49
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.3167, Validation Loss: 0.8274
# Validation Metrics - Accuracy: 0.6477, f1: 0.5641, sensitivity: 0.7586, Specificity: 0.6000, ROC AUC: 0.7535
# Confusion Matrix - TN: 81, FP: 54, FN: 14, TP: 44
# EarlyStopping counter: 3 out of 15
# Epoch 6, Training Loss: 0.2548, Validation Loss: 0.8840
# Validation Metrics - Accuracy: 0.6839, f1: 0.6115, sensitivity: 0.8276, Specificity: 0.6222, ROC AUC: 0.8079
# Confusion Matrix - TN: 84, FP: 51, FN: 10, TP: 48
# EarlyStopping counter: 4 out of 15
# Epoch 7, Training Loss: 0.1751, Validation Loss: 0.7147
# Validation Metrics - Accuracy: 0.7202, f1: 0.5846, sensitivity: 0.6552, Specificity: 0.7481, ROC AUC: 0.7948
# Confusion Matrix - TN: 101, FP: 34, FN: 20, TP: 38
# EarlyStopping counter: 5 out of 15
# Epoch 8, Training Loss: 0.1256, Validation Loss: 0.8747
# Validation Metrics - Accuracy: 0.7047, f1: 0.6174, sensitivity: 0.7931, Specificity: 0.6667, ROC AUC: 0.8047
# Confusion Matrix - TN: 90, FP: 45, FN: 12, TP: 46
# EarlyStopping counter: 6 out of 15
# Epoch 9, Training Loss: 0.0824, Validation Loss: 0.8698
# Validation Metrics - Accuracy: 0.7202, f1: 0.6143, sensitivity: 0.7414, Specificity: 0.7111, ROC AUC: 0.8005
# Confusion Matrix - TN: 96, FP: 39, FN: 15, TP: 43
# EarlyStopping counter: 7 out of 15
# Epoch 10, Training Loss: 0.0948, Validation Loss: 0.8923
# Validation Metrics - Accuracy: 0.7254, f1: 0.6187, sensitivity: 0.7414, Specificity: 0.7185, ROC AUC: 0.8008
# Confusion Matrix - TN: 97, FP: 38, FN: 15, TP: 43
# EarlyStopping counter: 8 out of 15
# Epoch 11, Training Loss: 0.0701, Validation Loss: 0.9263
# Validation Metrics - Accuracy: 0.7254, f1: 0.6187, sensitivity: 0.7414, Specificity: 0.7185, ROC AUC: 0.8024
# Confusion Matrix - TN: 97, FP: 38, FN: 15, TP: 43
# EarlyStopping counter: 9 out of 15
# Epoch 12, Training Loss: 0.0836, Validation Loss: 0.9470
# Validation Metrics - Accuracy: 0.7150, f1: 0.6099, sensitivity: 0.7414, Specificity: 0.7037, ROC AUC: 0.8034
# Confusion Matrix - TN: 95, FP: 40, FN: 15, TP: 43
# EarlyStopping counter: 10 out of 15
# Epoch 13, Training Loss: 0.0653, Validation Loss: 0.9642
# Validation Metrics - Accuracy: 0.7150, f1: 0.6099, sensitivity: 0.7414, Specificity: 0.7037, ROC AUC: 0.8036
# Confusion Matrix - TN: 95, FP: 40, FN: 15, TP: 43
# EarlyStopping counter: 11 out of 15
# Epoch 14, Training Loss: 0.0729, Validation Loss: 0.9912
# Validation Metrics - Accuracy: 0.7202, f1: 0.6197, sensitivity: 0.7586, Specificity: 0.7037, ROC AUC: 0.8032
# Confusion Matrix - TN: 95, FP: 40, FN: 14, TP: 44
# EarlyStopping counter: 12 out of 15
# Epoch 15, Training Loss: 0.0661, Validation Loss: 1.0008
# Validation Metrics - Accuracy: 0.7202, f1: 0.6197, sensitivity: 0.7586, Specificity: 0.7037, ROC AUC: 0.8034
# Confusion Matrix - TN: 95, FP: 40, FN: 14, TP: 44
# EarlyStopping counter: 13 out of 15
# Epoch 16, Training Loss: 0.0719, Validation Loss: 1.0021
# Validation Metrics - Accuracy: 0.7150, f1: 0.6099, sensitivity: 0.7414, Specificity: 0.7037, ROC AUC: 0.8034
# Confusion Matrix - TN: 95, FP: 40, FN: 15, TP: 43
# EarlyStopping counter: 14 out of 15
# Epoch 17, Training Loss: 0.0588, Validation Loss: 1.0147
# Validation Metrics - Accuracy: 0.7150, f1: 0.6099, sensitivity: 0.7414, Specificity: 0.7037, ROC AUC: 0.8032
# Confusion Matrix - TN: 95, FP: 40, FN: 15, TP: 43
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 0.7012
# Test Metrics for Split 5 -Accuracy: 0.6475, f1: 0.5376, sensitivity: 0.6818, Specificity: 0.6328, ROC AUC: 0.7466
# Confusion Matrix - TN: 162, FP: 94, FN: 35, TP: 75
# for split 5:
# [0.13918576 0.27467555 0.38882577 0.2531385  0.23560247 0.206014
#  0.490842   0.18852875 0.30120367 0.27584007 0.45186576 0.81189287
#  0.27747864 0.24191992 0.625216   0.8265411  0.8513158  0.7494919
#  0.99550843 0.24972492 0.15687849 0.88863015 0.8700094  0.7094883
#  0.3301686  0.14162003 0.42616525 0.96422744 0.4118602  0.5798775
#  0.6064385  0.94739985 0.6773276  0.7220356  0.9088051  0.99598527
#  0.21987104 0.87539715 0.24312185 0.94879556 0.86970454 0.52761275
#  0.3552794  0.9674529  0.6522916  0.33582518 0.3979337  0.91335136
#  0.92583984 0.5639775  0.54669    0.3330333  0.64977723 0.7890174
#  0.85361886 0.938822   0.58320665 0.9197341  0.48954824 0.9881258
#  0.4383906  0.4929109  0.48504472 0.37745112 0.972563   0.950367
#  0.42513624 0.6499792  0.23467794 0.38224187 0.4335233  0.9372448
#  0.38183236 0.1344677  0.71401757 0.8844381  0.22777325 0.3656351
#  0.69163954 0.86981803 0.8077814  0.82905376 0.2615126  0.8785396
#  0.9246365  0.58777225 0.321961   0.23321824 0.9684401  0.96337056
#  0.4912051  0.4711428  0.38444883 0.27321523 0.15695792 0.6159873
#  0.22601368 0.4477427  0.5612587  0.951852   0.95895815 0.76569325
#  0.6493909  0.5490334  0.82022005 0.45194134 0.0928575  0.71209747
#  0.9763693  0.4853113  0.7931501  0.8786653  0.93808484 0.837378
#  0.849949   0.6020074  0.99330443 0.7786464  0.33840898 0.16370766]

# %% [markdown]
# ### RESULTS (PERFORMANCE)

# %% [markdown]
# #### Step 1. Load model and best results

# %%
directory = './Results_FewPGT2'

def load_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

y_pred_by_split = {}
y_pred_by_split['1'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_1', "y_pred_split_1.pkl"))
y_pred_by_split['2'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_2', "y_pred_split_2.pkl"))
y_pred_by_split['3'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_3', "y_pred_split_3.pkl"))
y_pred_by_split['4'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_4', "y_pred_split_4.pkl"))
y_pred_by_split['5'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_5', "y_pred_split_5.pkl"))

# %% [markdown]
# #### Step 2. Analysis of results

# %%
all_metrics = []

for i in [2, 3,5]: 
    y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    y_test_single = y_test.flatten()  
    y_test_pred = y_pred_by_split[str(i)].flatten()  
    
    df_metrics = utils.get_metrics_(y_test_single, (y_test_pred))
    print(df_metrics)
    utils.plot_metrics(df_metrics)
    utils.plot_roc_curve(y_test_single, y_test_pred)

    all_metrics.append(df_metrics)
print(all_metrics)
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  195  75  43  73  0.694301      0.62931     0.722222  0.733461   0.55303
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  174  68  30  74  0.716763     0.711538     0.719008  0.776502  0.601626
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  162  94  35  75  0.647541     0.681818     0.632812  0.746591  0.537634
# [    TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  195  75  43  73  0.694301      0.62931     0.722222  0.733461   0.55303,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  174  68  30  74  0.716763     0.711538     0.719008  0.776502  0.601626,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  162  94  35  75  0.647541     0.681818     0.632812  0.746591  0.537634]

# %%
metrics_FewGPT2 = pd.concat(all_metrics)
metrics_FewGPT2.to_csv('./Results_FewPGT2/metrics_FewGPT2.csv', index=False)

metrics_FewGPT2.head()
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  195  75  43  73  0.694301     0.629310     0.722222  0.733461  0.553030
# 0  174  68  30  74  0.716763     0.711538     0.719008  0.776502  0.601626
# 0  162  94  35  75  0.647541     0.681818     0.632812  0.746591  0.537634

# %%
metrics_mean = metrics_FewGPT2.mean()
metrics_std = metrics_FewGPT2.std()

summary_df = pd.DataFrame({
    "Metric": metrics_mean.index,
    "Mean": metrics_mean.values,
    "Standard Deviation": metrics_std.values
})
summary_df.to_csv('./Results_FewPGT2/metrics_summary_FewGPT2.csv', index=False)

print("\nMean and Standard Deviation of the Splits:")
print(summary_df)
# Out:
# Mean and Standard Deviation of the Splits:
#         Metric        Mean  Standard Deviation
# 0           TN  177.000000           16.703293
# 1           FP   79.000000           13.453624
# 2           FN   36.000000            6.557439
# 3           TP   74.000000            1.000000
# 4     Accuracy    0.686202            0.035315
# 5  Sensitivity    0.674222            0.041637
# 6  Specificity    0.691348            0.050718
# 7      ROC AUC    0.752185            0.022059
# 8     F1 Score    0.564097            0.033400

# %%
metrics_GPT2 = pd.read_csv('./Results_FewPGT2/metrics_FewGPT2.csv')

stats_GPT2 = metrics_GPT2.agg(["mean", "std"]) 
formatted_metrics = stats_GPT2.apply(lambda x: f"{x['mean']*100:.2f} ± {x['std']*100:.2f}", axis=0)
formatted_metrics_df = pd.DataFrame(formatted_metrics, columns=["Metrics (Mean ± Std)"])
formatted_metrics_df.to_csv('./Results_FewPGT2/metrics_GPT2_formatted.csv', index=True)
print(formatted_metrics_df)
# Out:
#             Metrics (Mean ± Std)
# TN            17700.00 ± 1670.33
# FP             7900.00 ± 1345.36
# FN              3600.00 ± 655.74
# TP              7400.00 ± 100.00
# Accuracy            68.62 ± 3.53
# Sensitivity         67.42 ± 4.16
# Specificity         69.13 ± 5.07
# ROC AUC             75.22 ± 2.21
# F1 Score            56.41 ± 3.34

# %% [markdown]
# ### SHAP

# %%
import shap

model_path = "/home/lcarmona/Modelos_finales/final_models/SHAP_bueno/LLM-Few4/checkpointGPT2.pt"
if os.path.exists(model_path):
    configs = Configs()
    model = LLMFew(configs).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    print("Model loaded")
else:
    raise FileNotFoundError(f"Model not found in {model_path}")

feature_names = [
    'AMG', 'ATF', 'ATI', 'ATP', 'CAR', 'CF1', 'CF2', 'CF3', 'CF4', 'Falta', 
    'GCC', 'GLI', 'LIN', 'LIP', 'MAC', 'MON', 'NTI', 
    'OTR', 'OXA', 'PAP', 'PEN', 'POL', 'QUI', 
    'SUL', 'TTC', 'hoursVM', 'acinet.$_{pc}$', 'enterobac.$_{pc}$', 'enteroc.$_{pc}$',
    'pseud.$_{pc}$', 'staph.$_{pc}$', 'others.$_{pc}$', 'hoursICU', '# pat_atb', '# pat_MR', 
    'CAR.$_{n}$', 'PAP.$_{n}$', 'Falta.$_{n}$', 'QUI.$_{n}$', 
    'ATF.$_{n}$', 'OXA.$_{n}$', 'PEN.$_{n}$', 'CF3.$_{n}$', 
    'GLI.$_{n}$', 'CF4.$_{n}$', 'SUL.$_{n}$', 'NTI.$_{n}$', 
    'LIN.$_{n}$', 'AMG.$_{n}$', 'MAC.$_{n}$', 'CF1.$_{n}$', 'GCC.$_{n}$', 
    'POL.$_{n}$', 'ATI.$_{n}$', 'MON.$_{n}$', 'LIP.$_{n}$', 'TTC.$_{n}$', 
    'OTR.$_{n}$', 'CF2.$_{n}$', 'ATP.$_{n}$', '# pat_ttl', 'posture.$_{change}$', 
    'insulin', 'nutr_art', 'sedation', 'relax', 'hep_fail', 'renal_fail', 
    'coag_fail', 'hemo_fail', 'resp_fail', 'multi_fail', 'n_transf', 
    'vasoactive.$_{drug}$', 'dosis_nems', 'hoursTracheo', 'hoursUlcer', 
    'hoursHemo', 'C01 PIVC 1', 'C01 PIVC 2', 'C02 CVC - YD', 'C02 CVC - SD', 
    'C02 CVC - SI', 'C02 CVC - FD', 'C02 CVC - YI', 'C02 CVC - FI', '# catheters'
]

all_shap_values = []
all_inputs = []

class WrappedModel(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        return self.model(x)

wrapped_model = WrappedModel(model)

for i in [1, 2, 3, 4, 5]:
    print(f"Processing split {i}...")
    X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w4days/s{i}/X_test_tensor_standardScaler.npy")
    X_test_tensor = torch.tensor(np.where(X_test == 666, 0, X_test), dtype=torch.float32).to(device)

    background = X_test_tensor[np.random.choice(X_test_tensor.shape[0], 100, replace=False)]

    explainer = shap.GradientExplainer(wrapped_model, background)
    shap_values = explainer.shap_values(X_test_tensor)

    all_shap_values.append(shap_values)
    all_inputs.append(X_test_tensor.cpu().numpy())

all_shap_concat = np.concatenate(all_shap_values, axis=0)
all_inputs_concat = np.concatenate(all_inputs, axis=0)

if all_shap_concat.ndim == 3:
    shap_values_avg = all_shap_concat.mean(axis=1)
    X_test_avg = all_inputs_concat.mean(axis=1)
else:
    shap_values_avg = all_shap_concat
    X_test_avg = all_inputs_concat

plt.figure(figsize=(12, 8))
shap.summary_plot(
    shap_values_avg,
    X_test_avg,
    feature_names=feature_names,
    max_display=30,
    show=False
)

plt.xticks(rotation=45, fontsize=18) 
plt.yticks(fontsize=19)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=20)
cbar.set_ylabel("Feature value", fontsize=20)

plt.tight_layout()
plt.savefig("shap_summary_llmfewgpt2_4.png", dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Model loaded
# Processing split 1...
# Processing split 2...
# Processing split 3...
# Processing split 4...
# Processing split 5...

# %%
plt.figure(figsize=(12, 8))
shap_values_exp = shap.Explanation(
    values=shap_values_avg,
    data=X_test_avg,
    feature_names=feature_names
)

shap.plots.heatmap(shap_values_exp, show=False)

plt.xticks(fontsize=21, rotation=45)
plt.yticks(fontsize=21)
plt.xlabel("Instances", fontsize=20)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=19)
cbar.set_ylabel("SHAP value (impact on model output)", fontsize=17)

plt.savefig("shap_heatmap_lllmfewgpt2_4.png", dpi=300, bbox_inches='tight')
plt.close()

# %%
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

import sklearn
from sklearn import metrics

import random, os, json
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import sys
sys.path.append("../")
import utils

from joblib import Parallel, delayed
import multiprocessing

import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader, TensorDataset

from torch.optim import Adam
from torch.nn import BCELoss
import numpy as np
import argparse
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, confusion_matrix

from CasualCNN import CausalCNNEncoder
from Embed import PatchEmbedding
from sklearn.utils import resample
from LLMprepare import LLMprepare

device = torch.device('cuda:0')
# Out:
# 2025-04-21 19:17:59.949161: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-21 19:18:00.021109: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-21 19:18:01.158309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def calculate_metrics(y_true, y_pred_probs):
    y_pred = np.round(y_pred_probs).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    accuracy = accuracy_score(y_true, y_pred)
    sensitivity = recall_score(y_true, y_pred) 
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0 
    roc_auc = roc_auc_score(y_true, y_pred_probs)
    f1 = f1_score(y_true, y_pred)  

    return accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp

# %% [markdown]
# ### HYPERPARAMETERS

# %% [markdown]
# - **seeds**: Seed values to ensure reproducibility.
# - **batch_size**: Number of samples per batch used during training.
# - **dropout**: Dropout rate applied to prevent overfitting.
# - **weight_decay**: Weight decay for the optimizer to apply additional L2 regularization.
# - **lr**: Learning rate assigned to the optimizer.
# - **patience**: Number of epochs with no improvement before early stopping is triggered.
# - **dimensions**: Number of features in each time step of the input data.
# - **length**: Number of time steps in the input sequence.
# - **num_class**: Number of output classes for the prediction task.
# - **patch_len**: Length of each patch created from the input sequence.
# - **stride**: Step size used when unfolding the sequence into patches.
# - **llm_type**: Type of large language model used as a backbone.

# %%
class Configs:
    def __init__(self):
        self.dimensions = 87
        self.length = 14
        self.num_class = 1  
        self.depth = 2
        self.channels = 128
        self.reduced_size = 64
        self.kernel_size = 3
        self.patch_len = 2
        self.stride = 1
        self.dropout = 0.1
        self.batch_size = 4
        self.epochs = 100
        self.lr = 0.0005
        self.llm_type = "gpt2"
        self.lora = 1
        
seeds = [9, 76, 227, 12, 18, 45]
batch_size = 4
n_epochs_max = 100
configs = Configs() 
monitor = "val_auc"

hyperparameters = {
    "lr": configs.lr,
    "batch_size": batch_size,          
    "n_epochs_max": n_epochs_max,                
    "weight_decay": 5e-4, 
    "dropout": configs.dropout,
    "patience": 15,
  }

# %% [markdown]
# ### FUNCTIONS OF THE MODEL

# %%
class LLMFew(nn.Module):
    def __init__(self, configs):
        super(LLMFew, self).__init__()
        self.configs = configs
        self.num_class = configs.num_class
        self.length = configs.length
        self.dimensions = configs.dimensions
        self.llm_type = configs.llm_type
        self.lora = configs.lora
        self.patch_len = configs.patch_len
        self.stride = configs.stride
        self.llm_model, self.d_model = LLMprepare(configs)
        self.patch_embedding = PatchEmbedding(
            self.d_model, self.patch_len, self.stride, configs.dropout) 
        self.patch_nums = int((self.length - self.patch_len) / self.stride + 2)
        self.padding_patch_layer = nn.ReplicationPad1d((0, self.stride if self.patch_len < self.length else 0))
        self.encoder = CausalCNNEncoder(in_channels=self.dimensions, channels=configs.channels, depth=configs.depth,
                                        reduced_size=configs.reduced_size, out_channels=self.d_model,
                                        kernel_size=configs.kernel_size)
        self.dropout = nn.Dropout(configs.dropout)
        self.relu = nn.LeakyReLU()
        self.act = F.relu
        self.ln_proj = nn.LayerNorm(self.d_model * self.patch_nums).to(torch.bfloat16)
        self.mapping = nn.Sequential(nn.Linear(self.d_model * self.patch_nums, self.num_class),
                                     nn.Dropout(configs.dropout))
        self.activation = nn.Sigmoid()

    def forward(self, x):
        # x: batch, dim(dimensions), seq(length)
        x = x.contiguous()
        B, L, M = x.shape
        x = x.permute(0, 2, 1)  # (B, M, L)
        input_x = self.padding_patch_layer(x)  
        input_x = input_x.unfold(dimension=-1, size=self.patch_len, step=self.stride)
        input_x = rearrange(input_x, 'b m n p-> (b n) m p')
        output_x = self.encoder(input_x)
        output_x = self.dropout(output_x)
        output_x = rearrange(output_x, '(b n) o-> b n o', b=B)
        output_x = output_x.to(torch.bfloat16)
        
        llm_out = self.llm_model(inputs_embeds=output_x.contiguous()).last_hidden_state
        outputs = self.relu(llm_out + output_x).reshape(B, -1)
        outputs = self.ln_proj(outputs)
        outputs = outputs.to(torch.float32)
        outputs = self.mapping(outputs)
        outputs = self.activation(outputs)
        
        return outputs

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0.001, verbose=False):
    """
    Early stops the training if validation ROC AUC does not improve after a given patience.

    Args:
        - patience: Number of epochs to wait for an improvement before stopping the training. 
        - delta: Minimum change in the monitored metric to qualify as an improvement.
        - verbose: If True, prints detailed messages each time the model improves and when early stopping is triggered.
    """
        self.patience = patience
        self.delta = delta
        self.verbose = verbose
        self.counter = 0
        self.best_roc_auc = None  
        self.early_stop = False

    def __call__(self, roc_auc, model):
        if self.best_roc_auc is None or roc_auc > self.best_roc_auc + self.delta:
            self.save_checkpoint(roc_auc, model)
            self.best_roc_auc = roc_auc
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True

    def save_checkpoint(self, roc_auc, model):
        if self.verbose:
            print(f"ROC AUC improved ({self.best_roc_auc if self.best_roc_auc is not None else 0:.4f} --> {roc_auc:.4f}). Saving model ...")
        torch.save(model.state_dict(), 'checkpoint.pt')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False 
    
def run_network(X_train, X_val, y_train, y_val, hyperparameters, seed, configs): 
    """
    Trains and evaluates the built model based on the provided data and hyperparameters.

    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.
        - configs: Configuration object with model settings.

    Returns:
        - model: The trained PyTorch model.
        - history: Training history object containing loss and metrics.
    """    
    device = torch.device('cuda:0')
    batch_size=hyperparameters['batch_size']
    
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device).unsqueeze(1)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device).unsqueeze(1)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    set_seed(seed)
    
    configs = Configs()
    model = LLMFew(configs).to(device)
    print(model)
    
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=hyperparameters['lr'], weight_decay=hyperparameters['weight_decay'])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

    train_loss_history = []
    val_loss_history = []
    val_auc_history = [] 
    early_stopping = EarlyStopping(patience=hyperparameters['patience'], delta=0.001, verbose=True)


    for epoch in range(hyperparameters['n_epochs_max']):
        model.train()
        train_loss = 0.0
        
        for batch_x, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_loss_history.append(train_loss)

        model.eval()
        val_loss = 0.0
        y_val_preds = []
        y_val_true = []
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()

                y_val_preds.extend(outputs.cpu().numpy().flatten())
                y_val_true.extend(batch_y.cpu().numpy().flatten())
        
        val_loss /= len(val_loader)
        val_loss_history.append(val_loss)

        y_val_preds = np.array(y_val_preds)
        y_val_true = np.array(y_val_true)
        accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp = calculate_metrics(y_val_true, y_val_preds)
        
        val_auc_history.append(roc_auc)
        scheduler.step(val_loss)
        
        print(f"Epoch {epoch + 1}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"Validation Metrics - Accuracy: {accuracy:.4f}, f1: {f1:.4f}, sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f} ")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        early_stopping(roc_auc, model)
        if early_stopping.early_stop:
            print("Early stopping.")
            break
    
    model.load_state_dict(torch.load('checkpoint.pt'))

    history = {'loss': train_loss_history, 'val_loss': val_loss_history,
        'val_auc': val_auc_history}
    return model, history

# %%
def objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs):
    """
    Objective function for hyperparameter optimization using Optuna.
    Args:
        - trial (optuna.trial.Trial): Optuna trial object.
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
        - configs: Configuration object with model settings.        
   
    Returns:
        - metric_dev: Best validation AUC achieved during training.     
    """
    trial_seed = seed + trial.number  
    set_seed(trial_seed)

    hyperparameters_copy = hyperparameters.copy()

    hyperparameters_copy['lr'] = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    hyperparameters_copy['weight_decay'] = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    hyperparameters_copy['dropout'] = trial.suggest_float("dropout", 0.0, 0.3)
    hyperparameters_copy['patience'] = trial.suggest_int("patience", 3, 20)

    v_val_auc = [] 
    
    configs = Configs()
    
    model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters_copy,
            trial_seed, 
            configs
        )

    v_val_auc.append(max(history['val_auc']))
    metric_dev = np.mean(v_val_auc)

    return metric_dev

def optuna_study(hyperparameters, seed, X_train, y_train, X_val, y_val):
    """
    Runs an Optuna study to optimize hyperparameters for the model.
    
    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
    Returns:
        - best_hyperparameters: Dictionary containing the best hyperparameters found 
          after the optimization process.
    """  
    set_seed(seed)

    sampler = optuna.samplers.TPESampler(seed=seed)
    study = optuna.create_study(direction='maximize', sampler=sampler)

    study.optimize(
        lambda trial: objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs),
        n_trials=20,  
        n_jobs=1      
    )

    best_params = study.best_params
    best_metric = study.best_value
    
    best_hyperparameters = {
        'lr': best_params['lr'], 
        'weight_decay': best_params['weight_decay'], 
        'dropout': best_params['dropout'],  
        'patience': best_params['patience'],  
    }

    print(f"Best Hyperparameters: {best_params}")
    print(f"Best Validation Metric: {best_metric}")

    return best_hyperparameters

# %%
import time
import os
import pickle
import torch
import numpy as np
import pandas as pd


run_model = True
results = []
if run_model:
    loss_train = []
    loss_dev = []
    v_models = []

    y_pred_by_split = {}
    bestHyperparameters_bySplit = {}

        
    for i in [1,2,3,4,5]:
        init = time.time()
        
        X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_test_tensor_standardScaler.npy")
        y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_train_tensor_standardScaler.npy")
        y_train = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_train_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    
        X_val = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_val_tensor_standardScaler.npy")
        y_val = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_val_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.where(X_train == 666, 0, X_train)
        X_val = np.where(X_val == 666, 0, X_val)
        X_test = np.where(X_test == 666, 0, X_test)
    

        X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device).unsqueeze(1)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        bestHyperparameters = optuna_study(
            hyperparameters,
            seeds[i-1],
            X_train, y_train,  
            X_val, y_val
        )

        bestHyperparameters_bySplit[str(i)] = bestHyperparameters
        
        split_directory = f'./Results_FewPGT2/split_{i}'
        if not os.path.exists(split_directory):
            os.makedirs(split_directory)

        with open(os.path.join(split_directory, f"bestHyperparameters_split_{i}.pkl"), 'wb') as f:
            pickle.dump(bestHyperparameters, f)

        hyperparameters.update({
            'lr': bestHyperparameters['lr'], 
            'weight_decay': bestHyperparameters['weight_decay'],
            'dropout': bestHyperparameters['dropout'], 
            'patience': bestHyperparameters['patience']
        })        

        
        configs = Configs()
        criterion = nn.BCELoss()
        
        model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters,
            seeds[i-1], 
            configs
        )

        v_models.append(model)
        loss_train.append(history['loss'])
        loss_dev.append(history['val_loss'])

        y_pred = []
        y_true = []
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                test_loss += loss.item()
                
                y_pred.extend(outputs.cpu().numpy().flatten())
                y_true.extend(batch_y.cpu().numpy().flatten())
        
        test_loss /= len(test_loader)
        y_pred = np.array(y_pred)  
        y_true = np.array(y_true)
        
        accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp = calculate_metrics(y_true, y_pred)
    
        print(f" Test Loss: {test_loss:.4f}")
        print(f"Test Metrics for Split {i} -Accuracy: {accuracy:.4f}, f1: {f1:.4f}, sensitivity: {sensitivity:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        results.append([accuracy, sensitivity, specificity, roc_auc, f1, tn, fp, fn, tp])

        y_pred_by_split[str(i)] = y_pred
        print(f"for split {i}:")
        print(y_pred_by_split[str(i)])

        y_pred_path = os.path.join(split_directory, f"y_pred_split_{i}.pkl")
        with open(y_pred_path, 'wb') as f:
            pickle.dump(y_pred, f)   
    
    directory = './Results_FewPGT2'
    if not os.path.exists(directory):
        os.makedirs(directory)

    def save_to_pickle(data, filename):
        with open(filename, 'wb') as f:
            pickle.dump(data, f)

    save_to_pickle(y_pred_by_split, os.path.join(directory, "y_pred_by_split.pkl"))
    save_to_pickle(loss_train, os.path.join(directory, "loss_train.pkl"))
    save_to_pickle(loss_dev, os.path.join(directory, "loss_dev.pkl"))
    save_to_pickle(bestHyperparameters_bySplit, os.path.join(directory, "bestHyperparameters_bySplit.pkl"))
# Out:
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7109, Validation Loss: 0.8531
# Validation Metrics - Accuracy: 0.6413, f1: 0.5238, sensitivity: 0.6567, Specificity: 0.6346, ROC AUC: 0.6670
# Confusion Matrix - TN: 99, FP: 57, FN: 23, TP: 44
# ROC AUC improved (0.0000 --> 0.6670). Saving model ...
# Epoch 2, Training Loss: 0.6462, Validation Loss: 1.2555
# Validation Metrics - Accuracy: 0.5740, f1: 0.5128, sensitivity: 0.7463, Specificity: 0.5000, ROC AUC: 0.7225
# Confusion Matrix - TN: 78, FP: 78, FN: 17, TP: 50
# ROC AUC improved (0.6670 --> 0.7225). Saving model ...
# Epoch 3, Training Loss: 0.5815, Validation Loss: 0.7783
# Validation Metrics - Accuracy: 0.7489, f1: 0.5758, sensitivity: 0.5672, Specificity: 0.8269, ROC AUC: 0.7099
# Confusion Matrix - TN: 129, FP: 27, FN: 29, TP: 38
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.5063, Validation Loss: 0.9374
# Validation Metrics - Accuracy: 0.6996, f1: 0.5503, sensitivity: 0.6119, Specificity: 0.7372, ROC AUC: 0.7083
# Confusion Matrix - TN: 115, FP: 41, FN: 26, TP: 41
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.4685, Validation Loss: 1.0623
# Validation Metrics - Accuracy: 0.6682, f1: 0.5432, sensitivity: 0.6567, Specificity: 0.6731, ROC AUC: 0.6852
# Confusion Matrix - TN: 105, FP: 51, FN: 23, TP: 44
# EarlyStopping counter: 3 out of 15
# Epoch 6, Training Loss: 0.4869, Validation Loss: 0.9134
# Validation Metrics - Accuracy: 0.6906, f1: 0.4889, sensitivity: 0.4925, Specificity: 0.7756, ROC AUC: 0.6545
# Confusion Matrix - TN: 121, FP: 35, FN: 34, TP: 33
# EarlyStopping counter: 4 out of 15
# Epoch 7, Training Loss: 0.3420, Validation Loss: 1.3558
# Validation Metrics - Accuracy: 0.6009, f1: 0.5189, sensitivity: 0.7164, Specificity: 0.5513, ROC AUC: 0.6524
# Confusion Matrix - TN: 86, FP: 70, FN: 19, TP: 48
# EarlyStopping counter: 5 out of 15
# Epoch 8, Training Loss: 0.2311, Validation Loss: 1.1945
# Validation Metrics - Accuracy: 0.6637, f1: 0.5455, sensitivity: 0.6716, Specificity: 0.6603, ROC AUC: 0.6790
# Confusion Matrix - TN: 103, FP: 53, FN: 22, TP: 45
# EarlyStopping counter: 6 out of 15
# Epoch 9, Training Loss: 0.1542, Validation Loss: 1.0329
# Validation Metrics - Accuracy: 0.6906, f1: 0.4733, sensitivity: 0.4627, Specificity: 0.7885, ROC AUC: 0.6571
# Confusion Matrix - TN: 123, FP: 33, FN: 36, TP: 31
# EarlyStopping counter: 7 out of 15
# Epoch 10, Training Loss: 0.1344, Validation Loss: 1.1728
# Validation Metrics - Accuracy: 0.6951, f1: 0.5072, sensitivity: 0.5224, Specificity: 0.7692, ROC AUC: 0.6581
# Confusion Matrix - TN: 120, FP: 36, FN: 32, TP: 35
# EarlyStopping counter: 8 out of 15
# Epoch 11, Training Loss: 0.0995, Validation Loss: 1.3320
# Validation Metrics - Accuracy: 0.6682, f1: 0.5132, sensitivity: 0.5821, Specificity: 0.7051, ROC AUC: 0.6574
# Confusion Matrix - TN: 110, FP: 46, FN: 28, TP: 39
# EarlyStopping counter: 9 out of 15
# Epoch 12, Training Loss: 0.0968, Validation Loss: 1.3700
# Validation Metrics - Accuracy: 0.6637, f1: 0.5223, sensitivity: 0.6119, Specificity: 0.6859, ROC AUC: 0.6573
# Confusion Matrix - TN: 107, FP: 49, FN: 26, TP: 41
# EarlyStopping counter: 10 out of 15
# Epoch 13, Training Loss: 0.1014, Validation Loss: 1.4183
# Validation Metrics - Accuracy: 0.6682, f1: 0.5316, sensitivity: 0.6269, Specificity: 0.6859, ROC AUC: 0.6591
# Confusion Matrix - TN: 107, FP: 49, FN: 25, TP: 42
# EarlyStopping counter: 11 out of 15
# Epoch 14, Training Loss: 0.0800, Validation Loss: 1.4714
# Validation Metrics - Accuracy: 0.6637, f1: 0.5283, sensitivity: 0.6269, Specificity: 0.6795, ROC AUC: 0.6648
# Confusion Matrix - TN: 106, FP: 50, FN: 25, TP: 42
# EarlyStopping counter: 12 out of 15
# Epoch 15, Training Loss: 0.0829, Validation Loss: 1.5551
# Validation Metrics - Accuracy: 0.6682, f1: 0.5542, sensitivity: 0.6866, Specificity: 0.6603, ROC AUC: 0.6596
# Confusion Matrix - TN: 103, FP: 53, FN: 21, TP: 46
# EarlyStopping counter: 13 out of 15
# Epoch 16, Training Loss: 0.0817, Validation Loss: 1.5218
# Validation Metrics - Accuracy: 0.6726, f1: 0.5466, sensitivity: 0.6567, Specificity: 0.6795, ROC AUC: 0.6620
# Confusion Matrix - TN: 106, FP: 50, FN: 23, TP: 44
#  0.9849503  0.15664652 0.38699782 0.8921999  0.9999949  0.84510493
#  0.9951109  0.30325592 0.2727458  0.99998045 0.96119475 0.9804735
#  0.79086614 0.8943687  0.94867903 0.98465586 0.07723346 0.42270264
#  0.98763484 0.63936996 0.39183965 0.41992104 0.9994019  0.12331546
#  0.22764532 0.8905069  0.72711957 0.7755318  0.20571451 0.9935208
#  0.6200585  0.9642884  0.17003162 0.23663782 0.7620373  0.8174645
#  0.99981767 0.556575   0.6290352  0.07610141 0.37297443 0.99991786
#  0.99991596 0.9998273  0.35324654 0.9825524  0.9998455  0.37920442
#  0.2464467  0.33724618 0.99759513 0.7076232  0.28628063 0.82097983
#  0.7669515  0.9999999  0.03355369 0.8770007  0.11962535 0.9941387
#  0.8153935  0.2926444  0.12335689 0.07313551 0.07799307 0.24515001
#  0.9688289  0.9988606  0.9992392  0.5539943  0.10917287 0.99929714
#  0.9148795  0.65864116 0.79684734 0.95166314 0.9891745  0.8531336
#  0.10558517 0.46218562 0.99999917 0.9999529  0.711418   0.25282505
#  0.85200036 0.8542401  0.658465   0.12621723 0.59203047 0.32819524
#  0.12998277 0.84570444 0.9040834  0.4894055  0.99490863 0.9982436
#  0.92459226 0.2692941  0.8060253  0.99454206 0.9993105  0.13388479
#  0.9998673  0.3812639  0.81008434 0.6210744  0.99997795 0.7610618
#  0.69260657 0.9996816  0.2407113  0.46388435]
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7000, Validation Loss: 0.8298
# Validation Metrics - Accuracy: 0.6046, f1: 0.5478, sensitivity: 0.7975, Specificity: 0.5217, ROC AUC: 0.7464
# Confusion Matrix - TN: 96, FP: 88, FN: 16, TP: 63
# ROC AUC improved (0.0000 --> 0.7464). Saving model ...
# Epoch 2, Training Loss: 0.6597, Validation Loss: 0.6341
# Validation Metrics - Accuracy: 0.7300, f1: 0.5749, sensitivity: 0.6076, Specificity: 0.7826, ROC AUC: 0.7264
# Confusion Matrix - TN: 144, FP: 40, FN: 31, TP: 48
# EarlyStopping counter: 1 out of 15
# Epoch 3, Training Loss: 0.5390, Validation Loss: 0.5231
# Validation Metrics - Accuracy: 0.7871, f1: 0.5882, sensitivity: 0.5063, Specificity: 0.9076, ROC AUC: 0.7909
# Confusion Matrix - TN: 167, FP: 17, FN: 39, TP: 40
# ROC AUC improved (0.7464 --> 0.7909). Saving model ...
# Epoch 4, Training Loss: 0.4904, Validation Loss: 0.8208
# Validation Metrics - Accuracy: 0.7148, f1: 0.6341, sensitivity: 0.8228, Specificity: 0.6685, ROC AUC: 0.8210
# Confusion Matrix - TN: 123, FP: 61, FN: 14, TP: 65
# ROC AUC improved (0.7909 --> 0.8210). Saving model ...
# Epoch 5, Training Loss: 0.4950, Validation Loss: 0.6290
# Validation Metrics - Accuracy: 0.7757, f1: 0.5874, sensitivity: 0.5316, Specificity: 0.8804, ROC AUC: 0.8187
# Confusion Matrix - TN: 162, FP: 22, FN: 37, TP: 42
# EarlyStopping counter: 1 out of 15
# Epoch 6, Training Loss: 0.4268, Validation Loss: 0.7220
# Validation Metrics - Accuracy: 0.7490, f1: 0.6292, sensitivity: 0.7089, Specificity: 0.7663, ROC AUC: 0.7838
# Confusion Matrix - TN: 141, FP: 43, FN: 23, TP: 56
# EarlyStopping counter: 2 out of 15
# Epoch 7, Training Loss: 0.2764, Validation Loss: 0.6960
# Validation Metrics - Accuracy: 0.7833, f1: 0.6667, sensitivity: 0.7215, Specificity: 0.8098, ROC AUC: 0.8109
# Confusion Matrix - TN: 149, FP: 35, FN: 22, TP: 57
# EarlyStopping counter: 3 out of 15
# Epoch 8, Training Loss: 0.1879, Validation Loss: 0.8739
# Validation Metrics - Accuracy: 0.7110, f1: 0.6346, sensitivity: 0.8354, Specificity: 0.6576, ROC AUC: 0.8188
# Confusion Matrix - TN: 121, FP: 63, FN: 13, TP: 66
# EarlyStopping counter: 4 out of 15
# Epoch 9, Training Loss: 0.1332, Validation Loss: 0.9196
# Validation Metrics - Accuracy: 0.7110, f1: 0.6311, sensitivity: 0.8228, Specificity: 0.6630, ROC AUC: 0.8282
# Confusion Matrix - TN: 122, FP: 62, FN: 14, TP: 65
# ROC AUC improved (0.8210 --> 0.8282). Saving model ...
# Epoch 10, Training Loss: 0.1372, Validation Loss: 0.8783
# Validation Metrics - Accuracy: 0.7262, f1: 0.6327, sensitivity: 0.7848, Specificity: 0.7011, ROC AUC: 0.8130
# Confusion Matrix - TN: 129, FP: 55, FN: 17, TP: 62
# EarlyStopping counter: 1 out of 15
# Epoch 11, Training Loss: 0.1102, Validation Loss: 0.7731
# Validation Metrics - Accuracy: 0.7757, f1: 0.6629, sensitivity: 0.7342, Specificity: 0.7935, ROC AUC: 0.8237
# Confusion Matrix - TN: 146, FP: 38, FN: 21, TP: 58
# EarlyStopping counter: 2 out of 15
# Epoch 12, Training Loss: 0.0956, Validation Loss: 0.9347
# Validation Metrics - Accuracy: 0.7300, f1: 0.6359, sensitivity: 0.7848, Specificity: 0.7065, ROC AUC: 0.8253
# Confusion Matrix - TN: 130, FP: 54, FN: 17, TP: 62
# EarlyStopping counter: 3 out of 15
# Epoch 13, Training Loss: 0.0822, Validation Loss: 0.9888
# Validation Metrics - Accuracy: 0.7186, f1: 0.6263, sensitivity: 0.7848, Specificity: 0.6902, ROC AUC: 0.8267
# Confusion Matrix - TN: 127, FP: 57, FN: 17, TP: 62
# EarlyStopping counter: 4 out of 15
# Epoch 14, Training Loss: 0.0911, Validation Loss: 0.9994
# Validation Metrics - Accuracy: 0.7300, f1: 0.6359, sensitivity: 0.7848, Specificity: 0.7065, ROC AUC: 0.8263
# Confusion Matrix - TN: 130, FP: 54, FN: 17, TP: 62
# EarlyStopping counter: 5 out of 15
# Epoch 15, Training Loss: 0.0730, Validation Loss: 1.0856
# Validation Metrics - Accuracy: 0.6920, f1: 0.6049, sensitivity: 0.7848, Specificity: 0.6522, ROC AUC: 0.8229
# Confusion Matrix - TN: 120, FP: 64, FN: 17, TP: 62
# EarlyStopping counter: 6 out of 15
# Epoch 16, Training Loss: 0.0698, Validation Loss: 1.0626
# Validation Metrics - Accuracy: 0.7186, f1: 0.6263, sensitivity: 0.7848, Specificity: 0.6902, ROC AUC: 0.8248
# Confusion Matrix - TN: 127, FP: 57, FN: 17, TP: 62
# EarlyStopping counter: 7 out of 15
# Epoch 17, Training Loss: 0.0703, Validation Loss: 1.0489
# Validation Metrics - Accuracy: 0.7300, f1: 0.6359, sensitivity: 0.7848, Specificity: 0.7065, ROC AUC: 0.8244
# Confusion Matrix - TN: 130, FP: 54, FN: 17, TP: 62
# EarlyStopping counter: 8 out of 15
# Epoch 18, Training Loss: 0.0823, Validation Loss: 1.0716
# Validation Metrics - Accuracy: 0.7224, f1: 0.6294, sensitivity: 0.7848, Specificity: 0.6957, ROC AUC: 0.8239
# Confusion Matrix - TN: 128, FP: 56, FN: 17, TP: 62
# EarlyStopping counter: 9 out of 15
# Epoch 19, Training Loss: 0.0926, Validation Loss: 1.1077
# Validation Metrics - Accuracy: 0.7034, f1: 0.6139, sensitivity: 0.7848, Specificity: 0.6685, ROC AUC: 0.8234
# Confusion Matrix - TN: 123, FP: 61, FN: 17, TP: 62
# EarlyStopping counter: 10 out of 15
# Epoch 20, Training Loss: 0.0693, Validation Loss: 1.1231
# Validation Metrics - Accuracy: 0.7034, f1: 0.6139, sensitivity: 0.7848, Specificity: 0.6685, ROC AUC: 0.8224
# Confusion Matrix - TN: 123, FP: 61, FN: 17, TP: 62
# EarlyStopping counter: 11 out of 15
# Epoch 21, Training Loss: 0.0844, Validation Loss: 1.1016
# Validation Metrics - Accuracy: 0.7186, f1: 0.6263, sensitivity: 0.7848, Specificity: 0.6902, ROC AUC: 0.8235
# Confusion Matrix - TN: 127, FP: 57, FN: 17, TP: 62
# EarlyStopping counter: 12 out of 15
# Epoch 22, Training Loss: 0.0769, Validation Loss: 1.1239
# Validation Metrics - Accuracy: 0.7034, f1: 0.6139, sensitivity: 0.7848, Specificity: 0.6685, ROC AUC: 0.8232
# Confusion Matrix - TN: 123, FP: 61, FN: 17, TP: 62
# EarlyStopping counter: 13 out of 15
# Epoch 23, Training Loss: 0.0788, Validation Loss: 1.0948
# Validation Metrics - Accuracy: 0.7224, f1: 0.6256, sensitivity: 0.7722, Specificity: 0.7011, ROC AUC: 0.8237
# Confusion Matrix - TN: 129, FP: 55, FN: 18, TP: 61
# EarlyStopping counter: 14 out of 15
# Epoch 24, Training Loss: 0.0621, Validation Loss: 1.1138
# Validation Metrics - Accuracy: 0.7148, f1: 0.6193, sensitivity: 0.7722, Specificity: 0.6902, ROC AUC: 0.8227
#  9.83769357e-01 5.23347855e-01 9.59468901e-01 8.92702937e-01
#  9.73685801e-01 1.99559882e-01 9.82199311e-01 9.72854018e-01
#  2.49711592e-02 9.99998927e-01 9.99436915e-01 9.92744923e-01
#  9.52578366e-01 3.39722097e-01 4.23135370e-01 1.86232120e-01
#  9.94031847e-01 6.80039674e-02 9.10403907e-01 4.94820207e-01
#  3.28370392e-01 4.58451390e-01 9.48085487e-01 9.68127489e-01
#  5.79495609e-01 8.84928763e-01 1.76824071e-02 2.47930750e-01
#  9.86225247e-01 7.11460188e-02 6.42790571e-02 9.99324679e-01
#  9.99998212e-01 9.33935523e-01 9.99450028e-01 8.70279670e-02
#  6.67716488e-02 2.57892072e-01 4.73666817e-01 2.60352194e-01
#  9.95452106e-01 4.59049702e-01 9.99722183e-01 9.98498321e-01
#  8.62826258e-02 8.67539465e-01 9.99342144e-01 6.87903389e-02
#  9.99958515e-01 6.90587103e-01 9.97045457e-01 2.35705376e-01
#  1.03425488e-01 3.47052813e-01 8.18605542e-01 9.99999404e-01
#  1.75638109e-01 9.81933177e-01 8.85755062e-01 1.70890853e-01]
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): GPT2Model(
#         (wte): Embedding(50257, 768)
#         (wpe): Embedding(1024, 768)
#         (drop): Dropout(p=0.1, inplace=False)
#         (h): ModuleList(
#           (0-11): 12 x GPT2Block(
#             (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (attn): GPT2SdpaAttention(
#               (c_attn): lora.Linear(
#                 (base_layer): Conv1D(nf=2304, nx=768)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=768, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=2304, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (c_proj): Conv1D(nf=768, nx=768)
#               (attn_dropout): Dropout(p=0.1, inplace=False)
#               (resid_dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7442, Validation Loss: 0.6674
# Validation Metrics - Accuracy: 0.7180, f1: 0.3243, sensitivity: 0.2250, Specificity: 0.9301, ROC AUC: 0.7203
# Confusion Matrix - TN: 173, FP: 13, FN: 62, TP: 18
# ROC AUC improved (0.0000 --> 0.7203). Saving model ...
# Epoch 2, Training Loss: 0.6353, Validation Loss: 0.6207
# Validation Metrics - Accuracy: 0.7331, f1: 0.5535, sensitivity: 0.5500, Specificity: 0.8118, ROC AUC: 0.7581
# Confusion Matrix - TN: 151, FP: 35, FN: 36, TP: 44
# ROC AUC improved (0.7203 --> 0.7581). Saving model ...
# Epoch 3, Training Loss: 0.5903, Validation Loss: 0.9225
# Validation Metrics - Accuracy: 0.6767, f1: 0.5981, sensitivity: 0.8000, Specificity: 0.6237, ROC AUC: 0.7565
# Confusion Matrix - TN: 116, FP: 70, FN: 16, TP: 64
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.5211, Validation Loss: 0.6718
# Validation Metrics - Accuracy: 0.7444, f1: 0.5211, sensitivity: 0.4625, Specificity: 0.8656, ROC AUC: 0.7589
# Confusion Matrix - TN: 161, FP: 25, FN: 43, TP: 37
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.4188, Validation Loss: 0.9871
# Validation Metrics - Accuracy: 0.7105, f1: 0.6051, sensitivity: 0.7375, Specificity: 0.6989, ROC AUC: 0.7475
# Confusion Matrix - TN: 130, FP: 56, FN: 21, TP: 59
# EarlyStopping counter: 3 out of 15
# Epoch 6, Training Loss: 0.4238, Validation Loss: 0.9231
# Validation Metrics - Accuracy: 0.6992, f1: 0.5960, sensitivity: 0.7375, Specificity: 0.6828, ROC AUC: 0.7141
# Confusion Matrix - TN: 127, FP: 59, FN: 21, TP: 59
# EarlyStopping counter: 4 out of 15
# Epoch 7, Training Loss: 0.3469, Validation Loss: 0.9595
# Validation Metrics - Accuracy: 0.6955, f1: 0.5970, sensitivity: 0.7500, Specificity: 0.6720, ROC AUC: 0.7362
# Confusion Matrix - TN: 125, FP: 61, FN: 20, TP: 60
# EarlyStopping counter: 5 out of 15
# Epoch 8, Training Loss: 0.2249, Validation Loss: 0.9648
# Validation Metrics - Accuracy: 0.7105, f1: 0.5698, sensitivity: 0.6375, Specificity: 0.7419, ROC AUC: 0.7233
# Confusion Matrix - TN: 138, FP: 48, FN: 29, TP: 51
# EarlyStopping counter: 6 out of 15
# Epoch 9, Training Loss: 0.1827, Validation Loss: 1.2083
# Validation Metrics - Accuracy: 0.6692, f1: 0.5849, sensitivity: 0.7750, Specificity: 0.6237, ROC AUC: 0.7356
# Confusion Matrix - TN: 116, FP: 70, FN: 18, TP: 62
# EarlyStopping counter: 7 out of 15
# Epoch 10, Training Loss: 0.1414, Validation Loss: 1.8552
# Validation Metrics - Accuracy: 0.7030, f1: 0.6146, sensitivity: 0.7875, Specificity: 0.6667, ROC AUC: 0.7366
# Confusion Matrix - TN: 124, FP: 62, FN: 17, TP: 63
# EarlyStopping counter: 8 out of 15
# Epoch 11, Training Loss: 0.1407, Validation Loss: 1.8610
# Validation Metrics - Accuracy: 0.6880, f1: 0.5951, sensitivity: 0.7625, Specificity: 0.6559, ROC AUC: 0.7282
# Confusion Matrix - TN: 122, FP: 64, FN: 19, TP: 61
# EarlyStopping counter: 9 out of 15
# Epoch 12, Training Loss: 0.1062, Validation Loss: 2.1760
# Validation Metrics - Accuracy: 0.7143, f1: 0.6122, sensitivity: 0.7500, Specificity: 0.6989, ROC AUC: 0.7285
# Confusion Matrix - TN: 130, FP: 56, FN: 20, TP: 60
# EarlyStopping counter: 10 out of 15
# Epoch 13, Training Loss: 0.1096, Validation Loss: 2.1561
# Validation Metrics - Accuracy: 0.7143, f1: 0.6000, sensitivity: 0.7125, Specificity: 0.7151, ROC AUC: 0.7285
# Confusion Matrix - TN: 133, FP: 53, FN: 23, TP: 57
# EarlyStopping counter: 11 out of 15
# Epoch 14, Training Loss: 0.0958, Validation Loss: 2.1652
# Validation Metrics - Accuracy: 0.7143, f1: 0.5824, sensitivity: 0.6625, Specificity: 0.7366, ROC AUC: 0.7299
# Confusion Matrix - TN: 137, FP: 49, FN: 27, TP: 53
# EarlyStopping counter: 12 out of 15
# Epoch 15, Training Loss: 0.0822, Validation Loss: 2.2270
dropout): Dropout(p=0.1, inplace=False)
#             )
#             (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (mlp): GPT2MLP(
#               (c_fc): Conv1D(nf=3072, nx=768)
#               (c_proj): Conv1D(nf=768, nx=3072)
#               (act): NewGELUActivation()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7010, Validation Loss: 1.2847
# Validation Metrics - Accuracy: 0.3333, f1: 0.4701, sensitivity: 0.9844, Specificity: 0.0537, ROC AUC: 0.7134
# Confusion Matrix - TN: 8, FP: 141, FN: 1, TP: 63
# ROC AUC improved (0.0000 --> 0.7134). Saving model ...
# Epoch 2, Training Loss: 0.6587, Validation Loss: 0.8783
# Validation Metrics - Accuracy: 0.6291, f1: 0.5635, sensitivity: 0.7969, Specificity: 0.5570, ROC AUC: 0.7453
# Confusion Matrix - TN: 83, FP: 66, FN: 13, TP: 51
# ROC AUC improved (0.7134 --> 0.7453). Saving model ...
# Epoch 3, Training Loss: 0.5003, Validation Loss: 1.2895
# Validation Metrics - Accuracy: 0.4695, f1: 0.5150, sensitivity: 0.9375, Specificity: 0.2685, ROC AUC: 0.7809
# Confusion Matrix - TN: 40, FP: 109, FN: 4, TP: 60
# ROC AUC improved (0.7453 --> 0.7809). Saving model ...
# Epoch 4, Training Loss: 0.4343, Validation Loss: 0.8505
# Validation Metrics - Accuracy: 0.6150, f1: 0.5495, sensitivity: 0.7812, Specificity: 0.5436, ROC AUC: 0.7348
# Confusion Matrix - TN: 81, FP: 68, FN: 14, TP: 50
# EarlyStopping counter: 1 out of 15
# Epoch 5, Training Loss: 0.3279, Validation Loss: 0.8456
# Validation Metrics - Accuracy: 0.7465, f1: 0.6301, sensitivity: 0.7188, Specificity: 0.7584, ROC AUC: 0.7620
# Confusion Matrix - TN: 113, FP: 36, FN: 18, TP: 46
# EarlyStopping counter: 2 out of 15
# Epoch 6, Training Loss: 0.2568, Validation Loss: 1.1308
# Validation Metrics - Accuracy: 0.6526, f1: 0.5488, sensitivity: 0.7031, Specificity: 0.6309, ROC AUC: 0.7019
# Confusion Matrix - TN: 94, FP: 55, FN: 19, TP: 45
# EarlyStopping counter: 3 out of 15
# Epoch 7, Training Loss: 0.2060, Validation Loss: 0.9481
# Validation Metrics - Accuracy: 0.6995, f1: 0.5616, sensitivity: 0.6406, Specificity: 0.7248, ROC AUC: 0.7102
# Confusion Matrix - TN: 108, FP: 41, FN: 23, TP: 41
# EarlyStopping counter: 4 out of 15
# Epoch 8, Training Loss: 0.2198, Validation Loss: 1.4617
# Validation Metrics - Accuracy: 0.6291, f1: 0.5635, sensitivity: 0.7969, Specificity: 0.5570, ROC AUC: 0.7375
# Confusion Matrix - TN: 83, FP: 66, FN: 13, TP: 51
# EarlyStopping counter: 5 out of 15
# Epoch 9, Training Loss: 0.2615, Validation Loss: 2.0195
# Validation Metrics - Accuracy: 0.6244, f1: 0.5402, sensitivity: 0.7344, Specificity: 0.5772, ROC AUC: 0.7323
# Confusion Matrix - TN: 86, FP: 63, FN: 17, TP: 47
# EarlyStopping counter: 6 out of 15
# Epoch 10, Training Loss: 0.1251, Validation Loss: 1.1613
# Validation Metrics - Accuracy: 0.7042, f1: 0.5594, sensitivity: 0.6250, Specificity: 0.7383, ROC AUC: 0.7150
# Confusion Matrix - TN: 110, FP: 39, FN: 24, TP: 40
# EarlyStopping counter: 7 out of 15
# Epoch 11, Training Loss: 0.0878, Validation Loss: 1.2485
# Validation Metrics - Accuracy: 0.6761, f1: 0.5430, sensitivity: 0.6406, Specificity: 0.6913, ROC AUC: 0.7068
# Confusion Matrix - TN: 103, FP: 46, FN: 23, TP: 41
# EarlyStopping counter: 8 out of 15
# Epoch 12, Training Loss: 0.0718, Validation Loss: 1.2680
# Validation Metrics - Accuracy: 0.6901, f1: 0.5479, sensitivity: 0.6250, Specificity: 0.7181, ROC AUC: 0.7129
# Confusion Matrix - TN: 107, FP: 42, FN: 24, TP: 40
# EarlyStopping counter: 9 out of 15
# Epoch 13, Training Loss: 0.0761, Validation Loss: 1.3429
# Validation Metrics - Accuracy: 0.6948, f1: 0.5578, sensitivity: 0.6406, Specificity: 0.7181, ROC AUC: 0.7160
# Confusion Matrix - TN: 107, FP: 42, FN: 23, TP: 41
# EarlyStopping counter: 10 out of 15
# Epoch 14, Training Loss: 0.0909, Validation Loss: 1.8096
# Validation Metrics - Accuracy: 0.6667, f1: 0.5359, sensitivity: 0.6406, Specificity: 0.6779, ROC AUC: 0.7162
# Confusion Matrix - TN: 101, FP: 48, FN: 23, TP: 41
# EarlyStopping counter: 11 out of 15
# Epoch 15, Training Loss: 0.0759, Validation Loss: 1.8420
# Validation Metrics - Accuracy: 0.6573, f1: 0.5290, sensitivity: 0.6406, Specificity: 0.6644, ROC AUC: 0.7159
# Confusion Matrix - TN: 99, FP: 50, FN: 23, TP: 41
# EarlyStopping counter: 12 out of 15
# Epoch 16, Training Loss: 0.0710, Validation Loss: 1.8613
# Validation Metrics - Accuracy: 0.6761, f1: 0.5430, sensitivity: 0.6406, Specificity: 0.6913, ROC AUC: 0.7162
# Confusion Matrix - TN: 103, FP: 46, FN: 23, TP: 41
# EarlyStopping counter: 13 out of 15
# Epoch 17, Training Loss: 0.0820, Validation Loss: 1.8661
# Validation Metrics - Accuracy: 0.6808, f1: 0.5467, sensitivity: 0.6406, Specificity: 0.6980, ROC AUC: 0.7175
# Confusion Matrix - TN: 104, FP: 45, FN: 23, TP: 41
# EarlyStopping counter: 14 out of 15
# Epoch 18, Training Loss: 0.0749, Validation Loss: 1.8878
# Validation Metrics - Accuracy: 0.6761, f1: 0.5430, sensitivity: 0.6406, Specificity: 0.6913, ROC AUC: 0.7182
# Confusion Matrix - TN: 103, FP: 46, FN: 23, TP: 41
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 1.4002
# Test Metrics for Split 5 -Accuracy: 0.4186, f1: 0.4811, sensitivity: 0.8983, Specificity: 0.2131, ROC AUC: 0.7281
# Confusion Matrix - TN: 88, FP: 325, FN: 18, TP: 159
# for split 5:
# [0.4863687  0.34872812 0.3912938  0.55065376 0.6638766  0.5518584
#  0.6482104  0.6806477  0.5453238  0.45108166 0.7587394  0.65668434
#  0.72008556 0.8646743  0.9791733  0.93896496 0.83477175 0.5231347
#  0.9600865  0.48199245 0.64767194 0.7229158  0.9983752  0.9971392
#  0.67416424 0.8312592  0.57724255 0.98647577 0.9041259  0.7716998
#  0.9995751  0.9513589  0.99643964 0.49909267 0.6932298  0.9509537
#  0.9023095  0.9811163  0.9021273  0.9993463  0.9999801  0.9991241
#  0.79116774 0.8834419  0.5305455  0.8623885  0.2922062  0.35844457
#  0.9130861  0.8249971  0.59865946 0.8933923  0.6425101  0.67074305
#  0.56447464 0.82893604 0.45106596 0.5746651  0.65879273 0.84567165
#  0.5962687  0.6533879  0.9926634  0.67189515 0.7284369  0.9979232
#  0.99937135 0.58261454 0.9994     0.70904684 0.95721817 0.99918073
#  0.9009484  0.6523351  0.9872464  0.9683754  0.7323094  0.50528795
#  0.95384085 0.990867   0.6346679  0.97758555 0.9933964  0.56908417
#  0.84462357 0.78507733 0.99751294 0.8142158  0.35073468 0.9925092
#  0.6593588  0.33205676 0.5754247  0.99773824 0.59205675 0.99899167
#  0.8820342  0.7325853  0.4275766  0.8852844  0.7206052  0.99905366
#  0.8542649  0.9975848 ]

# %% [markdown]
# ### RESULTS (PERFORMANCE)

# %% [markdown]
# #### Step 1. Load model and best results

# %%
directory = './Results_FewPGT2'

def load_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

y_pred_by_split = {}
y_pred_by_split['1'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_1', "y_pred_split_1.pkl"))
y_pred_by_split['2'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_2', "y_pred_split_2.pkl"))
y_pred_by_split['3'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_3', "y_pred_split_3.pkl"))
y_pred_by_split['4'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_4', "y_pred_split_4.pkl"))
y_pred_by_split['5'] = load_from_pickle(os.path.join('./Results_FewPGT2/split_5', "y_pred_split_5.pkl"))

# %% [markdown]
# #### Step 2. Analysis of results

# %%
all_metrics = []

for i in [1, 2,5]: 
    y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    y_test_single = y_test.flatten()  
    y_test_pred = y_pred_by_split[str(i)].flatten()  
    
    df_metrics = utils.get_metrics_(y_test_single, (y_test_pred))
    print(df_metrics)
    utils.plot_metrics(df_metrics)
    utils.plot_roc_curve(y_test_single, y_test_pred)

    all_metrics.append(df_metrics)
print(all_metrics)
# Out:
#     TN  FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  290  95  57  108  0.723636     0.654545     0.753247  0.766753  0.586957
#     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  231  133  39  117  0.669231         0.75     0.634615  0.761341  0.576355
#     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  251  162  38  139  0.661017     0.785311     0.607748  0.756118   0.58159
# [    TN  FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  290  95  57  108  0.723636     0.654545     0.753247  0.766753  0.586957,     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  231  133  39  117  0.669231         0.75     0.634615  0.761341  0.576355,     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  251  162  38  139  0.661017     0.785311     0.607748  0.756118   0.58159]

# %%
metrics_FewGPT2 = pd.concat(all_metrics)
metrics_FewGPT2.to_csv('./Results_FewPGT2/metrics_FewGPT2.csv', index=False)

metrics_FewGPT2.head()
# Out:
#     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  290   95  57  108  0.723636     0.654545     0.753247  0.766753  0.586957
# 0  231  133  39  117  0.669231     0.750000     0.634615  0.761341  0.576355
# 0  251  162  38  139  0.661017     0.785311     0.607748  0.756118  0.581590

# %%
metrics_mean = metrics_FewGPT2.mean()
metrics_std = metrics_FewGPT2.std()

summary_df = pd.DataFrame({
    "Metric": metrics_mean.index,
    "Mean": metrics_mean.values,
    "Standard Deviation": metrics_std.values
})
summary_df.to_csv('./Results_FewPGT2/metrics_summary_FewGPT2.csv', index=False)

print("\nMean and Standard Deviation of the Splits:")
print(summary_df)
# Out:
# Mean and Standard Deviation of the Splits:
#         Metric        Mean  Standard Deviation
# 0           TN  257.333333           30.005555
# 1           FP  130.000000           33.600595
# 2           FN   44.666667           10.692677
# 3           TP  121.333333           15.947832
# 4     Accuracy    0.684628            0.034031
# 5  Sensitivity    0.729952            0.067649
# 6  Specificity    0.665203            0.077422
# 7      ROC AUC    0.761404            0.005318
# 8     F1 Score    0.581634            0.005301

# %%
metrics_GPT2 = pd.read_csv('./Results_FewPGT2/metrics_FewGPT2.csv')

stats_GPT2 = metrics_GPT2.agg(["mean", "std"]) 
formatted_metrics = stats_GPT2.apply(lambda x: f"{x['mean']*100:.2f} ± {x['std']*100:.2f}", axis=0)
formatted_metrics_df = pd.DataFrame(formatted_metrics, columns=["Metrics (Mean ± Std)"])
formatted_metrics_df.to_csv('./Results_FewPGT2/metrics_GPT2_formatted.csv', index=True)
print(formatted_metrics_df)
# Out:
#             Metrics (Mean ± Std)
# TN            25733.33 ± 3000.56
# FP            13000.00 ± 3360.06
# FN             4466.67 ± 1069.27
# TP            12133.33 ± 1594.78
# Accuracy            68.46 ± 3.40
# Sensitivity         73.00 ± 6.76
# Specificity         66.52 ± 7.74
# ROC AUC             76.14 ± 0.53
# F1 Score            58.16 ± 0.53

# %% [markdown]
# ### SHAP

# %%
import shap

model_path = "/home/lcarmona/Modelos_finales/final_models/SHAP_bueno/LLM-Few14/checkpoint.pt"
if os.path.exists(model_path):
    configs = Configs()
    model = LLMFew(configs).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    print("Model loaded")
else:
    raise FileNotFoundError(f"Model not found in {model_path}")

feature_names = [
    'AMG', 'ATF', 'ATI', 'ATP', 'CAR', 'CF1', 'CF2', 'CF3', 'CF4', 'Falta', 
    'GCC', 'GLI', 'LIN', 'LIP', 'MAC', 'MON', 'NTI', 
    'OTR', 'OXA', 'PAP', 'PEN', 'POL', 'QUI', 
    'SUL', 'TTC', 'hoursVM', 'acinet.$_{pc}$', 'enterobac.$_{pc}$', 'enteroc.$_{pc}$',
    'pseud.$_{pc}$', 'staph.$_{pc}$', 'others.$_{pc}$', 'hoursICU', '# pat_atb', '# pat_MR', 
    'CAR.$_{n}$', 'PAP.$_{n}$', 'Falta.$_{n}$', 'QUI.$_{n}$', 
    'ATF.$_{n}$', 'OXA.$_{n}$', 'PEN.$_{n}$', 'CF3.$_{n}$', 
    'GLI.$_{n}$', 'CF4.$_{n}$', 'SUL.$_{n}$', 'NTI.$_{n}$', 
    'LIN.$_{n}$', 'AMG.$_{n}$', 'MAC.$_{n}$', 'CF1.$_{n}$', 'GCC.$_{n}$', 
    'POL.$_{n}$', 'ATI.$_{n}$', 'MON.$_{n}$', 'LIP.$_{n}$', 'TTC.$_{n}$', 
    'OTR.$_{n}$', 'CF2.$_{n}$', 'ATP.$_{n}$', '# pat_ttl', 'posture.$_{change}$', 
    'insulin', 'nutr_art', 'sedation', 'relax', 'hep_fail', 'renal_fail', 
    'coag_fail', 'hemo_fail', 'resp_fail', 'multi_fail', 'n_transf', 
    'vasoactive.$_{drug}$', 'dosis_nems', 'hoursTracheo', 'hoursUlcer', 
    'hoursHemo', 'C01 PIVC 1', 'C01 PIVC 2', 'C02 CVC - YD', 'C02 CVC - SD', 
    'C02 CVC - SI', 'C02 CVC - FD', 'C02 CVC - YI', 'C02 CVC - FI', '# catheters'
]

all_shap_values = []
all_inputs = []

class WrappedModel(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        return self.model(x)

wrapped_model = WrappedModel(model)

for i in [1, 2, 3, 4, 5]:
    print(f"Processing split {i}...")
    X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_test_tensor_standardScaler.npy")
    X_test_tensor = torch.tensor(np.where(X_test == 666, 0, X_test), dtype=torch.float32).to(device)

    background = X_test_tensor[np.random.choice(X_test_tensor.shape[0], 100, replace=False)]

    explainer = shap.GradientExplainer(wrapped_model, background)
    shap_values = explainer.shap_values(X_test_tensor)

    all_shap_values.append(shap_values)
    all_inputs.append(X_test_tensor.cpu().numpy())

all_shap_concat = np.concatenate(all_shap_values, axis=0)
all_inputs_concat = np.concatenate(all_inputs, axis=0)

if all_shap_concat.ndim == 3:
    shap_values_avg = all_shap_concat.mean(axis=1)
    X_test_avg = all_inputs_concat.mean(axis=1)
else:
    shap_values_avg = all_shap_concat
    X_test_avg = all_inputs_concat

plt.figure(figsize=(12, 8))
shap.summary_plot(
    shap_values_avg,
    X_test_avg,
    feature_names=feature_names,
    max_display=30,
    show=False
)

plt.xticks(rotation=45, fontsize=18) 
plt.yticks(fontsize=19)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=20)
cbar.set_ylabel("Feature value", fontsize=20)

plt.tight_layout()
plt.savefig("shap_summary_llmfewgpt2_14.png", dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Model loaded
# Processing split 1...
# Processing split 2...
# Processing split 3...
# Processing split 4...
# Processing split 5...

# %%
plt.figure(figsize=(12, 8))
shap_values_exp = shap.Explanation(
    values=shap_values_avg,
    data=X_test_avg,
    feature_names=feature_names
)

shap.plots.heatmap(shap_values_exp, show=False)

plt.xticks(fontsize=21, rotation=45)
plt.yticks(fontsize=21)
plt.xlabel("Instances", fontsize=20)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=19)
cbar.set_ylabel("SHAP value (impact on model output)", fontsize=17)

plt.savefig("shap_heatmap_lllmfewgpt2_14.png", dpi=300, bbox_inches='tight')
plt.close()

# %%
import optuna
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime
import time
import warnings
warnings.filterwarnings('ignore')

import sklearn
from sklearn import metrics

import random, os, json
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import sys
sys.path.append("../")
import utils

from joblib import Parallel, delayed
import multiprocessing

import pickle
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader, TensorDataset

from torch.optim import Adam
from torch.nn import BCELoss
import numpy as np
import argparse
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, confusion_matrix

#from LLMFew import LLMFew
from CasualCNN import CausalCNNEncoder
from Embed import PatchEmbedding
from sklearn.utils import resample
from LLMprepareopt import LLMprepare

device = torch.device('cuda:0')
# Out:
# 2025-04-21 20:32:13.988168: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-21 20:32:14.065418: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-21 20:32:17.938892: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# cuda:0

# %%
def calculate_metrics(y_true, y_pred_probs):
    y_pred = np.round(y_pred_probs).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    specificity = tn / (tn + fp)  
    roc_auc = roc_auc_score(y_true, y_pred_probs) 

    return accuracy, recall, specificity, roc_auc, tn, fp, fn, tp

# %% [markdown]
# ### HYPERPARAMETERS

# %% [markdown]
# - **seeds**: Seed values to ensure reproducibility.
# - **batch_size**: Number of samples per batch used during training.
# - **dropout**: Dropout rate applied to prevent overfitting.
# - **weight_decay**: Weight decay for the optimizer to apply additional L2 regularization.
# - **lr**: Learning rate assigned to the optimizer.
# - **patience**: Number of epochs with no improvement before early stopping is triggered.
# - **dimensions**: Number of features in each time step of the input data.
# - **length**: Number of time steps in the input sequence.
# - **num_class**: Number of output classes for the prediction task.
# - **patch_len**: Length of each patch created from the input sequence.
# - **stride**: Step size used when unfolding the sequence into patches.
# - **llm_type**: Type of large language model used as a backbone.

# %%
class Configs:
    def __init__(self):
        self.dimensions = 87
        self.length = 14
        self.num_class = 1  
        self.depth = 2
        self.channels = 128
        self.reduced_size = 64
        self.kernel_size = 3
        self.patch_len = 2
        self.stride = 1
        self.dropout = 0.1
        self.batch_size = 4
        self.epochs = 100
        self.lr = 0.0005
        self.llm_type = "facebook/opt-125m"  
        self.lora = 1
        
seeds = [9, 76, 227, 12, 18, 45]
batch_size = 4
n_epochs_max = 100
configs = Configs() 
monitor = "val_auc"  

hyperparameters = {
    "lr": configs.lr,
    "batch_size": batch_size,          
    "n_epochs_max": n_epochs_max,                
    "weight_decay": 5e-4, 
    "dropout": configs.dropout,
    "patience": 15,
}

# %% [markdown]
# ### FUNCTIONS OF THE MODEL

# %%
class LLMFew(nn.Module):
    def __init__(self, configs):
        super(LLMFew, self).__init__()
        self.configs = configs
        self.num_class = configs.num_class
        self.length = configs.length
        self.dimensions = configs.dimensions
        self.llm_type = configs.llm_type
        self.lora = configs.lora
        self.patch_len = configs.patch_len
        self.stride = configs.stride
        self.llm_model, self.d_model = LLMprepare(configs)
        self.patch_embedding = PatchEmbedding(
            self.d_model, self.patch_len, self.stride, configs.dropout) 
        self.patch_nums = int((self.length - self.patch_len) / self.stride + 2)
        self.padding_patch_layer = nn.ReplicationPad1d((0, self.stride if self.patch_len < self.length else 0))
        self.encoder = CausalCNNEncoder(in_channels=self.dimensions, channels=configs.channels, depth=configs.depth,
                                        reduced_size=configs.reduced_size, out_channels=self.d_model,
                                        kernel_size=configs.kernel_size)
        self.dropout = nn.Dropout(configs.dropout)
        self.relu = nn.LeakyReLU()
        self.act = F.relu
        self.ln_proj = nn.LayerNorm(self.d_model * self.patch_nums).to(torch.bfloat16)
        self.mapping = nn.Sequential(nn.Linear(self.d_model * self.patch_nums, self.num_class),
                                     nn.Dropout(configs.dropout))
        self.activation = nn.Sigmoid()

    def forward(self, x):
        # x: batch, dim(dimensions), seq(length)
        x = x.contiguous()
        B, L, M = x.shape
        x = x.permute(0, 2, 1)  # (B, M, L)
        input_x = self.padding_patch_layer(x)  
        input_x = input_x.unfold(dimension=-1, size=self.patch_len, step=self.stride)
        input_x = rearrange(input_x, 'b m n p-> (b n) m p')
        output_x = self.encoder(input_x)
        output_x = self.dropout(output_x)
        output_x = rearrange(output_x, '(b n) o-> b n o', b=B)
        output_x = output_x.to(torch.bfloat16)
        
        llm_out = self.llm_model(inputs_embeds=output_x.contiguous()).last_hidden_state
        outputs = self.relu(llm_out + output_x).reshape(B, -1)
        outputs = self.ln_proj(outputs)
        outputs = outputs.to(torch.float32)
        outputs = self.mapping(outputs)
        outputs = self.activation(outputs)
        
        return outputs

# %%
class EarlyStopping:
    def __init__(self, patience=5, delta=0, verbose=False):
    """
    Early stops the training if validation ROC AUC does not improve after a given patience.

    Args:
        - patience: Number of epochs to wait for an improvement before stopping the training. 
        - delta: Minimum change in the monitored metric to qualify as an improvement.
        - verbose: If True, prints detailed messages each time the model improves and when early stopping is triggered.
    """
        self.patience = patience
        self.delta = delta
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.best_roc_auc = 0.0  

    def __call__(self, roc_auc, model):
        if self.best_score is None:
            self.best_score = roc_auc
            self.save_checkpoint(roc_auc, model)
        elif roc_auc < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = roc_auc
            self.save_checkpoint(roc_auc, model)
            self.counter = 0

    def save_checkpoint(self, roc_auc, model):
        """Saves the model when ROC AUC increases."""
        if self.verbose:
            print(f"ROC AUC increased ({self.best_roc_auc:.4f} --> {roc_auc:.4f}). Saving model ...")
        self.best_roc_auc = roc_auc
        torch.save(model.state_dict(), 'checkpointOpt.pt')

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False 
    
def run_network(X_train, X_val, y_train, y_val, hyperparameters, seed, configs): 
    """
    Trains and evaluates the built model based on the provided data and hyperparameters.

    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.
        - configs: Configuration object with model settings.

    Returns:
        - model: The trained PyTorch model.
        - history: Training history object containing loss and metrics.
    """   
    device = torch.device('cuda:0')
    print(device)
    batch_size=hyperparameters['batch_size']

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32).to(device)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).to(device).unsqueeze(1)
    X_val_tensor = torch.tensor(X_val, dtype=torch.float32).to(device)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).to(device).unsqueeze(1)

    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    set_seed(seed)
    
    configs = Configs()
    model = LLMFew(configs).to(device)
    print(model)
    
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=hyperparameters['lr'], weight_decay=hyperparameters['weight_decay'])
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=True)

    train_loss_history = []
    val_loss_history = []
    val_auc_history = [] 
    early_stopping = EarlyStopping(patience=hyperparameters['patience'], delta=0.001, verbose=True)


    for epoch in range(hyperparameters['n_epochs_max']):
        model.train()
        train_loss = 0.0
        
        for batch_x, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_x)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        
        train_loss /= len(train_loader)
        train_loss_history.append(train_loss)

        model.eval()
        val_loss = 0.0
        y_val_preds = []
        y_val_true = []
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item()

                y_val_preds.extend(outputs.cpu().numpy().flatten())
                y_val_true.extend(batch_y.cpu().numpy().flatten())
        
        val_loss /= len(val_loader)
        val_loss_history.append(val_loss)

        y_val_preds = np.array(y_val_preds)
        y_val_true = np.array(y_val_true)
        accuracy, recall, specificity, roc_auc, tn, fp, fn, tp = calculate_metrics(y_val_true, y_val_preds)
        
        val_auc_history.append(roc_auc)
        scheduler.step(val_loss)
        
        print(f"Epoch {epoch + 1}, Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"Validation Metrics - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        early_stopping(roc_auc, model)
        if early_stopping.early_stop:
            print("Early stopping.")
            break
    
    model.load_state_dict(torch.load('checkpointOpt.pt'))

    history = {'loss': train_loss_history, 'val_loss': val_loss_history,
        'val_auc': val_auc_history}
    return model, history

# %%
def objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs):
    """
    Objective function for hyperparameter optimization using Optuna.
    Args:
        - trial (optuna.trial.Trial): Optuna trial object.
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
        - configs: Configuration object with model settings.        
   
    Returns:
        - metric_dev: Best validation AUC achieved during training.     
    """
    trial_seed = seed + trial.number  
    set_seed(trial_seed)

    hyperparameters_copy = hyperparameters.copy()

    hyperparameters_copy['lr'] = trial.suggest_float("lr", 1e-5, 1e-3, log=True)
    hyperparameters_copy['weight_decay'] = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    hyperparameters_copy['dropout'] = trial.suggest_float("dropout", 0.0, 0.3)
    hyperparameters_copy['patience'] = trial.suggest_int("patience", 3, 20)

    v_val_auc = [] 
    
    configs = Configs()
    
    model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters_copy,
            trial_seed, 
            configs
        )

    v_val_auc.append(max(history['val_auc']))
    metric_dev = np.mean(v_val_auc)

    return metric_dev

def optuna_study(hyperparameters, seed, X_train, y_train, X_val, y_val):
    """
    Runs an Optuna study to optimize hyperparameters for the model.
    
    Args:
        - X_train, X_val, y_train, y_val: numpy.ndarray. Training (T) and Validation (V) data labels.
        - hyperparameters: Dictionary containing training and model hyperparameters.
        - seed: Random seed for reproducibility.  
    Returns:
        - best_hyperparameters: Dictionary containing the best hyperparameters found 
          after the optimization process.
    """ 
    set_seed(seed)

    sampler = optuna.samplers.TPESampler(seed=seed)
    study = optuna.create_study(direction='maximize', sampler=sampler)

    study.optimize(
        lambda trial: objective(trial, hyperparameters, seed, X_train, y_train, X_val, y_val, configs),
        n_trials=20,  
        n_jobs=1      
    )

    best_params = study.best_params
    best_metric = study.best_value
    
    best_hyperparameters = {
        'lr': best_params['lr'], 
        'weight_decay': best_params['weight_decay'], 
        'dropout': best_params['dropout'],  
        'patience': best_params['patience'],  
    }

    print(f"Best Hyperparameters: {best_params}")
    print(f"Best Validation Metric: {best_metric}")

    return best_hyperparameters

# %% [markdown]
# ### PREDICTIONS

# %%
import time
import os
import pickle
import torch
import numpy as np
import pandas as pd

run_model = True
results = []
if run_model:
    loss_train = []
    loss_dev = []
    v_models = []

    y_pred_by_split = {}
    bestHyperparameters_bySplit = {}

        
    for i in [1,2,3,4,5]:
        init = time.time()
        
        X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_test_tensor_standardScaler.npy")
        y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)

        X_train = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_train_tensor_standardScaler.npy")
        y_train = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_train_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    
        X_val = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_val_tensor_standardScaler.npy")
        y_val = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_val_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)


        X_train = np.where(X_train == 666, 0, X_train)
        X_val = np.where(X_val == 666, 0, X_val)
        X_test = np.where(X_test == 666, 0, X_test)

        X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
        y_test_tensor = torch.tensor(y_test, dtype=torch.float32).to(device).unsqueeze(1)
        test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
        bestHyperparameters = optuna_study(
            hyperparameters,
            seeds[i-1],
            X_train, y_train,  
            X_val, y_val
        )

        bestHyperparameters_bySplit[str(i)] = bestHyperparameters
        
        split_directory = f'./Results_FewOpt/split_{i}'
        if not os.path.exists(split_directory):
            os.makedirs(split_directory)
        
        with open(os.path.join(split_directory, f"bestHyperparameters_split_{i}.pkl"), 'wb') as f:
            pickle.dump(bestHyperparameters, f)
        
        hyperparameters.update({
            'lr': bestHyperparameters['lr'], 
            'weight_decay': bestHyperparameters['weight_decay'],
            'dropout': bestHyperparameters['dropout'], 
            'patience': bestHyperparameters['patience']
        })        

        
        configs = Configs()
        criterion = nn.BCELoss()
        
        model, history = run_network(
            X_train, X_val,
            y_train,
            y_val,
            hyperparameters,
            seeds[i-1], 
            configs
        )

        v_models.append(model)
        loss_train.append(history['loss'])
        loss_dev.append(history['val_loss'])

        y_pred = []
        y_true = []
        test_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                outputs = model(batch_x)
                loss = criterion(outputs, batch_y)
                test_loss += loss.item()
                
                y_pred.extend(outputs.cpu().numpy().flatten())
                y_true.extend(batch_y.cpu().numpy().flatten())
        
        test_loss /= len(test_loader)
        y_pred = np.array(y_pred)  
        y_true = np.array(y_true)
        
        accuracy, recall, specificity, roc_auc, tn, fp, fn, tp = calculate_metrics(y_true, y_pred)
    
        print(f" Test Loss: {test_loss:.4f}")
        print(f"Test Metrics for Split {i} - Accuracy: {accuracy:.4f}, Recall: {recall:.4f}, Specificity: {specificity:.4f}, ROC AUC: {roc_auc:.4f}")
        print(f"Confusion Matrix - TN: {tn}, FP: {fp}, FN: {fn}, TP: {tp}")

        results.append([accuracy, recall, specificity, roc_auc, tn, fp, fn, tp])

        y_pred_by_split[str(i)] = y_pred
        print(f"for split {i}:")
        print(y_pred_by_split[str(i)])

        y_pred_path = os.path.join(split_directory, f"y_pred_split_{i}.pkl")
        with open(y_pred_path, 'wb') as f:
            pickle.dump(y_pred, f)
    
    directory = './Results_FewOpt'
    if not os.path.exists(directory):
        os.makedirs(directory)

    def save_to_pickle(data, filename):
        with open(filename, 'wb') as f:
            pickle.dump(data, f)

    save_to_pickle(y_pred_by_split, os.path.join(directory, "y_pred_by_split.pkl"))
    save_to_pickle(loss_train, os.path.join(directory, "loss_train.pkl"))
    save_to_pickle(loss_dev, os.path.join(directory, "loss_dev.pkl"))
    save_to_pickle(bestHyperparameters_bySplit, os.path.join(directory, "bestHyperparameters_bySplit.pkl"))
# Out:
# cuda:0
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): OPTModel(
#         (decoder): OPTDecoder(
#           (embed_tokens): Embedding(50272, 768, padding_idx=1)
#           (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (layers): ModuleList(
#             (0-11): 12 x OPTDecoderLayer(
#               (self_attn): OPTSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (activation_fn): ReLU()
#               (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.6842, Validation Loss: 0.6733
# Validation Metrics - Accuracy: 0.6682, Recall: 0.6418, Specificity: 0.6795, ROC AUC: 0.6992
# Confusion Matrix - TN: 106, FP: 50, FN: 24, TP: 43
# ROC AUC increased (0.0000 --> 0.6992). Saving model ...
# Epoch 2, Training Loss: 0.5272, Validation Loss: 0.5814
# Validation Metrics - Accuracy: 0.7489, Recall: 0.3284, Specificity: 0.9295, ROC AUC: 0.7127
# Confusion Matrix - TN: 145, FP: 11, FN: 45, TP: 22
# ROC AUC increased (0.6992 --> 0.7127). Saving model ...
# Epoch 3, Training Loss: 0.4739, Validation Loss: 0.7285
# Validation Metrics - Accuracy: 0.6996, Recall: 0.6269, Specificity: 0.7308, ROC AUC: 0.7033
# Confusion Matrix - TN: 114, FP: 42, FN: 25, TP: 42
# EarlyStopping counter: 1 out of 15
# Epoch 4, Training Loss: 0.3594, Validation Loss: 0.8206
# Validation Metrics - Accuracy: 0.6861, Recall: 0.6119, Specificity: 0.7179, ROC AUC: 0.6974
# Confusion Matrix - TN: 112, FP: 44, FN: 26, TP: 41
# EarlyStopping counter: 2 out of 15
# Epoch 5, Training Loss: 0.3122, Validation Loss: 1.1986
# Validation Metrics - Accuracy: 0.5650, Recall: 0.7910, Specificity: 0.4679, ROC AUC: 0.7115
# Confusion Matrix - TN: 73, FP: 83, FN: 14, TP: 53
# EarlyStopping counter: 3 out of 15
# Epoch 6, Training Loss: 0.2828, Validation Loss: 0.9489
# Validation Metrics - Accuracy: 0.6682, Recall: 0.5224, Specificity: 0.7308, ROC AUC: 0.6332
# Confusion Matrix - TN: 114, FP: 42, FN: 32, TP: 35
# EarlyStopping counter: 4 out of 15
# Epoch 7, Training Loss: 0.1671, Validation Loss: 1.1025
# Validation Metrics - Accuracy: 0.6637, Recall: 0.5970, Specificity: 0.6923, ROC AUC: 0.6668
# Confusion Matrix - TN: 108, FP: 48, FN: 27, TP: 40
# EarlyStopping counter: 5 out of 15
# Epoch 8, Training Loss: 0.1173, Validation Loss: 1.1470
# Validation Metrics - Accuracy: 0.7130, Recall: 0.5224, Specificity: 0.7949, ROC AUC: 0.6515
# Confusion Matrix - TN: 124, FP: 32, FN: 32, TP: 35
# EarlyStopping counter: 6 out of 15
# Epoch 9, Training Loss: 0.0960, Validation Loss: 1.4603
#  0.07691322 0.18462421 0.9976841  0.6721224  0.09365211 0.08039068
#  0.12514289 0.60996586 0.26360303 0.11311799 0.12864979 0.14344579
#  0.23093198 0.5067304  0.17007096 0.10218439 0.22863752 0.77959895
#  0.237131   0.03147855 0.11641017 0.30051184 0.97708637 0.06486773
#  0.8247215  0.23054013 0.1632703  0.20014365 0.66043586 0.37168896
#  0.5760775  0.76727724 0.15544072 0.18721053]
# cuda:0
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): OPTModel(
#         (decoder): OPTDecoder(
#           (embed_tokens): Embedding(50272, 768, padding_idx=1)
#           (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (layers): ModuleList(
#             (0-11): 12 x OPTDecoderLayer(
#               (self_attn): OPTSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (activation_fn): ReLU()
#               (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7516, Validation Loss: 0.5862
# Validation Metrics - Accuracy: 0.7110, Recall: 0.7722, Specificity: 0.6848, ROC AUC: 0.7869
# Confusion Matrix - TN: 126, FP: 58, FN: 18, TP: 61
# ROC AUC increased (0.0000 --> 0.7869). Saving model ...
# Epoch 2, Training Loss: 0.6061, Validation Loss: 0.5517
# Validation Metrics - Accuracy: 0.7871, Recall: 0.5316, Specificity: 0.8967, ROC AUC: 0.7700
# Confusion Matrix - TN: 165, FP: 19, FN: 37, TP: 42
# EarlyStopping counter: 1 out of 15
# Epoch 3, Training Loss: 0.5722, Validation Loss: 0.8069
# Validation Metrics - Accuracy: 0.5285, Recall: 0.8608, Specificity: 0.3859, ROC AUC: 0.7875
# Confusion Matrix - TN: 71, FP: 113, FN: 11, TP: 68
# EarlyStopping counter: 2 out of 15
# Epoch 4, Training Loss: 0.4552, Validation Loss: 0.6573
# Validation Metrics - Accuracy: 0.7414, Recall: 0.7215, Specificity: 0.7500, ROC AUC: 0.7784
# Confusion Matrix - TN: 138, FP: 46, FN: 22, TP: 57
# EarlyStopping counter: 3 out of 15
# Epoch 5, Training Loss: 0.4556, Validation Loss: 0.8085
# Validation Metrics - Accuracy: 0.6920, Recall: 0.7975, Specificity: 0.6467, ROC AUC: 0.8043
# Confusion Matrix - TN: 119, FP: 65, FN: 16, TP: 63
# ROC AUC increased (0.7869 --> 0.8043). Saving model ...
# Epoch 6, Training Loss: 0.4048, Validation Loss: 0.6117
# Validation Metrics - Accuracy: 0.7757, Recall: 0.7215, Specificity: 0.7989, ROC AUC: 0.8253
# Confusion Matrix - TN: 147, FP: 37, FN: 22, TP: 57
# ROC AUC increased (0.8043 --> 0.8253). Saving model ...
# Epoch 7, Training Loss: 0.2965, Validation Loss: 1.0727
# Validation Metrics - Accuracy: 0.7224, Recall: 0.7848, Specificity: 0.6957, ROC AUC: 0.8052
# Confusion Matrix - TN: 128, FP: 56, FN: 17, TP: 62
# EarlyStopping counter: 1 out of 15
# Epoch 8, Training Loss: 0.2514, Validation Loss: 0.6143
# Validation Metrics - Accuracy: 0.7795, Recall: 0.6203, Specificity: 0.8478, ROC AUC: 0.8165
# Confusion Matrix - TN: 156, FP: 28, FN: 30, TP: 49
# EarlyStopping counter: 2 out of 15
# Epoch 9, Training Loss: 0.2132, Validation Loss: 0.9228
# Validation Metrics - Accuracy: 0.7262, Recall: 0.8481, Specificity: 0.6739, ROC AUC: 0.8190
# Confusion Matrix - TN: 124, FP: 60, FN: 12, TP: 67
# EarlyStopping counter: 3 out of 15
# Epoch 10, Training Loss: 0.2019, Validation Loss: 0.8476
# Validation Metrics - Accuracy: 0.6920, Recall: 0.7975, Specificity: 0.6467, ROC AUC: 0.8012
# Confusion Matrix - TN: 119, FP: 65, FN: 16, TP: 63
# EarlyStopping counter: 4 out of 15
# Epoch 11, Training Loss: 0.1526, Validation Loss: 1.0868
# Validation Metrics - Accuracy: 0.6692, Recall: 0.8481, Specificity: 0.5924, ROC AUC: 0.8203
# Confusion Matrix - TN: 109, FP: 75, FN: 12, TP: 67
# EarlyStopping counter: 5 out of 15
# Epoch 12, Training Loss: 0.1382, Validation Loss: 1.0850
# Validation Metrics - Accuracy: 0.7034, Recall: 0.8481, Specificity: 0.6413, ROC AUC: 0.8189
# Confusion Matrix - TN: 118, FP: 66, FN: 12, TP: 67
# EarlyStopping counter: 6 out of 15
# Epoch 13, Training Loss: 0.1180, Validation Loss: 0.9961
# Validation Metrics - Accuracy: 0.7452, Recall: 0.8354, Specificity: 0.7065, ROC AUC: 0.8223
# Confusion Matrix - TN: 130, FP: 54, FN: 13, TP: 66
# EarlyStopping counter: 7 out of 15
# Epoch 14, Training Loss: 0.1147, Validation Loss: 0.9666
# Validation Metrics - Accuracy: 0.7719, Recall: 0.7848, Specificity: 0.7663, ROC AUC: 0.8197
# Confusion Matrix - TN: 141, FP: 43, FN: 17, TP: 62
# EarlyStopping counter: 8 out of 15
# Epoch 15, Training Loss: 0.1084, Validation Loss: 1.0822
# Validation Metrics - Accuracy: 0.7376, Recall: 0.8228, Specificity: 0.7011, ROC AUC: 0.8175
# Confusion Matrix - TN: 129, FP: 55, FN: 14, TP: 65
# EarlyStopping counter: 9 out of 15
# Epoch 16, Training Loss: 0.0992, Validation Loss: 1.4778
# Validation Metrics - Accuracy: 0.7262, Recall: 0.8354, Specificity: 0.6793, ROC AUC: 0.8174
# Confusion Matrix - TN: 125, FP: 59, FN: 13, TP: 66
# EarlyStopping counter: 10 out of 15
# Epoch 17, Training Loss: 0.1078, Validation Loss: 1.5245
# Validation Metrics - Accuracy: 0.7300, Recall: 0.8228, Specificity: 0.6902, ROC AUC: 0.8158
# Confusion Matrix - TN: 127, FP: 57, FN: 14, TP: 65
# EarlyStopping counter: 11 out of 15
# Epoch 18, Training Loss: 0.0802, Validation Loss: 1.5758
# Validation Metrics - Accuracy: 0.7224, Recall: 0.8354, Specificity: 0.6739, ROC AUC: 0.8142
# Confusion Matrix - TN: 124, FP: 60, FN: 13, TP: 66
# EarlyStopping counter: 12 out of 15
# Epoch 19, Training Loss: 0.0832, Validation Loss: 1.5571
# Validation Metrics - Accuracy: 0.7414, Recall: 0.8228, Specificity: 0.7065, ROC AUC: 0.8169
# Confusion Matrix - TN: 130, FP: 54, FN: 14, TP: 65
# EarlyStopping counter: 13 out of 15
#  0.28118375 0.5588769  0.26998425 0.6402678  0.09943599 0.05414072
#  0.19838113 0.105773   0.9626424  0.10290551 0.7091359  0.04720788
#  0.17885086 0.11961443 0.9885129  0.7147622  0.5664075  0.6700345
#  0.10454661 0.1437129  0.13916664 0.01045213 0.08331338 0.06042587
#  0.82495594 0.9617237  0.68344945 0.9999789  0.05271463 0.24284448
#  0.00810541 0.60768986 0.9929609  0.05425648 0.85910904 0.20981696
#  0.8452906  0.71541363 0.80791575 0.06138893 0.4078197  0.971799
#  0.08489922 0.89215034 0.916339   0.77630836 0.44888967 0.221969
#  0.09056073 0.02045721 0.9340161  0.01235281 0.54869354 0.2882435
#  0.02542248 0.08144665 0.6629469  0.9568993  0.32448676 0.8479805
#  0.04044232 0.06832497 0.3362876  0.01203326 0.01690158 0.2607776
#  0.9986141  0.40819818 0.94315934 0.29943982 0.01387515 0.0362689
#  0.19326155 0.06592564 0.79792714 0.25991368 0.97124946 0.7217383
#  0.05351929 0.62245566 0.9738461  0.04686083 0.99785703 0.16281703
#  0.869344   0.53292567 0.37990218 0.24226977 0.51615053 0.99631435
#  0.03165212 0.8745063  0.23890918 0.14831644]
# cuda:0
# LLMFew(
#   (llm_model): PeftModel(
#     (base_model): LoraModel(
#       (model): OPTModel(
#         (decoder): OPTDecoder(
#           (embed_tokens): Embedding(50272, 768, padding_idx=1)
#           (embed_positions): OPTLearnedPositionalEmbedding(2050, 768)
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (layers): ModuleList(
#             (0-11): 12 x OPTDecoderLayer(
#               (self_attn): OPTSdpaAttention(
#                 (k_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (v_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (q_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#                 (out_proj): lora.Linear(
#                   (base_layer): Linear(in_features=768, out_features=768, bias=True)
#                   (lora_dropout): ModuleDict(
#                     (default): Dropout(p=0.1, inplace=False)
#                   )
#                   (lora_A): ModuleDict(
#                     (default): Linear(in_features=768, out_features=8, bias=False)
#                   )
#                   (lora_B): ModuleDict(
#                     (default): Linear(in_features=8, out_features=768, bias=False)
#                   )
#                   (lora_embedding_A): ParameterDict()
#                   (lora_embedding_B): ParameterDict()
#                   (lora_magnitude_vector): ModuleDict()
#                 )
#               )
#               (activation_fn): ReLU()
#               (self_attn_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (fc1): Linear(in_features=768, out_features=3072, bias=True)
#               (fc2): Linear(in_features=3072, out_features=768, bias=True)
#               (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (patch_embedding): PatchEmbedding(
#     (padding_patch_layer): ReplicationPad1d()
#     (value_embedding): TokenEmbedding(
#       (tokenConv): Conv1d(2, 768, kernel_size=(3,), stride=(1,), padding=(1,), bias=False, padding_mode=circular)
#     )
#     (position_embedding): PositionalEmbedding()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (padding_patch_layer): ReplicationPad1d((0, 1))
#   (encoder): CausalCNNEncoder(
#     (network): Sequential(
#       (0): CausalCNN(
#         (network): Sequential(
#           (0): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(87, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(87, 128, kernel_size=(1,), stride=(1,))
#           )
#           (1): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(4,), dilation=(2,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#           )
#           (2): CausalConvolutionBlock(
#             (causal): Sequential(
#               (0): Conv1d(128, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (1): Chomp1d()
#               (2): LeakyReLU(negative_slope=0.01)
#               (3): Conv1d(64, 64, kernel_size=(3,), stride=(1,), padding=(8,), dilation=(4,))
#               (4): Chomp1d()
#               (5): LeakyReLU(negative_slope=0.01)
#             )
#             (upordownsample): Conv1d(128, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#       )
#       (1): AdaptiveMaxPool1d(output_size=1)
#       (2): SqueezeChannels()
#       (3): Linear(in_features=64, out_features=768, bias=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (ln_proj): LayerNorm((10752,), eps=1e-05, elementwise_affine=True)
#   (mapping): Sequential(
#     (0): Linear(in_features=10752, out_features=1, bias=True)
#     (1): Dropout(p=0.1, inplace=False)
#   )
#   (activation): Sigmoid()
# )
# Epoch 1, Training Loss: 0.7066, Validation Loss: 0.5295
# Validation Metrics - Accuracy: 0.7444, Recall: 0.4125, Specificity: 0.8871, ROC AUC: 0.7659
# Confusion Matrix - TN: 165, FP: 21, FN: 47, TP: 33
# ROC AUC increased (0.0000 --> 0.7659). Saving model ...
# Epoch 2, Training Loss: 0.7235, Validation Loss: 0.6817
# Validation Metrics - Accuracy: 0.7218, Recall: 0.5125, Specificity: 0.8118, ROC AUC: 0.7196
# Confusion Matrix - TN: 151, FP: 35, FN: 39, TP: 41
# EarlyStopping counter: 1 out of 15
# Epoch 3, Training Loss: 0.8321, Validation Loss: 0.7256
# Validation Metrics - Accuracy: 0.7256, Recall: 0.5250, Specificity: 0.8118, ROC AUC: 0.7240
# Confusion Matrix - TN: 151, FP: 35, FN: 38, TP: 42
# EarlyStopping counter: 2 out of 15
# Epoch 4, Training Loss: 0.6765, Validation Loss: 0.7569
# Validation Metrics - Accuracy: 0.7030, Recall: 0.6500, Specificity: 0.7258, ROC AUC: 0.7166
# Confusion Matrix - TN: 135, FP: 51, FN: 28, TP: 52
# EarlyStopping counter: 3 out of 15
# Epoch 5, Training Loss: 0.5120, Validation Loss: 0.9786
# Validation Metrics - Accuracy: 0.7030, Recall: 0.6500, Specificity: 0.7258, ROC AUC: 0.7257
# Confusion Matrix - TN: 135, FP: 51, FN: 28, TP: 52
# EarlyStopping counter: 4 out of 15
# Epoch 6, Training Loss: 0.3288, Validation Loss: 0.9587
# Validation Metrics - Accuracy: 0.6992, Recall: 0.6375, Specificity: 0.7258, ROC AUC: 0.7228
# Confusion Matrix - TN: 135, FP: 51, FN: 29, TP: 51
# EarlyStopping counter: 5 out of 15
# Epoch 7, Training Loss: 0.3025, Validation Loss: 0.9742
# Validation Metrics - Accuracy: 0.6842, Recall: 0.5375, Specificity: 0.7473, ROC AUC: 0.6998
# Confusion Matrix - TN: 139, FP: 47, FN: 37, TP: 43
# EarlyStopping counter: 6 out of 15
# Epoch 8, Training Loss: 0.2462, Validation Loss: 1.0308
# Validation Metrics - Accuracy: 0.6805, Recall: 0.5625, Specificity: 0.7312, ROC AUC: 0.7271
# Confusion Matrix - TN: 136, FP: 50, FN: 35, TP: 45
# EarlyStopping counter: 7 out of 15
# Epoch 9, Training Loss: 0.1897, Validation Loss: 1.2734
# Validation Metrics - Accuracy: 0.6729, Recall: 0.7250, Specificity: 0.6505, ROC AUC: 0.7254
# Confusion Matrix - TN: 121, FP: 65, FN: 22, TP: 58
# EarlyStopping counter: 8 out of 15
# Epoch 10, Training Loss: 0.1602, Validation Loss: 1.2286
# Validation Metrics - Accuracy: 0.6767, Recall: 0.6500, Specificity: 0.6882, ROC AUC: 0.7249
# Confusion Matrix - TN: 128, FP: 58, FN: 28, TP: 52
# EarlyStopping counter: 9 out of 15
# Epoch 11, Training Loss: 0.1520, Validation Loss: 1.2557
# Validation Metrics - Accuracy: 0.6880, Recall: 0.6375, Specificity: 0.7097, ROC AUC: 0.7264
# Confusion Matrix - TN: 132, FP: 54, FN: 29, TP: 51
# EarlyStopping counter: 10 out of 15
# Epoch 12, Training Loss: 0.1439, Validation Loss: 1.3648
# Validation Metrics - Accuracy: 0.6617, Recall: 0.7000, Specificity: 0.6452, ROC AUC: 0.7220
# Confusion Matrix - TN: 120, FP: 66, FN: 24, TP: 56
# EarlyStopping counter: 11 out of 15
# Epoch 13, Training Loss: 0.1171, Validation Loss: 1.3770
# Validation Metrics - Accuracy: 0.6880, Recall: 0.6625, Specificity: 0.6989, ROC AUC: 0.7298
# Confusion Matrix - TN: 130, FP: 56, FN: 27, TP: 53
# EarlyStopping counter: 12 out of 15
# Epoch 14, Training Loss: 0.1039, Validation Loss: 1.4750
# Validation Metrics - Accuracy: 0.6579, Recall: 0.6625, Specificity: 0.6559, ROC AUC: 0.7221
# Confusion Matrix - TN: 122, FP: 64, FN: 27, TP: 53
# EarlyStopping counter: 13 out of 15
# Epoch 15, Training Loss: 0.1014, Validation Loss: 1.4842
# Validation Metrics - Accuracy: 0.6654, Recall: 0.6625, Specificity: 0.6667, ROC AUC: 0.7252
# Confusion Matrix - TN: 124, FP: 62, FN: 27, TP: 53
# EarlyStopping counter: 14 out of 15
# Epoch 16, Training Loss: 0.0851, Validation Loss: 1.5666
# Validation Metrics - Accuracy: 0.6504, Recall: 0.6750, Specificity: 0.6398, ROC AUC: 0.7221
# Confusion Matrix - TN: 119, FP: 67, FN: 26, TP: 54
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 0.5560
# Test Metrics for Split 3 - Accuracy: 0.7138, Recall: 0.3000, Specificity: 0.8914, ROC AUC: 0.7075
# Validation Metrics - Accuracy: 0.7465, Recall: 0.5312, Specificity: 0.8389, ROC AUC: 0.7579
# Confusion Matrix - TN: 125, FP: 24, FN: 30, TP: 34
# EarlyStopping counter: 5 out of 15
# Epoch 7, Training Loss: 0.2359, Validation Loss: 1.0094
# Validation Metrics - Accuracy: 0.6808, Recall: 0.7969, Specificity: 0.6309, ROC AUC: 0.7757
# Confusion Matrix - TN: 94, FP: 55, FN: 13, TP: 51
# EarlyStopping counter: 6 out of 15
# Epoch 8, Training Loss: 0.1836, Validation Loss: 1.0760
# Validation Metrics - Accuracy: 0.6854, Recall: 0.7656, Specificity: 0.6510, ROC AUC: 0.7736
# Confusion Matrix - TN: 97, FP: 52, FN: 15, TP: 49
# EarlyStopping counter: 7 out of 15
# Epoch 9, Training Loss: 0.1375, Validation Loss: 1.0311
# Validation Metrics - Accuracy: 0.7089, Recall: 0.6250, Specificity: 0.7450, ROC AUC: 0.7590
# Confusion Matrix - TN: 111, FP: 38, FN: 24, TP: 40
# EarlyStopping counter: 8 out of 15
# Epoch 10, Training Loss: 0.1442, Validation Loss: 1.1983
# Validation Metrics - Accuracy: 0.6995, Recall: 0.7812, Specificity: 0.6644, ROC AUC: 0.7651
# Confusion Matrix - TN: 99, FP: 50, FN: 14, TP: 50
# EarlyStopping counter: 9 out of 15
# Epoch 11, Training Loss: 0.1122, Validation Loss: 1.1445
# Validation Metrics - Accuracy: 0.7136, Recall: 0.7188, Specificity: 0.7114, ROC AUC: 0.7641
# Confusion Matrix - TN: 106, FP: 43, FN: 18, TP: 46
# EarlyStopping counter: 10 out of 15
# Epoch 12, Training Loss: 0.1061, Validation Loss: 1.2667
# Validation Metrics - Accuracy: 0.7042, Recall: 0.7656, Specificity: 0.6779, ROC AUC: 0.7552
# Confusion Matrix - TN: 101, FP: 48, FN: 15, TP: 49
# EarlyStopping counter: 11 out of 15
# Epoch 13, Training Loss: 0.0927, Validation Loss: 1.2221
# Validation Metrics - Accuracy: 0.7089, Recall: 0.6406, Specificity: 0.7383, ROC AUC: 0.7469
# Confusion Matrix - TN: 110, FP: 39, FN: 23, TP: 41
# EarlyStopping counter: 12 out of 15
# Epoch 14, Training Loss: 0.0923, Validation Loss: 1.3494
# Validation Metrics - Accuracy: 0.7089, Recall: 0.6562, Specificity: 0.7315, ROC AUC: 0.7443
# Confusion Matrix - TN: 109, FP: 40, FN: 22, TP: 42
# EarlyStopping counter: 13 out of 15
# Epoch 15, Training Loss: 0.0791, Validation Loss: 1.4476
# Validation Metrics - Accuracy: 0.6995, Recall: 0.6719, Specificity: 0.7114, ROC AUC: 0.7464
# Confusion Matrix - TN: 106, FP: 43, FN: 21, TP: 43
# EarlyStopping counter: 14 out of 15
# Epoch 16, Training Loss: 0.0790, Validation Loss: 1.4889
# Validation Metrics - Accuracy: 0.6948, Recall: 0.6875, Specificity: 0.6980, ROC AUC: 0.7467
# Confusion Matrix - TN: 104, FP: 45, FN: 20, TP: 44
# EarlyStopping counter: 15 out of 15
# Early stopping.
#  Test Loss: 0.6107
#  0.9378859  0.84403795 0.3306696  0.7097877  0.87055737 0.8710862
#  0.3262427  0.46459123 0.51636815 0.63316125 0.8407867  0.24929081
#  0.29276562 0.21255499 0.8877449  0.41268766 0.8169785  0.94339216
#  0.27617773 0.28913954 0.8180414  0.25523126 0.41550982 0.52253485
#  0.31227967 0.5985673  0.42643768 0.48020247 0.2739807  0.224069
#  0.65758467 0.2260033  0.19337822 0.2339153  0.6924109  0.9050798
#  0.35030323 0.2297898  0.19624844 0.5985421  0.29217592 0.27219373
#  0.83961505 0.5688052  0.8849352  0.35541695 0.3885456  0.50705004
#  0.47573033 0.9823099  0.6786331  0.64981675 0.96976656 0.58441985
#  0.34872738 0.7765622  0.23552811 0.58642673 0.7846587  0.83028495
#  0.43354398 0.59819627 0.14383377 0.2650043  0.3199934  0.11687692
#  0.19040893 0.69813424 0.25288007 0.27669704 0.59555876 0.43527177
#  0.21547896 0.29347068 0.7592865  0.19839591 0.3187579  0.7465582
#  0.9651688  0.34465715 0.82114637 0.5489744  0.44779572 0.7112837
#  0.3458945  0.2833169  0.5976537  0.59920007 0.41701216 0.2589158
#  0.47526124 0.6754556  0.2973924  0.355252   0.8077586  0.1999956
#  0.77705276 0.39833274 0.908198   0.26802325 0.24318346 0.803178
#  0.37445378 0.21860819 0.40791968 0.8184779  0.25255445 0.8844311
#  0.49210674 0.35687515 0.13015758 0.7168489  0.57179695 0.8970381
#  0.32988906 0.71638113]

# %% [markdown]
# ### RESULTS (PERFORMANCE)

# %% [markdown]
# #### Step 1. Load model and best results

# %%
directory = './Results_FewOpt'

def load_from_pickle(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

y_pred_by_split = {}
y_pred_by_split['1'] = load_from_pickle(os.path.join('./Results_FewOpt/split_1', "y_pred_split_1.pkl"))
y_pred_by_split['2'] = load_from_pickle(os.path.join('./Results_FewOpt/split_2', "y_pred_split_2.pkl"))
y_pred_by_split['3'] = load_from_pickle(os.path.join('./Results_FewOpt/split_3', "y_pred_split_3.pkl"))
y_pred_by_split['4'] = load_from_pickle(os.path.join('./Results_FewOpt/split_4', "y_pred_split_4.pkl"))
y_pred_by_split['5'] = load_from_pickle(os.path.join('./Results_FewOpt/split_5', "y_pred_split_5.pkl"))

# %% [markdown]
# #### Step 2. Analysis of results

# %%
all_metrics = []

for i in [2,4,5]: 
    y_test = pd.read_csv(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/y_test_tensor_standardScaler.csv")["individualMRGerm_stac"].values.astype(int)
    y_test_single = y_test.flatten()  
    y_test_pred = y_pred_by_split[str(i)].flatten()  
    
    df_metrics = utils.get_metrics_(y_test_single, (y_test_pred))
    print(df_metrics)
    utils.plot_metrics(df_metrics)
    utils.plot_roc_curve(y_test_single, y_test_pred)

    all_metrics.append(df_metrics)
print(all_metrics)
# Out:
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  280  84  62  94  0.719231     0.602564     0.769231  0.730945  0.562874
#     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  268  98  59  98  0.699809     0.624204      0.73224  0.722686  0.555241
#     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  310  103  66  111  0.713559     0.627119     0.750605  0.747254  0.567775
# [    TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  280  84  62  94  0.719231     0.602564     0.769231  0.730945  0.562874,     TN  FP  FN  TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  268  98  59  98  0.699809     0.624204      0.73224  0.722686  0.555241,     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  310  103  66  111  0.713559     0.627119     0.750605  0.747254  0.567775]

# %%
metrics_FewOpt = pd.concat(all_metrics)
metrics_FewOpt.to_csv('./Results_FewOpt/metrics_FewOpt.csv', index=False)

metrics_FewOpt.head()
# Out:
#     TN   FP  FN   TP  Accuracy  Sensitivity  Specificity   ROC AUC  F1 Score
# 0  280   84  62   94  0.719231     0.602564     0.769231  0.730945  0.562874
# 0  268   98  59   98  0.699809     0.624204     0.732240  0.722686  0.555241
# 0  310  103  66  111  0.713559     0.627119     0.750605  0.747254  0.567775

# %%
metrics_mean = metrics_FewOpt.mean()
metrics_std = metrics_FewOpt.std()

summary_df = pd.DataFrame({
    "Metric": metrics_mean.index,
    "Mean": metrics_mean.values,
    "Standard Deviation": metrics_std.values
})

summary_df.to_csv('./Results_FewOpt/metrics_summary_FewOpt.csv', index=False)

print("\nMean and Standard Deviation of the Splits:")
print(summary_df)
# Out:
# Mean and Standard Deviation of the Splits:
#         Metric        Mean  Standard Deviation
# 0           TN  286.000000           21.633308
# 1           FP   95.000000            9.848858
# 2           FN   62.333333            3.511885
# 3           TP  101.000000            8.888194
# 4     Accuracy    0.710866            0.009987
# 5  Sensitivity    0.617962            0.013415
# 6  Specificity    0.750692            0.018495
# 7      ROC AUC    0.733628            0.012502
# 8     F1 Score    0.561963            0.006317

# %%
metrics_FewOpt = pd.read_csv('./Results_FewOpt/metrics_FewOpt.csv')
stats_Opt = metrics_FewOpt.agg(["mean", "std"]) 
formatted_metrics = stats_Opt.apply(lambda x: f"{x['mean']*100:.2f} ± {x['std']*100:.2f}", axis=0)
formatted_metrics_df = pd.DataFrame(formatted_metrics, columns=["Metrics (Mean ± Std)"])
formatted_metrics_df.to_csv('./Results_FewOpt/metrics_FewOpt_formatted.csv', index=True)
print(formatted_metrics_df)
# Out:
#             Metrics (Mean ± Std)
# TN            28600.00 ± 2163.33
# FP              9500.00 ± 984.89
# FN              6233.33 ± 351.19
# TP             10100.00 ± 888.82
# Accuracy            71.09 ± 1.00
# Sensitivity         61.80 ± 1.34
# Specificity         75.07 ± 1.85
# ROC AUC             73.36 ± 1.25
# F1 Score            56.20 ± 0.63

# %% [markdown]
# ### SHAP

# %%
import shap

model_path = "/home/lcarmona/Modelos_finales/final_models/SHAP_bueno/LLM-Few14/checkpointOpt.pt"
if os.path.exists(model_path):
    configs = Configs()
    model = LLMFew(configs).to(device)
    model.load_state_dict(torch.load(model_path, map_location=device))
    model.eval()
    print("Model loaded")
else:
    raise FileNotFoundError(f"Model not found in {model_path}")

feature_names = [
    'AMG', 'ATF', 'ATI', 'ATP', 'CAR', 'CF1', 'CF2', 'CF3', 'CF4', 'Falta', 
    'GCC', 'GLI', 'LIN', 'LIP', 'MAC', 'MON', 'NTI', 
    'OTR', 'OXA', 'PAP', 'PEN', 'POL', 'QUI', 
    'SUL', 'TTC', 'hoursVM', 'acinet.$_{pc}$', 'enterobac.$_{pc}$', 'enteroc.$_{pc}$',
    'pseud.$_{pc}$', 'staph.$_{pc}$', 'others.$_{pc}$', 'hoursICU', '# pat_atb', '# pat_MR', 
    'CAR.$_{n}$', 'PAP.$_{n}$', 'Falta.$_{n}$', 'QUI.$_{n}$', 
    'ATF.$_{n}$', 'OXA.$_{n}$', 'PEN.$_{n}$', 'CF3.$_{n}$', 
    'GLI.$_{n}$', 'CF4.$_{n}$', 'SUL.$_{n}$', 'NTI.$_{n}$', 
    'LIN.$_{n}$', 'AMG.$_{n}$', 'MAC.$_{n}$', 'CF1.$_{n}$', 'GCC.$_{n}$', 
    'POL.$_{n}$', 'ATI.$_{n}$', 'MON.$_{n}$', 'LIP.$_{n}$', 'TTC.$_{n}$', 
    'OTR.$_{n}$', 'CF2.$_{n}$', 'ATP.$_{n}$', '# pat_ttl', 'posture.$_{change}$', 
    'insulin', 'nutr_art', 'sedation', 'relax', 'hep_fail', 'renal_fail', 
    'coag_fail', 'hemo_fail', 'resp_fail', 'multi_fail', 'n_transf', 
    'vasoactive.$_{drug}$', 'dosis_nems', 'hoursTracheo', 'hoursUlcer', 
    'hoursHemo', 'C01 PIVC 1', 'C01 PIVC 2', 'C02 CVC - YD', 'C02 CVC - SD', 
    'C02 CVC - SI', 'C02 CVC - FD', 'C02 CVC - YI', 'C02 CVC - FI', '# catheters'
]

all_shap_values = []
all_inputs = []

class WrappedModel(nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, x):
        return self.model(x)

wrapped_model = WrappedModel(model)

for i in [1, 2, 3, 4, 5]:
    print(f"Processing split {i}...")
    X_test = np.load(f"/home/lcarmona/Modelos_finales/09032025_LLMs/w14days/s{i}/X_test_tensor_standardScaler.npy")
    X_test_tensor = torch.tensor(np.where(X_test == 666, 0, X_test), dtype=torch.float32).to(device)

    background = X_test_tensor[np.random.choice(X_test_tensor.shape[0], 100, replace=False)]

    explainer = shap.GradientExplainer(wrapped_model, background)
    shap_values = explainer.shap_values(X_test_tensor)

    all_shap_values.append(shap_values)
    all_inputs.append(X_test_tensor.cpu().numpy())

all_shap_concat = np.concatenate(all_shap_values, axis=0)
all_inputs_concat = np.concatenate(all_inputs, axis=0)

if all_shap_concat.ndim == 3:
    shap_values_avg = all_shap_concat.mean(axis=1)
    X_test_avg = all_inputs_concat.mean(axis=1)
else:
    shap_values_avg = all_shap_concat
    X_test_avg = all_inputs_concat

plt.figure(figsize=(12, 8))
shap.summary_plot(
    shap_values_avg,
    X_test_avg,
    feature_names=feature_names,
    max_display=30,
    show=False
)

plt.xticks(rotation=45, fontsize=18) 
plt.yticks(fontsize=19)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=20)
cbar.set_ylabel("Feature value", fontsize=20)

plt.tight_layout()
plt.savefig("shap_summary_llmfewopt14.png", dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Model loaded
# Processing split 1...

# %%
plt.figure(figsize=(12, 8))
shap_values_exp = shap.Explanation(
    values=shap_values_avg,
    data=X_test_avg,
    feature_names=feature_names
)

shap.plots.heatmap(shap_values_exp, show=False)

plt.xticks(fontsize=21, rotation=45)
plt.yticks(fontsize=21)
plt.xlabel("Instances", fontsize=20)

cbar = plt.gcf().axes[-1]
cbar.tick_params(labelsize=19)
cbar.set_ylabel("SHAP value (impact on model output)", fontsize=17)

plt.savefig("shap_heatmap_llmfewopt14.png", dpi=300, bbox_inches='tight')
plt.close()
